# %% [markdown]
# ## AIM: reduce dimensionality by feature selection with BORUTA

# %% [markdown]
# A seperate BORUTA will be performed for each feature set (6 total):
# 1. statistical TFR features (for ratio, EC, and EO)
# 2. stat TFR features + connectivity features (for ratio, EC, and EO)
#
# n_estimates & max_depth for RFs in BORUTA were determined for each feature set in 'boruta_hyperparameter_tuning.ipynb' located in the 'background_notebooks' subdir

# %%
from boruta import BorutaPy
import pandas as pd
import numpy as np
import mne
import pickle
import os

from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # 1. statistical TFR features

# %%
df_features = pd.read_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_stat_features.pkl')
df_features['age'] = df_features['age'].round().astype('Int32') # round age to nearest year and convert to int
df_features = df_features.dropna(subset=['diagnosis'])
df_features.sample(7)
# Out:
#                 ID  age  gender diagnosis  epoch  EO_l_frontal_delta_std  \
# 230   sub-87967057   74     0.0       SMC      3                0.131317
# 5469  sub-88054173   40     1.0      ADHD     10                0.057125
# 6659  sub-88066729   55     1.0       MDD     12                0.044415
# 1724  sub-88010033   31     0.0       MDD      9                0.097276
# 1618  sub-88006477   44     0.0       MDD     11                0.053302
# 3028  sub-88029557   27     0.0      ADHD      5                0.083229
# 511   sub-87968405   59     0.0       SMC      8                0.054586
#
#       EO_l_frontal_delta_mean  EO_l_frontal_delta_median  \
# 230                  0.091946                   0.091946
# 5469                 0.079952                   0.079952
# 6659                 0.068792                   0.068792
# 1724                 0.115370                   0.115370
# 1618                 0.055145                   0.055145
# 3028                 0.083219                   0.083219
# 511                  0.067259                   0.067259
#
#       EO_l_frontal_delta_skew  EO_l_frontal_delta_kurt  ...  \
# 230                  3.326113                12.442580  ...
# 5469                 1.112481                 0.682541  ...
# 6659                 1.948363                 5.399892  ...
# 1724                 2.038411                 4.445757  ...
# 1618                 2.177200                 5.317627  ...
# 3028                 2.246496                 5.591200  ...
# 511                  1.980829                 4.419257  ...
#
#       ratio_r_posterior_beta_std  ratio_r_posterior_beta_mean  \
# 230                     0.579151                     0.901946
# 5469                    1.012567                     1.110645
# 6659                    0.858547                     1.095156
# 1724                    2.580043                     2.160914
# 1618                    0.704590                     1.094550
# 3028                    0.993092                     1.448815
# 511                     0.581078                     0.580018
#
#       ratio_r_posterior_beta_median  ratio_r_posterior_beta_skew  \
# 230                        0.760345                     1.104035
# 5469                       0.778183                     2.241343
# 6659                       0.773212                     1.741732
# 1724                       1.096419                     2.925703
# 1618                       0.907928                     1.748422
# 3028                       1.134454                     1.679474
# 511                        0.367718                     2.184806
#
#       ratio_r_posterior_beta_kurt  ratio_r_posterior_gamma_std  \
# 230                      1.355222                     0.308126
# 5469                     7.032785                     0.101951
# 6659                     2.656008                     0.278072
# 1724                    10.336452                     1.176784
# 1618                     3.573143                     0.520738
# 3028                     2.715663                     0.297821
# 511                      5.318295                     0.020762
#
#       ratio_r_posterior_gamma_mean  ratio_r_posterior_gamma_median  \
# 230                       0.515739                        0.439457
# 5469                      0.255756                        0.239199
# 6659                      0.637446                        0.595991
# 1724                      1.072574                        0.662941
# 1618                      1.005755                        0.873124
# 3028                      0.427952                        0.349677
# 511                       0.042778                        0.037304
#
#       ratio_r_posterior_gamma_skew  ratio_r_posterior_gamma_kurt
# 230                       2.147945                      7.484372
# 5469                      1.375131                      3.180725
# 6659                      1.145482                      2.196289
# 1724                      2.620790                      6.757755
# 1618                      2.047487                      6.556207
# 3028                      2.642864                      9.802142
# 511                       1.846080                      4.875539
#
# [7 rows x 680 columns]

# %% [markdown]
# Subsampling dataset here to rebalance dataset. Possibly would have been more efficient to perform before feature extraction, however I already extracted features of the full sample, which allows me to not have to recompute features if we ever change this subsampling step. Additionally, for a still unknown reason, during feature extraction some participants data seem to be lossed, possibly due to the marked 'BAD' files from preprocessing.

# %%
# subsample dataset to rebalance dataset
df_ids = df_features[(df_features['epoch'] == 1)] # select only first epoch to make sure we subsample from participants, and not from epochs
df_ids_subsample = df_ids.groupby('diagnosis').sample(45, random_state=42) # sample 45 participants per diagnosis (which is the max for OCD)
df_ids_subsample_index = df_ids_subsample['ID'].tolist()
df_stat_subsample = df_features[(df_features['ID'].isin(df_ids_subsample_index))]
df_stat_subsample['diagnosis'].value_counts()
# Out:
# diagnosis
# SMC        540
# HEALTHY    540
# MDD        540
# ADHD       540
# OCD        540
# Name: count, dtype: int64

# %%
# create 3 feature sets [EC, EO, ratio] with column ['ID', 'age', 'gender', 'diagnosis', 'epoch']
df_features_ec = df_stat_subsample[df_features.columns[~(df_stat_subsample.columns.str.startswith('EO') | df_stat_subsample.columns.str.startswith('ratio'))]]
df_features_eo = df_stat_subsample[df_features.columns[~(df_stat_subsample.columns.str.startswith('EC') | df_stat_subsample.columns.str.startswith('ratio'))]]
df_features_ratio = df_stat_subsample[df_features.columns[~(df_stat_subsample.columns.str.startswith('EC') | df_stat_subsample.columns.str.startswith('EO'))]]

# %% [markdown]
# ### Ratio features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_features_ratio.columns if 'ratio' in num_col]
 
X = df_features_ratio[numeric_cols]
Y = df_features_ratio['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=20, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=3, n_estimators=195)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	54
# Tentative: 	50
# Rejected: 	121
# Iteration: 	9 / 100
# Confirmed: 	54
# Tentative: 	50
# Rejected: 	121
# Iteration: 	10 / 100
# Confirmed: 	54
# Tentative: 	50
# Rejected: 	121
# Iteration: 	11 / 100
# Confirmed: 	54
# Tentative: 	50
# Rejected: 	121
# Iteration: 	12 / 100
# Confirmed: 	60
# Tentative: 	44
# Rejected: 	121
# Iteration: 	13 / 100
# Confirmed: 	60
# Tentative: 	39
# Rejected: 	126
# Iteration: 	14 / 100
# Confirmed: 	60
# Tentative: 	39
# Rejected: 	126
# Iteration: 	15 / 100
# Confirmed: 	60
# Tentative: 	39
# Rejected: 	126
# Iteration: 	16 / 100
# Confirmed: 	61
# Tentative: 	33
# Rejected: 	131
# Iteration: 	17 / 100
# Confirmed: 	61
# Tentative: 	33
# Rejected: 	131
# Iteration: 	18 / 100
# Confirmed: 	61
# Tentative: 	33
# Rejected: 	131
# Iteration: 	19 / 100
# Confirmed: 	61
# Tentative: 	33
# Rejected: 	131
# Iteration: 	20 / 100
# Confirmed: 	61
# Tentative: 	33
# Rejected: 	131
# Iteration: 	21 / 100
# Confirmed: 	61
# Tentative: 	33
# Rejected: 	131
# Iteration: 	22 / 100
# Confirmed: 	61
# Tentative: 	33
# Rejected: 	131
# Iteration: 	23 / 100
# Confirmed: 	61
# Tentative: 	29
# Rejected: 	135
# Iteration: 	24 / 100
# Confirmed: 	61
# Tentative: 	29
# Rejected: 	135
# Iteration: 	25 / 100
# Confirmed: 	61
# Tentative: 	29
# Rejected: 	135
# Iteration: 	26 / 100
# Confirmed: 	61
# Tentative: 	29
# Rejected: 	135
# Iteration: 	27 / 100
# Confirmed: 	61
# Tentative: 	27
# Rejected: 	137
# Iteration: 	28 / 100
# Confirmed: 	61
# Tentative: 	27
# Rejected: 	137
# Iteration: 	29 / 100
# Confirmed: 	62
# Tentative: 	26
# Rejected: 	137
# Iteration: 	30 / 100
# Confirmed: 	62
# Tentative: 	26
# Rejected: 	137
# Iteration: 	31 / 100
# Confirmed: 	62
# Tentative: 	26
# Rejected: 	137
# Iteration: 	32 / 100
# Confirmed: 	62
# Tentative: 	26
# Rejected: 	137
# Iteration: 	33 / 100
# Confirmed: 	62
# Tentative: 	26
# Rejected: 	137
# Iteration: 	34 / 100
# Confirmed: 	62
# Tentative: 	26
# Rejected: 	137
# Iteration: 	35 / 100
# Confirmed: 	62
# Tentative: 	26
# Rejected: 	137
# Iteration: 	36 / 100
# Confirmed: 	62
# Tentative: 	26
# Rejected: 	137
# Iteration: 	37 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	38 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	39 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	40 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	41 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	42 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	43 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	44 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	45 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	46 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	47 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	48 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	49 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	50 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	51 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	52 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	53 / 100
# Confirmed: 	62
# Tentative: 	23
# Rejected: 	140
# Iteration: 	54 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	55 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	56 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	57 / 100
# Confirmed: 	64
# Tentative: 	21
# Rejected: 	140
# Iteration: 	58 / 100
# Confirmed: 	64
# Tentative: 	21
# Rejected: 	140
# Iteration: 	59 / 100
# Confirmed: 	64
# Tentative: 	21
# Rejected: 	140
# Iteration: 	60 / 100
# Confirmed: 	64
# Tentative: 	21
# Rejected: 	140
# Iteration: 	61 / 100
# Confirmed: 	64
# Tentative: 	21
# Rejected: 	140
# Iteration: 	62 / 100
# Confirmed: 	64
# Tentative: 	21
# Rejected: 	140
# Iteration: 	63 / 100
# Confirmed: 	64
# Tentative: 	21
# Rejected: 	140
# Iteration: 	64 / 100
# Confirmed: 	64
# Tentative: 	21
# Rejected: 	140
# Iteration: 	65 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	66 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	67 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	68 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	69 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	70 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	71 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	72 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	73 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	74 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	75 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	76 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	77 / 100
# Confirmed: 	65
# Tentative: 	20
# Rejected: 	140
# Iteration: 	78 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	79 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	80 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	81 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	82 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	83 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	84 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	85 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	86 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	87 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	88 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	89 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	90 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	91 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	92 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	93 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	94 / 100
# Confirmed: 	65
# Tentative: 	19
# Rejected: 	141
# Iteration: 	95 / 100
# Confirmed: 	66
# Tentative: 	18
# Rejected: 	141
# Iteration: 	96 / 100
# Confirmed: 	66
# Tentative: 	18
# Rejected: 	141
# Iteration: 	97 / 100
# Confirmed: 	66
# Tentative: 	18
# Rejected: 	141
# Iteration: 	98 / 100
# Confirmed: 	66
# Tentative: 	18
# Rejected: 	141
# Iteration: 	99 / 100
# Confirmed: 	66
# Tentative: 	18
# Rejected: 	141
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	66
# Tentative: 	7
# Rejected: 	141

# %%
selected_columns = df_features_ratio[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_feat_ratio = df_features_ratio[standard_columns]  # select the columns from the DataFrame
print(df_selected_feat_ratio.shape)
df_selected_feat_ratio.sample(5)
# Out:
# (2700, 69)
#                 ID  epoch diagnosis  ratio_l_frontal_theta_mean  \
# 1138  sub-87976413     11   HEALTHY                    1.164398
# 1322  sub-87980913      3   HEALTHY                    2.865208
# 5468  sub-88054173      9      ADHD                    2.300222
# 4076  sub-88042661      9      ADHD                    3.249032
# 1042  sub-87974617     11   HEALTHY                    1.630862
#
#       ratio_l_frontal_theta_median  ratio_l_frontal_gamma_std  \
# 1138                      0.873991                   0.278515
# 1322                      1.735721                   0.672841
# 5468                      1.325076                   0.174439
# 4076                      2.050577                   2.422123
# 1042                      1.187309                   0.342146
#
#       ratio_l_frontal_gamma_mean  ratio_l_frontal_gamma_median  \
# 1138                    0.513499                      0.448008
# 1322                    0.789467                      0.657561
# 5468                    0.306549                      0.266772
# 4076                    1.427004                      0.581138
# 1042                    0.864981                      0.802860
#
#       ratio_m_frontal_theta_mean  ratio_m_frontal_beta_median  ...  \
# 1138                    1.202425                     1.420343  ...
# 1322                    2.367281                     1.058802  ...
# 5468                    2.122678                     1.491304  ...
# 4076                    3.946551                     0.914172  ...
# 1042                    1.483440                     1.507120  ...
#
#       ratio_r_posterior_delta_median  ratio_r_posterior_theta_mean  \
# 1138                        0.813469                      1.183523
# 1322                        0.483612                      1.514127
# 5468                        0.478715                      2.105531
# 4076                        1.269519                      3.750454
# 1042                        0.731819                      1.781351
#
#       ratio_r_posterior_theta_median  ratio_r_posterior_alpha_median  \
# 1138                        0.642713                        1.440177
# 1322                        1.037735                        3.816115
# 5468                        1.350527                        2.303889
# 4076                        1.918219                        3.391514
# 1042                        1.014684                        1.900307
#
#       ratio_r_posterior_beta_std  ratio_r_posterior_beta_mean  \
# 1138                    1.357555                     1.595337
# 1322                    1.406119                     1.962848
# 5468                    0.448780                     0.676730
# 4076                    0.721442                     0.735480
# 1042                    0.956504                     1.614549
#
#       ratio_r_posterior_beta_median  ratio_r_posterior_gamma_std  \
# 1138                       1.146901                     0.913251
# 1322                       1.598665                     0.261337
# 5468                       0.538431                     0.057860
# 4076                       0.445581                     0.719139
# 1042                       1.405128                     3.024930
#
#       ratio_r_posterior_gamma_mean  ratio_r_posterior_gamma_median
# 1138                      1.023929                        0.767025
# 1322                      0.391174                        0.377460
# 5468                      0.112486                        0.097701
# 4076                      0.468172                        0.229470
# 1042                      3.174462                        2.530971
#
# [5 rows x 69 columns]

# %% [markdown]
# ### EC features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_features_ec.columns if 'EC' in num_col]
 
X = df_features_ec[numeric_cols]
Y = df_features_ec['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=20, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=10, n_estimators=200)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	135
# Tentative: 	32
# Rejected: 	58
# Iteration: 	9 / 100
# Confirmed: 	135
# Tentative: 	32
# Rejected: 	58
# Iteration: 	10 / 100
# Confirmed: 	135
# Tentative: 	32
# Rejected: 	58
# Iteration: 	11 / 100
# Confirmed: 	135
# Tentative: 	32
# Rejected: 	58
# Iteration: 	12 / 100
# Confirmed: 	141
# Tentative: 	26
# Rejected: 	58
# Iteration: 	13 / 100
# Confirmed: 	141
# Tentative: 	18
# Rejected: 	66
# Iteration: 	14 / 100
# Confirmed: 	141
# Tentative: 	18
# Rejected: 	66
# Iteration: 	15 / 100
# Confirmed: 	141
# Tentative: 	18
# Rejected: 	66
# Iteration: 	16 / 100
# Confirmed: 	142
# Tentative: 	17
# Rejected: 	66
# Iteration: 	17 / 100
# Confirmed: 	142
# Tentative: 	17
# Rejected: 	66
# Iteration: 	18 / 100
# Confirmed: 	142
# Tentative: 	14
# Rejected: 	69
# Iteration: 	19 / 100
# Confirmed: 	142
# Tentative: 	14
# Rejected: 	69
# Iteration: 	20 / 100
# Confirmed: 	142
# Tentative: 	14
# Rejected: 	69
# Iteration: 	21 / 100
# Confirmed: 	142
# Tentative: 	14
# Rejected: 	69
# Iteration: 	22 / 100
# Confirmed: 	142
# Tentative: 	14
# Rejected: 	69
# Iteration: 	23 / 100
# Confirmed: 	142
# Tentative: 	13
# Rejected: 	70
# Iteration: 	24 / 100
# Confirmed: 	142
# Tentative: 	13
# Rejected: 	70
# Iteration: 	25 / 100
# Confirmed: 	142
# Tentative: 	13
# Rejected: 	70
# Iteration: 	26 / 100
# Confirmed: 	142
# Tentative: 	13
# Rejected: 	70
# Iteration: 	27 / 100
# Confirmed: 	142
# Tentative: 	13
# Rejected: 	70
# Iteration: 	28 / 100
# Confirmed: 	142
# Tentative: 	13
# Rejected: 	70
# Iteration: 	29 / 100
# Confirmed: 	142
# Tentative: 	13
# Rejected: 	70
# Iteration: 	30 / 100
# Confirmed: 	142
# Tentative: 	13
# Rejected: 	70
# Iteration: 	31 / 100
# Confirmed: 	142
# Tentative: 	13
# Rejected: 	70
# Iteration: 	32 / 100
# Confirmed: 	143
# Tentative: 	12
# Rejected: 	70
# Iteration: 	33 / 100
# Confirmed: 	143
# Tentative: 	12
# Rejected: 	70
# Iteration: 	34 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	35 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	36 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	37 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	38 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	39 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	40 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	41 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	42 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	43 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	44 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	45 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	46 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	47 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	48 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	49 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	50 / 100
# Confirmed: 	143
# Tentative: 	10
# Rejected: 	72
# Iteration: 	51 / 100
# Confirmed: 	144
# Tentative: 	9
# Rejected: 	72
# Iteration: 	52 / 100
# Confirmed: 	144
# Tentative: 	9
# Rejected: 	72
# Iteration: 	53 / 100
# Confirmed: 	144
# Tentative: 	9
# Rejected: 	72
# Iteration: 	54 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	55 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	56 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	57 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	58 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	59 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	60 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	61 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	62 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	63 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	64 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	65 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	66 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	67 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	68 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	69 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	70 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	71 / 100
# Confirmed: 	146
# Tentative: 	7
# Rejected: 	72
# Iteration: 	72 / 100
# Confirmed: 	146
# Tentative: 	6
# Rejected: 	73
# Iteration: 	73 / 100
# Confirmed: 	146
# Tentative: 	6
# Rejected: 	73
# Iteration: 	74 / 100
# Confirmed: 	146
# Tentative: 	6
# Rejected: 	73
# Iteration: 	75 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	76 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	77 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	78 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	79 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	80 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	81 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	82 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	83 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	84 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	85 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	86 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	87 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	88 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	89 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	90 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	91 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	92 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	93 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	94 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	95 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	96 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	97 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	98 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
# Iteration: 	99 / 100
# Confirmed: 	147
# Tentative: 	5
# Rejected: 	73
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	147
# Tentative: 	1
# Rejected: 	73

# %%
selected_columns = df_features_ec[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_feat_ec = df_features_ec[standard_columns]  # select the columns from the DataFrame
print(df_selected_feat_ec.shape)
df_selected_feat_ec.sample(5)
# Out:
# (2700, 150)
#                 ID  epoch diagnosis  EC_l_frontal_delta_mean  \
# 2190  sub-88019033      7      ADHD                 0.049442
# 2536  sub-88023529      5       MDD                 0.075909
# 326   sub-87967509      3       SMC                 0.050580
# 6758  sub-88067493      3      ADHD                 0.086632
# 3456  sub-88035229      1       MDD                 0.097505
#
#       EC_l_frontal_delta_median  EC_l_frontal_theta_std  \
# 2190                   0.049442                0.036766
# 2536                   0.075909                0.033465
# 326                    0.050580                0.038611
# 6758                   0.086632                0.032141
# 3456                   0.097505                0.041207
#
#       EC_l_frontal_theta_mean  EC_l_frontal_theta_median  \
# 2190                 0.048052                   0.048052
# 2536                 0.048818                   0.048818
# 326                  0.067996                   0.067996
# 6758                 0.067233                   0.067233
# 3456                 0.071340                   0.071340
#
#       EC_l_frontal_alpha_std  EC_l_frontal_alpha_mean  ...  \
# 2190                0.054522                 0.069290  ...
# 2536                0.066115                 0.059850  ...
# 326                 0.055883                 0.078750  ...
# 6758                0.022857                 0.040665  ...
# 3456                0.017822                 0.032206  ...
#
#       EC_r_posterior_alpha_median  EC_r_posterior_alpha_skew  \
# 2190                     0.081476                   2.268587
# 2536                     0.042445                   1.636998
# 326                      0.075164                   2.161599
# 6758                     0.057605                   0.833860
# 3456                     0.047941                   0.747524
#
#       EC_r_posterior_beta_std  EC_r_posterior_beta_mean  \
# 2190                 0.011888                  0.031144
# 2536                 0.017411                  0.022479
# 326                  0.003428                  0.007617
# 6758                 0.007148                  0.014202
# 3456                 0.004921                  0.015025
#
#       EC_r_posterior_beta_median  EC_r_posterior_gamma_std  \
# 2190                    0.031144                  0.002748
# 2536                    0.022479                  0.001506
# 326                     0.007617                  0.000428
# 6758                    0.014202                  0.001080
# 3456                    0.015025                  0.000980
#
#       EC_r_posterior_gamma_mean  EC_r_posterior_gamma_median  \
# 2190                   0.009717                     0.009717
# 2536                   0.004912                     0.004912
# 326                    0.001477                     0.001477
# 6758                   0.004127                     0.004127
# 3456                   0.003169                     0.003169
#
#       EC_r_posterior_gamma_skew  EC_r_posterior_gamma_kurt
# 2190                   0.219625                   0.058755
# 2536                   0.575311                  -0.286306
# 326                    0.304032                  -0.017980
# 6758                   0.335330                  -0.117589
# 3456                   1.760780                   4.571128
#
# [5 rows x 150 columns]

# %% [markdown]
# ### EO features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_features_eo.columns if 'EO' in num_col]
 
X = df_features_eo[numeric_cols]
Y = df_features_eo['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=20, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=10, n_estimators=195)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	118
# Tentative: 	37
# Rejected: 	70
# Iteration: 	9 / 100
# Confirmed: 	118
# Tentative: 	37
# Rejected: 	70
# Iteration: 	10 / 100
# Confirmed: 	118
# Tentative: 	37
# Rejected: 	70
# Iteration: 	11 / 100
# Confirmed: 	118
# Tentative: 	37
# Rejected: 	70
# Iteration: 	12 / 100
# Confirmed: 	121
# Tentative: 	34
# Rejected: 	70
# Iteration: 	13 / 100
# Confirmed: 	121
# Tentative: 	27
# Rejected: 	77
# Iteration: 	14 / 100
# Confirmed: 	121
# Tentative: 	27
# Rejected: 	77
# Iteration: 	15 / 100
# Confirmed: 	121
# Tentative: 	27
# Rejected: 	77
# Iteration: 	16 / 100
# Confirmed: 	126
# Tentative: 	22
# Rejected: 	77
# Iteration: 	17 / 100
# Confirmed: 	126
# Tentative: 	22
# Rejected: 	77
# Iteration: 	18 / 100
# Confirmed: 	126
# Tentative: 	22
# Rejected: 	77
# Iteration: 	19 / 100
# Confirmed: 	127
# Tentative: 	21
# Rejected: 	77
# Iteration: 	20 / 100
# Confirmed: 	127
# Tentative: 	21
# Rejected: 	77
# Iteration: 	21 / 100
# Confirmed: 	127
# Tentative: 	21
# Rejected: 	77
# Iteration: 	22 / 100
# Confirmed: 	128
# Tentative: 	20
# Rejected: 	77
# Iteration: 	23 / 100
# Confirmed: 	128
# Tentative: 	20
# Rejected: 	77
# Iteration: 	24 / 100
# Confirmed: 	128
# Tentative: 	20
# Rejected: 	77
# Iteration: 	25 / 100
# Confirmed: 	128
# Tentative: 	20
# Rejected: 	77
# Iteration: 	26 / 100
# Confirmed: 	128
# Tentative: 	20
# Rejected: 	77
# Iteration: 	27 / 100
# Confirmed: 	128
# Tentative: 	20
# Rejected: 	77
# Iteration: 	28 / 100
# Confirmed: 	128
# Tentative: 	20
# Rejected: 	77
# Iteration: 	29 / 100
# Confirmed: 	129
# Tentative: 	19
# Rejected: 	77
# Iteration: 	30 / 100
# Confirmed: 	129
# Tentative: 	19
# Rejected: 	77
# Iteration: 	31 / 100
# Confirmed: 	129
# Tentative: 	19
# Rejected: 	77
# Iteration: 	32 / 100
# Confirmed: 	129
# Tentative: 	18
# Rejected: 	78
# Iteration: 	33 / 100
# Confirmed: 	129
# Tentative: 	18
# Rejected: 	78
# Iteration: 	34 / 100
# Confirmed: 	130
# Tentative: 	17
# Rejected: 	78
# Iteration: 	35 / 100
# Confirmed: 	130
# Tentative: 	17
# Rejected: 	78
# Iteration: 	36 / 100
# Confirmed: 	130
# Tentative: 	17
# Rejected: 	78
# Iteration: 	37 / 100
# Confirmed: 	132
# Tentative: 	15
# Rejected: 	78
# Iteration: 	38 / 100
# Confirmed: 	132
# Tentative: 	15
# Rejected: 	78
# Iteration: 	39 / 100
# Confirmed: 	132
# Tentative: 	15
# Rejected: 	78
# Iteration: 	40 / 100
# Confirmed: 	132
# Tentative: 	14
# Rejected: 	79
# Iteration: 	41 / 100
# Confirmed: 	132
# Tentative: 	14
# Rejected: 	79
# Iteration: 	42 / 100
# Confirmed: 	132
# Tentative: 	14
# Rejected: 	79
# Iteration: 	43 / 100
# Confirmed: 	132
# Tentative: 	14
# Rejected: 	79
# Iteration: 	44 / 100
# Confirmed: 	132
# Tentative: 	14
# Rejected: 	79
# Iteration: 	45 / 100
# Confirmed: 	132
# Tentative: 	14
# Rejected: 	79
# Iteration: 	46 / 100
# Confirmed: 	132
# Tentative: 	14
# Rejected: 	79
# Iteration: 	47 / 100
# Confirmed: 	132
# Tentative: 	14
# Rejected: 	79
# Iteration: 	48 / 100
# Confirmed: 	132
# Tentative: 	14
# Rejected: 	79
# Iteration: 	49 / 100
# Confirmed: 	132
# Tentative: 	14
# Rejected: 	79
# Iteration: 	50 / 100
# Confirmed: 	132
# Tentative: 	14
# Rejected: 	79
# Iteration: 	51 / 100
# Confirmed: 	134
# Tentative: 	11
# Rejected: 	80
# Iteration: 	52 / 100
# Confirmed: 	134
# Tentative: 	11
# Rejected: 	80
# Iteration: 	53 / 100
# Confirmed: 	134
# Tentative: 	11
# Rejected: 	80
# Iteration: 	54 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	55 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	56 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	57 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	58 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	59 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	60 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	61 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	62 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	63 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	64 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	65 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	66 / 100
# Confirmed: 	134
# Tentative: 	10
# Rejected: 	81
# Iteration: 	67 / 100
# Confirmed: 	135
# Tentative: 	9
# Rejected: 	81
# Iteration: 	68 / 100
# Confirmed: 	135
# Tentative: 	9
# Rejected: 	81
# Iteration: 	69 / 100
# Confirmed: 	135
# Tentative: 	9
# Rejected: 	81
# Iteration: 	70 / 100
# Confirmed: 	135
# Tentative: 	9
# Rejected: 	81
# Iteration: 	71 / 100
# Confirmed: 	135
# Tentative: 	9
# Rejected: 	81
# Iteration: 	72 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	73 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	74 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	75 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	76 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	77 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	78 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	79 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	80 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	81 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	82 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	83 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	84 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	85 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	86 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	87 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	88 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	89 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	90 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	91 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	92 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	93 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	94 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	95 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	96 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	97 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	98 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
# Iteration: 	99 / 100
# Confirmed: 	135
# Tentative: 	8
# Rejected: 	82
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	135
# Tentative: 	4
# Rejected: 	82

# %%
selected_columns = df_features_eo[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_feat_eo = df_features_eo[standard_columns]  # select the columns from the DataFrame
print(df_selected_feat_eo.shape)
df_selected_feat_eo.sample(5)
# Out:
# (2700, 138)
#                 ID  epoch diagnosis  EO_l_frontal_delta_std  \
# 7259  sub-88071677     12       MDD                0.080671
# 5638  sub-88056021     11      ADHD                0.063258
# 2895  sub-88027577      4      ADHD                0.064711
# 4990  sub-88049813     11       MDD                0.073421
# 5364  sub-88053453      1   HEALTHY                0.057831
#
#       EO_l_frontal_delta_mean  EO_l_frontal_delta_median  \
# 7259                 0.075655                   0.075655
# 5638                 0.108238                   0.108238
# 2895                 0.104482                   0.104482
# 4990                 0.085408                   0.085408
# 5364                 0.088464                   0.088464
#
#       EO_l_frontal_theta_std  EO_l_frontal_theta_mean  \
# 7259                0.042880                 0.056677
# 5638                0.042544                 0.072637
# 2895                0.037772                 0.065109
# 4990                0.039910                 0.064025
# 5364                0.031597                 0.065411
#
#       EO_l_frontal_theta_median  EO_l_frontal_alpha_std  ...  \
# 7259                   0.056677                0.028860  ...
# 5638                   0.072637                0.015852  ...
# 2895                   0.065109                0.020732  ...
# 4990                   0.064025                0.021117  ...
# 5364                   0.065411                0.020111  ...
#
#       EO_r_posterior_alpha_std  EO_r_posterior_alpha_mean  \
# 7259                  0.021461                   0.046086
# 5638                  0.065366                   0.054795
# 2895                  0.012652                   0.031962
# 4990                  0.032505                   0.045560
# 5364                  0.020702                   0.033904
#
#       EO_r_posterior_alpha_median  EO_r_posterior_beta_std  \
# 7259                     0.046086                 0.011956
# 5638                     0.054795                 0.002320
# 2895                     0.031962                 0.003389
# 4990                     0.045560                 0.006710
# 5364                     0.033904                 0.006913
#
#       EO_r_posterior_beta_mean  EO_r_posterior_beta_median  \
# 7259                  0.029646                    0.029646
# 5638                  0.004575                    0.004575
# 2895                  0.008637                    0.008637
# 4990                  0.013511                    0.013511
# 5364                  0.012628                    0.012628
#
#       EO_r_posterior_gamma_std  EO_r_posterior_gamma_mean  \
# 7259                  0.003663                   0.011674
# 5638                  0.000098                   0.000294
# 2895                  0.000729                   0.002004
# 4990                  0.001145                   0.004198
# 5364                  0.000327                   0.001240
#
#       EO_r_posterior_gamma_median  EO_r_posterior_gamma_skew
# 7259                     0.011674                   1.194249
# 5638                     0.000294                   1.553898
# 2895                     0.002004                   1.004588
# 4990                     0.004198                   0.221794
# 5364                     0.001240                   0.395833
#
# [5 rows x 138 columns]

# %% [markdown]
# ### Merge selected ratio, EC, EO features

# %%
# Drop the 'ID', 'epoch', 'diagnosis' columns from the second and third dataframes for concatenation
df_selected_feat_eo = df_selected_feat_eo.drop(['ID', 'epoch', 'diagnosis'], axis=1)
df_selected_feat_ratio = df_selected_feat_ratio.drop(['ID', 'epoch', 'diagnosis'], axis=1)

# Concatenate the dataframes
df_selected_features = pd.concat([df_selected_feat_ec, df_selected_feat_eo, df_selected_feat_ratio], axis=1)
df_selected_features
# Out:
#                 ID  epoch diagnosis  EC_l_frontal_delta_mean  \
# 24    sub-87964717      1       SMC                 0.038548
# 25    sub-87964717      2       SMC                 0.064845
# 26    sub-87964717      3       SMC                 0.060132
# 27    sub-87964717      4       SMC                 0.068201
# 28    sub-87964717      5       SMC                 0.060723
# ...            ...    ...       ...                      ...
# 7807  sub-88076717      8       OCD                 0.052290
# 7808  sub-88076717      9       OCD                 0.068988
# 7809  sub-88076717     10       OCD                 0.076952
# 7810  sub-88076717     11       OCD                 0.087063
# 7811  sub-88076717     12       OCD                 0.058535
#
#       EC_l_frontal_delta_median  EC_l_frontal_theta_std  \
# 24                     0.038548                0.038556
# 25                     0.064845                0.030842
# 26                     0.060132                0.032789
# 27                     0.068201                0.061580
# 28                     0.060723                0.035185
# ...                         ...                     ...
# 7807                   0.052290                0.053702
# 7808                   0.068988                0.041480
# 7809                   0.076952                0.060294
# 7810                   0.087063                0.045478
# 7811                   0.058535                0.114411
#
#       EC_l_frontal_theta_mean  EC_l_frontal_theta_median  \
# 24                   0.052609                   0.052609
# 25                   0.056860                   0.056860
# 26                   0.049954                   0.049954
# 27                   0.059407                   0.059407
# 28                   0.048441                   0.048441
# ...                       ...                        ...
# 7807                 0.070063                   0.070063
# 7808                 0.073598                   0.073598
# 7809                 0.072454                   0.072454
# 7810                 0.061230                   0.061230
# 7811                 0.085738                   0.085738
#
#       EC_l_frontal_alpha_std  EC_l_frontal_alpha_mean  ...  \
# 24                  0.063854                 0.091404  ...
# 25                  0.041251                 0.068083  ...
# 26                  0.040715                 0.072963  ...
# 27                  0.040781                 0.060521  ...
# 28                  0.054241                 0.074711  ...
# ...                      ...                      ...  ...
# 7807                0.041325                 0.066680  ...
# 7808                0.029228                 0.054087  ...
# 7809                0.026849                 0.047361  ...
# 7810                0.032789                 0.051911  ...
# 7811                0.070924                 0.053647  ...
#
#       ratio_r_posterior_delta_median  ratio_r_posterior_theta_mean  \
# 24                          0.510265                      1.349741
# 25                          1.032241                      1.986691
# 26                          0.865775                      1.875845
# 27                          1.053052                      1.827830
# 28                          0.940136                      1.289571
# ...                              ...                           ...
# 7807                        1.219489                      2.867796
# 7808                        0.629160                      1.753572
# 7809                        0.673403                      1.728405
# 7810                        1.129796                      2.133611
# 7811                        0.801522                      1.746650
#
#       ratio_r_posterior_theta_median  ratio_r_posterior_alpha_median  \
# 24                          0.968623                        2.153139
# 25                          1.382212                        1.536313
# 26                          1.188569                        1.681806
# 27                          1.173045                        1.639288
# 28                          0.896923                        1.350853
# ...                              ...                             ...
# 7807                        1.820891                        2.639839
# 7808                        1.330836                        2.605999
# 7809                        1.069284                        1.497162
# 7810                        1.025203                        1.266488
# 7811                        0.629033                        1.650069
#
#       ratio_r_posterior_beta_std  ratio_r_posterior_beta_mean  \
# 24                      1.198007                     1.644368
# 25                      0.634587                     0.918662
# 26                      0.710918                     1.168534
# 27                      0.644873                     0.873910
# 28                      0.370200                     0.759917
# ...                          ...                          ...
# 7807                    3.794338                     4.965127
# 7808                    2.561313                     2.929883
# 7809                    1.769562                     2.767741
# 7810                    1.822750                     2.245996
# 7811                    5.606120                     4.982102
#
#       ratio_r_posterior_beta_median  ratio_r_posterior_gamma_std  \
# 24                         1.278645                     0.429809
# 25                         0.722950                     0.165883
# 26                         0.985158                     0.220094
# 27                         0.704022                     0.175540
# 28                         0.699207                     0.221074
# ...                             ...                          ...
# 7807                       3.652019                     1.843660
# 7808                       2.185694                     0.545471
# 7809                       2.322909                     1.098164
# 7810                       1.705901                     1.059606
# 7811                       3.586529                     2.055670
#
#       ratio_r_posterior_gamma_mean  ratio_r_posterior_gamma_median
# 24                        0.727186                        0.632788
# 25                        0.292965                        0.252897
# 26                        0.396351                        0.343460
# 27                        0.296261                        0.264274
# 28                        0.424809                        0.350868
# ...                            ...                             ...
# 7807                      3.089657                        2.700059
# 7808                      1.459109                        1.403218
# 7809                      2.350843                        2.186206
# 7810                      1.930280                        1.660883
# 7811                      3.842467                        3.485754
#
# [2700 rows x 351 columns]

# %%
df_selected_features.to_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_selected_stat_features.pkl')

# %% [markdown]
# # 2. statistical TFR + connectivity features

# %%
df_conn_features = pd.read_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_connectivity_features.pkl')
df_features = df_features.dropna(subset=['diagnosis'])

# %%
# subsample dataset to rebalance dataset
df_conn_subsample = df_conn_features[(df_conn_features['ID'].isin(df_ids_subsample_index))] # use same sampled IDs from earlier for the stat features
df_conn_subsample['diagnosis'].value_counts()
# Out:
# diagnosis
# SMC        540
# HEALTHY    540
# MDD        540
# ADHD       540
# OCD        540
# Name: count, dtype: int64

# %%
# merge stat and conn features and store for later training of GCNs
df_stat_conn_features = pd.merge(df_stat_subsample, df_conn_subsample.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
# drop age and gender columns
df_stat_conn_features = df_stat_conn_features.drop(columns=['age', 'gender'])
df_stat_conn_features.to_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_stat_conn_features.pkl')
print(df_stat_conn_features.shape)
df_stat_conn_features.sample(3)
# Out:
# (2700, 1218)
#                 ID diagnosis  epoch  EO_l_frontal_delta_std  \
# 2142  sub-88061325      ADHD      7                0.047699
# 1227  sub-88028661      ADHD      4                0.072364
# 2373  sub-88067449      ADHD     10                0.076451
#
#       EO_l_frontal_delta_mean  EO_l_frontal_delta_median  \
# 2142                 0.070020                   0.070020
# 1227                 0.118348                   0.118348
# 2373                 0.098355                   0.098355
#
#       EO_l_frontal_delta_skew  EO_l_frontal_delta_kurt  \
# 2142                 1.450376                 2.170555
# 1227                 0.779897                 0.262668
# 2373                 1.552793                 2.562090
#
#       EO_l_frontal_theta_std  EO_l_frontal_theta_mean  ...  \
# 2142                0.073392                 0.081435  ...
# 1227                0.031054                 0.068841  ...
# 2373                0.043211                 0.066036  ...
#
#       ratio_gamma_m_central-r_central  ratio_gamma_m_central-l_posterior  \
# 2142                         1.005611                           1.010197
# 1227                         1.058662                           1.091577
# 2373                         0.995175                           1.021824
#
#       ratio_gamma_m_central-m_posterior  ratio_gamma_m_central-r_posterior  \
# 2142                           1.015933                           1.031216
# 1227                           1.092001                           1.088674
# 2373                           1.005824                           1.007725
#
#       ratio_gamma_r_central-l_posterior  ratio_gamma_r_central-m_posterior  \
# 2142                           0.989211                           1.001109
# 1227                           1.133577                           1.103998
# 2373                           1.035576                           1.023221
#
#       ratio_gamma_r_central-r_posterior  ratio_gamma_l_posterior-m_posterior  \
# 2142                           1.016366                             1.005210
# 1227                           1.088202                             1.089568
# 2373                           1.027151                             1.008641
#
#       ratio_gamma_l_posterior-r_posterior  ratio_gamma_m_posterior-r_posterior
# 2142                             0.999851                             0.997668
# 1227                             1.083906                             1.042405
# 2373                             1.022826                             1.006733
#
# [3 rows x 1218 columns]

# %%
# create 3 feature sets [EC, EO, ratio] with column ['ID', 'age', 'gender', 'diagnosis', 'epoch']
df_conn_features_ec = df_conn_subsample[df_conn_features.columns[~(df_conn_subsample.columns.str.startswith('EO') | df_conn_subsample.columns.str.startswith('ratio'))]]
df_conn_features_eo = df_conn_subsample[df_conn_features.columns[~(df_conn_subsample.columns.str.startswith('EC') | df_conn_subsample.columns.str.startswith('ratio'))]]
df_conn_features_ratio = df_conn_subsample[df_conn_features.columns[~(df_conn_subsample.columns.str.startswith('EC') | df_conn_subsample.columns.str.startswith('EO'))]]

# %%
# concat connectivity features with stat features
df_stat_conn_features_ec = pd.merge(df_features_ec, df_conn_features_ec.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
df_stat_conn_features_eo = pd.merge(df_features_eo, df_conn_features_eo.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
df_stat_conn_features_ratio = pd.merge(df_features_ratio, df_conn_features_ratio.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
print(df_stat_conn_features_ec.shape)
# Out:
# (2700, 410)

# %% [markdown]
# ### Ratio features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_stat_conn_features_ratio.columns if 'ratio' in num_col]
 
X = df_stat_conn_features_ratio[numeric_cols]
Y = df_stat_conn_features_ratio['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=15, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=10, n_estimators=195)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	115
# Tentative: 	148
# Rejected: 	142
# Iteration: 	9 / 100
# Confirmed: 	115
# Tentative: 	148
# Rejected: 	142
# Iteration: 	10 / 100
# Confirmed: 	115
# Tentative: 	148
# Rejected: 	142
# Iteration: 	11 / 100
# Confirmed: 	115
# Tentative: 	148
# Rejected: 	142
# Iteration: 	12 / 100
# Confirmed: 	142
# Tentative: 	121
# Rejected: 	142
# Iteration: 	13 / 100
# Confirmed: 	142
# Tentative: 	110
# Rejected: 	153
# Iteration: 	14 / 100
# Confirmed: 	142
# Tentative: 	110
# Rejected: 	153
# Iteration: 	15 / 100
# Confirmed: 	142
# Tentative: 	110
# Rejected: 	153
# Iteration: 	16 / 100
# Confirmed: 	153
# Tentative: 	99
# Rejected: 	153
# Iteration: 	17 / 100
# Confirmed: 	153
# Tentative: 	99
# Rejected: 	153
# Iteration: 	18 / 100
# Confirmed: 	153
# Tentative: 	99
# Rejected: 	153
# Iteration: 	19 / 100
# Confirmed: 	162
# Tentative: 	88
# Rejected: 	155
# Iteration: 	20 / 100
# Confirmed: 	162
# Tentative: 	88
# Rejected: 	155
# Iteration: 	21 / 100
# Confirmed: 	162
# Tentative: 	88
# Rejected: 	155
# Iteration: 	22 / 100
# Confirmed: 	165
# Tentative: 	85
# Rejected: 	155
# Iteration: 	23 / 100
# Confirmed: 	165
# Tentative: 	85
# Rejected: 	155
# Iteration: 	24 / 100
# Confirmed: 	165
# Tentative: 	84
# Rejected: 	156
# Iteration: 	25 / 100
# Confirmed: 	165
# Tentative: 	84
# Rejected: 	156
# Iteration: 	26 / 100
# Confirmed: 	168
# Tentative: 	81
# Rejected: 	156
# Iteration: 	27 / 100
# Confirmed: 	168
# Tentative: 	81
# Rejected: 	156
# Iteration: 	28 / 100
# Confirmed: 	168
# Tentative: 	79
# Rejected: 	158
# Iteration: 	29 / 100
# Confirmed: 	168
# Tentative: 	70
# Rejected: 	167
# Iteration: 	30 / 100
# Confirmed: 	168
# Tentative: 	70
# Rejected: 	167
# Iteration: 	31 / 100
# Confirmed: 	168
# Tentative: 	70
# Rejected: 	167
# Iteration: 	32 / 100
# Confirmed: 	169
# Tentative: 	69
# Rejected: 	167
# Iteration: 	33 / 100
# Confirmed: 	169
# Tentative: 	69
# Rejected: 	167
# Iteration: 	34 / 100
# Confirmed: 	170
# Tentative: 	66
# Rejected: 	169
# Iteration: 	35 / 100
# Confirmed: 	170
# Tentative: 	66
# Rejected: 	169
# Iteration: 	36 / 100
# Confirmed: 	170
# Tentative: 	66
# Rejected: 	169
# Iteration: 	37 / 100
# Confirmed: 	176
# Tentative: 	58
# Rejected: 	171
# Iteration: 	38 / 100
# Confirmed: 	176
# Tentative: 	58
# Rejected: 	171
# Iteration: 	39 / 100
# Confirmed: 	176
# Tentative: 	58
# Rejected: 	171
# Iteration: 	40 / 100
# Confirmed: 	177
# Tentative: 	57
# Rejected: 	171
# Iteration: 	41 / 100
# Confirmed: 	177
# Tentative: 	57
# Rejected: 	171
# Iteration: 	42 / 100
# Confirmed: 	177
# Tentative: 	57
# Rejected: 	171
# Iteration: 	43 / 100
# Confirmed: 	178
# Tentative: 	56
# Rejected: 	171
# Iteration: 	44 / 100
# Confirmed: 	178
# Tentative: 	56
# Rejected: 	171
# Iteration: 	45 / 100
# Confirmed: 	178
# Tentative: 	56
# Rejected: 	171
# Iteration: 	46 / 100
# Confirmed: 	179
# Tentative: 	55
# Rejected: 	171
# Iteration: 	47 / 100
# Confirmed: 	179
# Tentative: 	55
# Rejected: 	171
# Iteration: 	48 / 100
# Confirmed: 	179
# Tentative: 	53
# Rejected: 	173
# Iteration: 	49 / 100
# Confirmed: 	179
# Tentative: 	53
# Rejected: 	173
# Iteration: 	50 / 100
# Confirmed: 	179
# Tentative: 	50
# Rejected: 	176
# Iteration: 	51 / 100
# Confirmed: 	179
# Tentative: 	50
# Rejected: 	176
# Iteration: 	52 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	53 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	54 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	55 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	56 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	57 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	58 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	59 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	60 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	61 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	62 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	63 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	64 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	65 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	66 / 100
# Confirmed: 	179
# Tentative: 	47
# Rejected: 	179
# Iteration: 	67 / 100
# Confirmed: 	180
# Tentative: 	46
# Rejected: 	179
# Iteration: 	68 / 100
# Confirmed: 	180
# Tentative: 	46
# Rejected: 	179
# Iteration: 	69 / 100
# Confirmed: 	180
# Tentative: 	46
# Rejected: 	179
# Iteration: 	70 / 100
# Confirmed: 	180
# Tentative: 	43
# Rejected: 	182
# Iteration: 	71 / 100
# Confirmed: 	180
# Tentative: 	43
# Rejected: 	182
# Iteration: 	72 / 100
# Confirmed: 	180
# Tentative: 	43
# Rejected: 	182
# Iteration: 	73 / 100
# Confirmed: 	180
# Tentative: 	43
# Rejected: 	182
# Iteration: 	74 / 100
# Confirmed: 	180
# Tentative: 	43
# Rejected: 	182
# Iteration: 	75 / 100
# Confirmed: 	181
# Tentative: 	42
# Rejected: 	182
# Iteration: 	76 / 100
# Confirmed: 	181
# Tentative: 	42
# Rejected: 	182
# Iteration: 	77 / 100
# Confirmed: 	181
# Tentative: 	42
# Rejected: 	182
# Iteration: 	78 / 100
# Confirmed: 	181
# Tentative: 	41
# Rejected: 	183
# Iteration: 	79 / 100
# Confirmed: 	181
# Tentative: 	41
# Rejected: 	183
# Iteration: 	80 / 100
# Confirmed: 	182
# Tentative: 	40
# Rejected: 	183
# Iteration: 	81 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	82 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	83 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	84 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	85 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	86 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	87 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	88 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	89 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	90 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	91 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	92 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	93 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	94 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	95 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	96 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	97 / 100
# Confirmed: 	182
# Tentative: 	39
# Rejected: 	184
# Iteration: 	98 / 100
# Confirmed: 	182
# Tentative: 	37
# Rejected: 	186
# Iteration: 	99 / 100
# Confirmed: 	182
# Tentative: 	37
# Rejected: 	186
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	182
# Tentative: 	18
# Rejected: 	186

# %%
selected_columns = df_stat_conn_features_ratio[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_stat_conn_feat_ratio = df_stat_conn_features_ratio[standard_columns]  # select the columns from the DataFrame
print(df_selected_stat_conn_feat_ratio.shape)
df_selected_stat_conn_feat_ratio.sample(5)
# Out:
# (2700, 185)
#                 ID  epoch diagnosis  ratio_l_frontal_theta_mean  \
# 277   sub-87968901      2       SMC                    1.809353
# 1537  sub-88046349      2       MDD                    2.084580
# 2400  sub-88067945      1       OCD                    1.788010
# 2016  sub-88057869      1   HEALTHY                    1.533297
# 74    sub-87967057      3       SMC                    2.388149
#
#       ratio_l_frontal_theta_median  ratio_l_frontal_beta_median  \
# 277                       1.297778                     2.185520
# 1537                      0.658338                     0.185791
# 2400                      0.974302                     1.290766
# 2016                      0.987835                     1.956900
# 74                        1.430944                     1.401702
#
#       ratio_l_frontal_gamma_std  ratio_l_frontal_gamma_mean  \
# 277                    3.988424                    6.329305
# 1537                   0.080309                    0.189506
# 2400                   1.211010                    2.384949
# 2016                   1.097599                    1.976693
# 74                     1.403060                    2.272396
#
#       ratio_l_frontal_gamma_median  ratio_m_frontal_theta_mean  ...  \
# 277                       5.826880                    2.070605  ...
# 1537                      0.167204                    1.929247  ...
# 2400                      2.092951                    1.613582  ...
# 2016                      1.751531                    1.394283  ...
# 74                        1.933186                    2.400292  ...
#
#       ratio_gamma_m_central-r_central  ratio_gamma_m_central-l_posterior  \
# 277                          0.917071                           1.011223
# 1537                         0.964027                           0.948596
# 2400                         1.059051                           1.059347
# 2016                         1.039702                           1.101394
# 74                           0.943752                           0.898081
#
#       ratio_gamma_m_central-m_posterior  ratio_gamma_m_central-r_posterior  \
# 277                            1.025837                           1.013874
# 1537                           0.939847                           0.930337
# 2400                           1.053278                           1.071033
# 2016                           1.068633                           1.088429
# 74                             0.936956                           0.962804
#
#       ratio_gamma_r_central-l_posterior  ratio_gamma_r_central-m_posterior  \
# 277                            0.895589                           0.904536
# 1537                           0.948964                           0.961293
# 2400                           1.100112                           1.063313
# 2016                           1.103761                           1.051398
# 74                             0.870618                           0.921746
#
#       ratio_gamma_r_central-r_posterior  ratio_gamma_l_posterior-m_posterior  \
# 277                            0.925220                             1.018816
# 1537                           0.973996                             0.965902
# 2400                           1.064923                             1.054521
# 2016                           1.043351                             1.066353
# 74                             0.976167                             0.941017
#
#       ratio_gamma_l_posterior-r_posterior  ratio_gamma_m_posterior-r_posterior
# 277                              0.998344                             0.998188
# 1537                             0.960743                             0.968686
# 2400                             1.080874                             1.043291
# 2016                             1.072289                             1.059547
# 74                               0.940644                             0.978442
#
# [5 rows x 185 columns]

# %%
# count the number of selected statistical features (columns containing ['std', 'mean', 'median', 'skew', 'kurt'])
stat_selected = [col for col in df_selected_stat_conn_feat_ratio.columns if any(x in col for x in ['std', 'mean', 'median', 'skew', 'kurt'])]
print(len(stat_selected))
# Out:
# 79

# %% [markdown]
# ### EC features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_stat_conn_features_ec.columns if 'EC' in num_col]
 
X = df_stat_conn_features_ec[numeric_cols]
Y = df_stat_conn_features_ec['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=20, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=10, n_estimators=195)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	308
# Tentative: 	30
# Rejected: 	67
# Iteration: 	9 / 100
# Confirmed: 	308
# Tentative: 	30
# Rejected: 	67
# Iteration: 	10 / 100
# Confirmed: 	308
# Tentative: 	30
# Rejected: 	67
# Iteration: 	11 / 100
# Confirmed: 	308
# Tentative: 	30
# Rejected: 	67
# Iteration: 	12 / 100
# Confirmed: 	310
# Tentative: 	28
# Rejected: 	67
# Iteration: 	13 / 100
# Confirmed: 	310
# Tentative: 	28
# Rejected: 	67
# Iteration: 	14 / 100
# Confirmed: 	310
# Tentative: 	28
# Rejected: 	67
# Iteration: 	15 / 100
# Confirmed: 	310
# Tentative: 	24
# Rejected: 	71
# Iteration: 	16 / 100
# Confirmed: 	314
# Tentative: 	20
# Rejected: 	71
# Iteration: 	17 / 100
# Confirmed: 	314
# Tentative: 	20
# Rejected: 	71
# Iteration: 	18 / 100
# Confirmed: 	314
# Tentative: 	20
# Rejected: 	71
# Iteration: 	19 / 100
# Confirmed: 	315
# Tentative: 	19
# Rejected: 	71
# Iteration: 	20 / 100
# Confirmed: 	315
# Tentative: 	19
# Rejected: 	71
# Iteration: 	21 / 100
# Confirmed: 	315
# Tentative: 	18
# Rejected: 	72
# Iteration: 	22 / 100
# Confirmed: 	315
# Tentative: 	18
# Rejected: 	72
# Iteration: 	23 / 100
# Confirmed: 	315
# Tentative: 	16
# Rejected: 	74
# Iteration: 	24 / 100
# Confirmed: 	315
# Tentative: 	16
# Rejected: 	74
# Iteration: 	25 / 100
# Confirmed: 	315
# Tentative: 	16
# Rejected: 	74
# Iteration: 	26 / 100
# Confirmed: 	315
# Tentative: 	16
# Rejected: 	74
# Iteration: 	27 / 100
# Confirmed: 	315
# Tentative: 	16
# Rejected: 	74
# Iteration: 	28 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	29 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	30 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	31 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	32 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	33 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	34 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	35 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	36 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	37 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	38 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	39 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	40 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	41 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	42 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	43 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	44 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	45 / 100
# Confirmed: 	315
# Tentative: 	15
# Rejected: 	75
# Iteration: 	46 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	47 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	48 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	49 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	50 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	51 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	52 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	53 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	54 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	55 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	56 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	57 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	58 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	59 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	60 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	61 / 100
# Confirmed: 	316
# Tentative: 	14
# Rejected: 	75
# Iteration: 	62 / 100
# Confirmed: 	317
# Tentative: 	13
# Rejected: 	75
# Iteration: 	63 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	64 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	65 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	66 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	67 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	68 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	69 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	70 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	71 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	72 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	73 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	74 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	75 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	76 / 100
# Confirmed: 	317
# Tentative: 	10
# Rejected: 	78
# Iteration: 	77 / 100
# Confirmed: 	318
# Tentative: 	9
# Rejected: 	78
# Iteration: 	78 / 100
# Confirmed: 	318
# Tentative: 	9
# Rejected: 	78
# Iteration: 	79 / 100
# Confirmed: 	318
# Tentative: 	9
# Rejected: 	78
# Iteration: 	80 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	81 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	82 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	83 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	84 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	85 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	86 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	87 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	88 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	89 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	90 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	91 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	92 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	93 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	94 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	95 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	96 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	97 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	98 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
# Iteration: 	99 / 100
# Confirmed: 	319
# Tentative: 	8
# Rejected: 	78
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	319
# Tentative: 	6
# Rejected: 	78

# %%
selected_columns = df_stat_conn_features_ec[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_stat_conn_feat_ec = df_stat_conn_features_ec[standard_columns]  # select the columns from the DataFrame
print(df_selected_stat_conn_feat_ec.shape)
df_selected_stat_conn_feat_ec.sample(5)
# Out:
# (2700, 322)
#                 ID  epoch diagnosis  EC_l_frontal_delta_std  \
# 2018  sub-88057869      3   HEALTHY                0.065805
# 359   sub-87969665     12       SMC                0.029795
# 70    sub-87966789     11       SMC                0.029605
# 2216  sub-88064253      9       OCD                0.039437
# 1827  sub-88053677      4       OCD                0.039084
#
#       EC_l_frontal_delta_mean  EC_l_frontal_delta_median  \
# 2018                 0.087256                   0.087256
# 359                  0.031681                   0.031681
# 70                   0.046889                   0.046889
# 2216                 0.051549                   0.051549
# 1827                 0.042453                   0.042453
#
#       EC_l_frontal_theta_std  EC_l_frontal_theta_mean  \
# 2018                0.032833                 0.059346
# 359                 0.040106                 0.056517
# 70                  0.024943                 0.043534
# 2216                0.022063                 0.045536
# 1827                0.029980                 0.048746
#
#       EC_l_frontal_theta_median  EC_l_frontal_alpha_std  ...  \
# 2018                   0.059346                0.031374  ...
# 359                    0.056517                0.069036  ...
# 70                     0.043534                0.063595  ...
# 2216                   0.045536                0.047830  ...
# 1827                   0.048746                0.043958  ...
#
#       EC_gamma_m_central-r_central  EC_gamma_m_central-l_posterior  \
# 2018                      0.784119                        0.757785
# 359                       0.943236                        0.892916
# 70                        0.783991                        0.714249
# 2216                      0.907615                        0.854666
# 1827                      0.820330                        0.780389
#
#       EC_gamma_m_central-m_posterior  EC_gamma_m_central-r_posterior  \
# 2018                        0.759586                        0.757190
# 359                         0.911694                        0.892759
# 70                          0.731389                        0.705721
# 2216                        0.882998                        0.837875
# 1827                        0.810172                        0.773212
#
#       EC_gamma_r_central-l_posterior  EC_gamma_r_central-m_posterior  \
# 2018                        0.784141                        0.791562
# 359                         0.885239                        0.909828
# 70                          0.666140                        0.707568
# 2216                        0.833697                        0.878451
# 1827                        0.741344                        0.786376
#
#       EC_gamma_r_central-r_posterior  EC_gamma_l_posterior-m_posterior  \
# 2018                        0.826607                          0.824762
# 359                         0.910530                          0.903640
# 70                          0.753655                          0.758176
# 2216                        0.860206                          0.871731
# 1827                        0.795513                          0.839005
#
#       EC_gamma_l_posterior-r_posterior  EC_gamma_m_posterior-r_posterior
# 2018                          0.830226                          0.831501
# 359                           0.866558                          0.896179
# 70                            0.692077                          0.756937
# 2216                          0.806258                          0.869970
# 1827                          0.782971                          0.844915
#
# [5 rows x 322 columns]

# %% [markdown]
# ### EO features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_stat_conn_features_eo.columns if 'EO' in num_col]
 
X = df_stat_conn_features_eo[numeric_cols]
Y = df_stat_conn_features_eo['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=20, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=10, n_estimators=190)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	283
# Tentative: 	49
# Rejected: 	73
# Iteration: 	9 / 100
# Confirmed: 	283
# Tentative: 	49
# Rejected: 	73
# Iteration: 	10 / 100
# Confirmed: 	283
# Tentative: 	49
# Rejected: 	73
# Iteration: 	11 / 100
# Confirmed: 	283
# Tentative: 	49
# Rejected: 	73
# Iteration: 	12 / 100
# Confirmed: 	295
# Tentative: 	37
# Rejected: 	73
# Iteration: 	13 / 100
# Confirmed: 	295
# Tentative: 	37
# Rejected: 	73
# Iteration: 	14 / 100
# Confirmed: 	295
# Tentative: 	37
# Rejected: 	73
# Iteration: 	15 / 100
# Confirmed: 	295
# Tentative: 	33
# Rejected: 	77
# Iteration: 	16 / 100
# Confirmed: 	297
# Tentative: 	31
# Rejected: 	77
# Iteration: 	17 / 100
# Confirmed: 	297
# Tentative: 	31
# Rejected: 	77
# Iteration: 	18 / 100
# Confirmed: 	297
# Tentative: 	31
# Rejected: 	77
# Iteration: 	19 / 100
# Confirmed: 	297
# Tentative: 	31
# Rejected: 	77
# Iteration: 	20 / 100
# Confirmed: 	297
# Tentative: 	29
# Rejected: 	79
# Iteration: 	21 / 100
# Confirmed: 	297
# Tentative: 	29
# Rejected: 	79
# Iteration: 	22 / 100
# Confirmed: 	298
# Tentative: 	28
# Rejected: 	79
# Iteration: 	23 / 100
# Confirmed: 	298
# Tentative: 	28
# Rejected: 	79
# Iteration: 	24 / 100
# Confirmed: 	298
# Tentative: 	27
# Rejected: 	80
# Iteration: 	25 / 100
# Confirmed: 	298
# Tentative: 	24
# Rejected: 	83
# Iteration: 	26 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	27 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	28 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	29 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	30 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	31 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	32 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	33 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	34 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	35 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	36 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	37 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	38 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	39 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	40 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	41 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	42 / 100
# Confirmed: 	299
# Tentative: 	23
# Rejected: 	83
# Iteration: 	43 / 100
# Confirmed: 	300
# Tentative: 	22
# Rejected: 	83
# Iteration: 	44 / 100
# Confirmed: 	300
# Tentative: 	22
# Rejected: 	83
# Iteration: 	45 / 100
# Confirmed: 	300
# Tentative: 	21
# Rejected: 	84
# Iteration: 	46 / 100
# Confirmed: 	300
# Tentative: 	21
# Rejected: 	84
# Iteration: 	47 / 100
# Confirmed: 	300
# Tentative: 	21
# Rejected: 	84
# Iteration: 	48 / 100
# Confirmed: 	300
# Tentative: 	21
# Rejected: 	84
# Iteration: 	49 / 100
# Confirmed: 	300
# Tentative: 	21
# Rejected: 	84
# Iteration: 	50 / 100
# Confirmed: 	300
# Tentative: 	20
# Rejected: 	85
# Iteration: 	51 / 100
# Confirmed: 	300
# Tentative: 	20
# Rejected: 	85
# Iteration: 	52 / 100
# Confirmed: 	300
# Tentative: 	20
# Rejected: 	85
# Iteration: 	53 / 100
# Confirmed: 	300
# Tentative: 	20
# Rejected: 	85
# Iteration: 	54 / 100
# Confirmed: 	300
# Tentative: 	18
# Rejected: 	87
# Iteration: 	55 / 100
# Confirmed: 	300
# Tentative: 	18
# Rejected: 	87
# Iteration: 	56 / 100
# Confirmed: 	300
# Tentative: 	18
# Rejected: 	87
# Iteration: 	57 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	58 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	59 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	60 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	61 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	62 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	63 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	64 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	65 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	66 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	67 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	68 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	69 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	70 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	71 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	72 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	73 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	74 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	75 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	76 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	77 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	78 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	79 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	80 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	81 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	82 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	83 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	84 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	85 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	86 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	87 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	88 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	89 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	90 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	91 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	92 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	93 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	94 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	95 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	96 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	97 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	98 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
# Iteration: 	99 / 100
# Confirmed: 	301
# Tentative: 	17
# Rejected: 	87
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	301
# Tentative: 	9
# Rejected: 	87

# %%
selected_columns = df_stat_conn_features_eo[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_stat_conn_feat_eo = df_stat_conn_features_eo[standard_columns]  # select the columns from the DataFrame
print(df_selected_stat_conn_feat_eo.shape)
df_selected_stat_conn_feat_eo.sample(5)
# Out:
# (2700, 304)
#                 ID  epoch diagnosis  EO_l_frontal_delta_mean  \
# 1053  sub-88020153     10       MDD                 0.047093
# 1641  sub-88048729     10   HEALTHY                 0.075992
# 533   sub-87971373      6       SMC                 0.068209
# 841   sub-87982225      2   HEALTHY                 0.105756
# 2021  sub-88057869      6   HEALTHY                 0.095775
#
#       EO_l_frontal_delta_median  EO_l_frontal_theta_std  \
# 1053                   0.047093                0.051526
# 1641                   0.075992                0.027999
# 533                    0.068209                0.023388
# 841                    0.105756                0.039290
# 2021                   0.095775                0.033913
#
#       EO_l_frontal_theta_mean  EO_l_frontal_theta_median  \
# 1053                 0.071701                   0.071701
# 1641                 0.058786                   0.058786
# 533                  0.049326                   0.049326
# 841                  0.060664                   0.060664
# 2021                 0.070260                   0.070260
#
#       EO_l_frontal_alpha_std  EO_l_frontal_alpha_mean  ...  \
# 1053                0.045020                 0.064309  ...
# 1641                0.031386                 0.048063  ...
# 533                 0.073008                 0.056803  ...
# 841                 0.017109                 0.031653  ...
# 2021                0.022717                 0.034513  ...
#
#       EO_gamma_m_central-r_central  EO_gamma_m_central-l_posterior  \
# 1053                      0.738773                        0.761486
# 1641                      0.817315                        0.714306
# 533                       0.715499                        0.675497
# 841                       0.816292                        0.816227
# 2021                      0.717423                        0.679339
#
#       EO_gamma_m_central-m_posterior  EO_gamma_m_central-r_posterior  \
# 1053                        0.768719                        0.732534
# 1641                        0.749558                        0.709733
# 533                         0.728627                        0.684925
# 841                         0.824331                        0.811274
# 2021                        0.697567                        0.690916
#
#       EO_gamma_r_central-l_posterior  EO_gamma_r_central-m_posterior  \
# 1053                        0.680734                        0.712608
# 1641                        0.707782                        0.757056
# 533                         0.593672                        0.672614
# 841                         0.787168                        0.801175
# 2021                        0.710698                        0.740873
#
#       EO_gamma_r_central-r_posterior  EO_gamma_l_posterior-m_posterior  \
# 1053                        0.786745                          0.829309
# 1641                        0.774414                          0.815801
# 533                         0.729554                          0.763374
# 841                         0.812497                          0.857148
# 2021                        0.778434                          0.759898
#
#       EO_gamma_l_posterior-r_posterior  EO_gamma_m_posterior-r_posterior
# 1053                          0.763347                          0.800853
# 1641                          0.771993                          0.809570
# 533                           0.667829                          0.766798
# 841                           0.828976                          0.844081
# 2021                          0.767092                          0.772105
#
# [5 rows x 304 columns]

# %% [markdown]
# ### Merge selected ratio, EC, EO features

# %%
# Drop the 'ID', 'epoch', 'diagnosis' columns from the second and third dataframes for concatenation
df_selected_stat_conn_feat_eo = df_selected_stat_conn_feat_eo.drop(['ID', 'epoch', 'diagnosis'], axis=1)
df_selected_stat_conn_feat_ratio = df_selected_stat_conn_feat_ratio.drop(['ID', 'epoch', 'diagnosis'], axis=1)

# Concatenate the dataframes
df_selected_stat_conn_features = pd.concat([df_selected_stat_conn_feat_ec, df_selected_stat_conn_feat_eo, df_selected_stat_conn_feat_ratio], axis=1)
df_selected_stat_conn_features
# Out:
#                 ID  epoch diagnosis  EC_l_frontal_delta_std  \
# 0     sub-87964717      1       SMC                0.026398
# 1     sub-87964717      2       SMC                0.058279
# 2     sub-87964717      3       SMC                0.059938
# 3     sub-87964717      4       SMC                0.075938
# 4     sub-87964717      5       SMC                0.052394
# ...            ...    ...       ...                     ...
# 2695  sub-88076717      8       OCD                0.039935
# 2696  sub-88076717      9       OCD                0.048182
# 2697  sub-88076717     10       OCD                0.086283
# 2698  sub-88076717     11       OCD                0.093845
# 2699  sub-88076717     12       OCD                0.079435
#
#       EC_l_frontal_delta_mean  EC_l_frontal_delta_median  \
# 0                    0.038548                   0.038548
# 1                    0.064845                   0.064845
# 2                    0.060132                   0.060132
# 3                    0.068201                   0.068201
# 4                    0.060723                   0.060723
# ...                       ...                        ...
# 2695                 0.052290                   0.052290
# 2696                 0.068988                   0.068988
# 2697                 0.076952                   0.076952
# 2698                 0.087063                   0.087063
# 2699                 0.058535                   0.058535
#
#       EC_l_frontal_theta_std  EC_l_frontal_theta_mean  \
# 0                   0.038556                 0.052609
# 1                   0.030842                 0.056860
# 2                   0.032789                 0.049954
# 3                   0.061580                 0.059407
# 4                   0.035185                 0.048441
# ...                      ...                      ...
# 2695                0.053702                 0.070063
# 2696                0.041480                 0.073598
# 2697                0.060294                 0.072454
# 2698                0.045478                 0.061230
# 2699                0.114411                 0.085738
#
#       EC_l_frontal_theta_median  EC_l_frontal_alpha_std  ...  \
# 0                      0.052609                0.063854  ...
# 1                      0.056860                0.041251  ...
# 2                      0.049954                0.040715  ...
# 3                      0.059407                0.040781  ...
# 4                      0.048441                0.054241  ...
# ...                         ...                     ...  ...
# 2695                   0.070063                0.041325  ...
# 2696                   0.073598                0.029228  ...
# 2697                   0.072454                0.026849  ...
# 2698                   0.061230                0.032789  ...
# 2699                   0.085738                0.070924  ...
#
#       ratio_gamma_m_central-r_central  ratio_gamma_m_central-l_posterior  \
# 0                            0.983375                           0.982205
# 1                            0.951962                           0.999252
# 2                            1.007210                           1.003786
# 3                            0.987823                           1.029448
# 4                            1.042865                           1.021432
# ...                               ...                                ...
# 2695                         1.050150                           1.093657
# 2696                         1.095957                           1.144254
# 2697                         1.059378                           1.114762
# 2698                         1.048840                           1.054833
# 2699                         1.069163                           1.087860
#
#       ratio_gamma_m_central-m_posterior  ratio_gamma_m_central-r_posterior  \
# 0                              0.973501                           0.957588
# 1                              0.989583                           0.969516
# 2                              0.997969                           0.981911
# 3                              1.023404                           1.011507
# 4                              1.011774                           1.023296
# ...                                 ...                                ...
# 2695                           1.076960                           1.060231
# 2696                           1.111357                           1.115784
# 2697                           1.086334                           1.146659
# 2698                           1.083075                           1.104262
# 2699                           1.099526                           1.116985
#
#       ratio_gamma_r_central-l_posterior  ratio_gamma_r_central-m_posterior  \
# 0                              0.965101                           0.975819
# 1                              0.930350                           0.938956
# 2                              1.021233                           1.027465
# 3                              0.995531                           1.025771
# 4                              1.010551                           1.047893
# ...                                 ...                                ...
# 2695                           1.153361                           1.122004
# 2696                           1.178204                           1.139658
# 2697                           1.183257                           1.136850
# 2698                           1.037404                           1.049401
# 2699                           1.091360                           1.102320
#
#       ratio_gamma_r_central-r_posterior  ratio_gamma_l_posterior-m_posterior  \
# 0                              0.977929                             0.973242
# 1                              0.968311                             0.982378
# 2                              1.020506                             0.977939
# 3                              1.032580                             0.990293
# 4                              1.041591                             1.019603
# ...                                 ...                                  ...
# 2695                           1.055451                             1.082843
# 2696                           1.100500                             1.109036
# 2697                           1.136010                             1.085056
# 2698                           1.063298                             1.047424
# 2699                           1.098257                             1.062940
#
#       ratio_gamma_l_posterior-r_posterior  ratio_gamma_m_posterior-r_posterior
# 0                                0.955600                             0.985688
# 1                                0.955147                             0.965178
# 2                                0.966586                             0.985563
# 3                                0.982638                             1.006213
# 4                                1.005809                             1.024247
# ...                                   ...                                  ...
# 2695                             1.109466                             1.075791
# 2696                             1.142876                             1.095822
# 2697                             1.136426                             1.107047
# 2698                             1.064664                             1.070277
# 2699                             1.066860                             1.070410
#
# [2700 rows x 805 columns]

# %%
df_selected_stat_conn_features.to_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_selected_stat_conn_features.pkl')
