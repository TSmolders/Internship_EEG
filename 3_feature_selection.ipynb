# %% [markdown]
# ## AIM: reduce dimensionality by feature selection with BORUTA

# %% [markdown]
# A seperate BORUTA will be performed for each feature set (6 total):
# 1. statistical TFR features (for ratio, EC, and EO)
# 2. stat TFR features + connectivity features (for ratio, EC, and EO)
#
# n_estimates & max_depth for RFs in BORUTA were determined for each feature set in 'boruta_hyperparameter_tuning.ipynb' located in the 'background_notebooks' subdir

# %%
from boruta import BorutaPy
import pandas as pd
import numpy as np
import mne
import pickle
import os

from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # 1. statistical TFR features

# %%
df_features = pd.read_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_stat_features.pkl')
df_features['age'] = df_features['age'].round().astype('Int32') # round age to nearest year and convert to int
df_features = df_features.dropna(subset=['diagnosis'])
df_features.sample(7)
# Out:
#                 ID  age  gender diagnosis  epoch  EO_l_frontal_delta_std  \
# 6593  sub-88066281   32     1.0       MDD      6                0.354021
# 69    sub-87966337   58     1.0       SMC     10                0.344499
# 1796  sub-88011333   24     1.0       MDD      9                0.366980
# 7348  sub-88072573   71     1.0       MDD      5                0.352858
# 6146  sub-88061829   48     1.0      ADHD      3                0.341650
# 3743  sub-88039193    7     1.0      ADHD     12                0.381017
# 323   sub-87967421   55     0.0       SMC     12                0.388022
#
#       EO_l_frontal_delta_mean  EO_l_frontal_delta_median  \
# 6593                -0.133072                  -0.131381
# 69                  -0.116322                  -0.116897
# 1796                -0.123264                  -0.123401
# 7348                -0.123107                  -0.119466
# 6146                -0.130367                  -0.134802
# 3743                -0.153673                  -0.149083
# 323                 -0.142892                  -0.145524
#
#       EO_l_frontal_delta_skew  EO_l_frontal_delta_kurt  ...  \
# 6593                -0.360056                 0.340202  ...
# 69                  -0.642301                 0.242954  ...
# 1796                -1.027417                 2.147161  ...
# 7348                -0.555479                -0.183167  ...
# 6146                -0.099623                -0.235092  ...
# 3743                -0.332437                -0.045920  ...
# 323                 -0.849505                 1.310415  ...
#
#       ratio_m_posterior_gamma_std  ratio_m_posterior_gamma_mean  \
# 6593                     0.779333                      0.545003
# 69                       1.146899                      1.627117
# 1796                     1.002552                      1.064240
# 7348                     0.904705                      0.834675
# 6146                     0.934062                      0.869845
# 3743                     0.990820                      1.001293
# 323                      1.152866                      1.350650
#
#       ratio_m_posterior_gamma_median  ratio_m_posterior_gamma_skew  \
# 6593                        0.603597                      4.429617
# 69                          1.575791                      0.170790
# 1796                        1.039252                      0.599186
# 7348                        0.825135                      0.907947
# 6146                        0.880608                      1.234495
# 3743                        1.046003                      0.863973
# 323                         1.353014                      0.756992
#
#       ratio_m_posterior_gamma_kurt  ratio_r_posterior_gamma_std  \
# 6593                     -4.061728                     0.806558
# 69                        0.472410                     1.450624
# 1796                      0.467584                     1.086627
# 7348                      0.398367                     0.900629
# 6146                      9.059310                     1.062249
# 3743                      0.666824                     0.922756
# 323                       1.429903                     1.201116
#
#       ratio_r_posterior_gamma_mean  ratio_r_posterior_gamma_median  \
# 6593                      0.584039                        0.657993
# 69                        3.012854                        2.445614
# 1796                      1.240398                        1.253282
# 7348                      0.821307                        0.809937
# 6146                      1.073870                        1.096663
# 3743                      0.878266                        0.894611
# 323                       1.450808                        1.323888
#
#       ratio_r_posterior_gamma_skew  ratio_r_posterior_gamma_kurt
# 6593                      5.421820                     -5.600346
# 69                       -0.592662                      1.365462
# 1796                      0.647121                      1.122853
# 7348                      1.018040                      0.669341
# 6146                      1.534252                      1.131127
# 3743                      1.058827                      3.876068
# 323                       0.962447                      1.141752
#
# [7 rows x 680 columns]

# %% [markdown]
# Subsampling dataset here to rebalance dataset. Possibly would have been more efficient to perform before feature extraction, however I already extracted features of the full sample, which allows me to not have to recompute features if we ever change this subsampling step. Additionally, for a still unknown reason, during feature extraction some participants data seem to be lossed, possibly due to the marked 'BAD' files from preprocessing.

# %%
# subsample dataset to rebalance dataset
df_ids = df_features[(df_features['epoch'] == 1)] # select only first epoch to make sure we subsample from participants, and not from epochs
df_ids_subsample = df_ids.groupby('diagnosis').sample(45, random_state=42) # sample 45 participants per diagnosis (which is the max for OCD)
df_ids_subsample_index = df_ids_subsample['ID'].tolist()
df_stat_subsample = df_features[(df_features['ID'].isin(df_ids_subsample_index))]
df_stat_subsample['diagnosis'].value_counts()
# Out:
# diagnosis
# SMC        540
# HEALTHY    540
# MDD        540
# ADHD       540
# OCD        540
# Name: count, dtype: int64

# %%
# create 3 feature sets [EC, EO, ratio] with column ['ID', 'age', 'gender', 'diagnosis', 'epoch']
df_features_ec = df_stat_subsample[df_features.columns[~(df_stat_subsample.columns.str.startswith('EO') | df_stat_subsample.columns.str.startswith('ratio'))]]
df_features_eo = df_stat_subsample[df_features.columns[~(df_stat_subsample.columns.str.startswith('EC') | df_stat_subsample.columns.str.startswith('ratio'))]]
df_features_ratio = df_stat_subsample[df_features.columns[~(df_stat_subsample.columns.str.startswith('EC') | df_stat_subsample.columns.str.startswith('EO'))]]

# %% [markdown]
# ### Ratio features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_features_ratio.columns if 'ratio' in num_col]
 
X = df_features_ratio[numeric_cols]
Y = df_features_ratio['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_estimators=190, n_jobs=-1, max_depth=10)
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=1)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 1 / 100
# Iteration: 2 / 100
# Iteration: 3 / 100
# Iteration: 4 / 100
# Iteration: 5 / 100
# Iteration: 6 / 100
# Iteration: 7 / 100
# Iteration: 8 / 100
# Iteration: 9 / 100
# Iteration: 10 / 100
# Iteration: 11 / 100
# Iteration: 12 / 100
# Iteration: 13 / 100
# Iteration: 14 / 100
# Iteration: 15 / 100
# Iteration: 16 / 100
# Iteration: 17 / 100
# Iteration: 18 / 100
# Iteration: 19 / 100
# Iteration: 20 / 100
# Iteration: 21 / 100
# Iteration: 22 / 100
# Iteration: 23 / 100
# Iteration: 24 / 100
# Iteration: 25 / 100
# Iteration: 26 / 100
# Iteration: 27 / 100
# Iteration: 28 / 100
# Iteration: 29 / 100
# Iteration: 30 / 100
# Iteration: 31 / 100
# Iteration: 32 / 100
# Iteration: 33 / 100
# Iteration: 34 / 100
# Iteration: 35 / 100
# Iteration: 36 / 100
# Iteration: 37 / 100
# Iteration: 38 / 100
# Iteration: 39 / 100
# Iteration: 40 / 100
# Iteration: 41 / 100
# Iteration: 42 / 100
# Iteration: 43 / 100
# Iteration: 44 / 100
# Iteration: 45 / 100
# Iteration: 46 / 100
# Iteration: 47 / 100
# Iteration: 48 / 100
# Iteration: 49 / 100
# Iteration: 50 / 100
# Iteration: 51 / 100
# Iteration: 52 / 100
# Iteration: 53 / 100
# Iteration: 54 / 100
# Iteration: 55 / 100
# Iteration: 56 / 100
# Iteration: 57 / 100
# Iteration: 58 / 100
# Iteration: 59 / 100
# Iteration: 60 / 100
# Iteration: 61 / 100
# Iteration: 62 / 100
# Iteration: 63 / 100
# Iteration: 64 / 100
# Iteration: 65 / 100
# Iteration: 66 / 100
# Iteration: 67 / 100
# Iteration: 68 / 100
# Iteration: 69 / 100
# Iteration: 70 / 100
# Iteration: 71 / 100
# Iteration: 72 / 100
# Iteration: 73 / 100
# Iteration: 74 / 100
# Iteration: 75 / 100
# Iteration: 76 / 100
# Iteration: 77 / 100
# Iteration: 78 / 100
# Iteration: 79 / 100
# Iteration: 80 / 100
# Iteration: 81 / 100
# Iteration: 82 / 100
# Iteration: 83 / 100
# Iteration: 84 / 100
# Iteration: 85 / 100
# Iteration: 86 / 100
# Iteration: 87 / 100
# Iteration: 88 / 100
# Iteration: 89 / 100
# Iteration: 90 / 100
# Iteration: 91 / 100
# Iteration: 92 / 100
# Iteration: 93 / 100
# Iteration: 94 / 100
# Iteration: 95 / 100
# Iteration: 96 / 100
# Iteration: 97 / 100
# Iteration: 98 / 100
# Iteration: 99 / 100
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	40
# Tentative: 	10
# Rejected: 	172

# %%
selected_columns = df_features_ratio[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_feat_ratio = df_features_ratio[standard_columns]  # select the columns from the DataFrame
print(df_selected_feat_ratio.shape)
df_selected_feat_ratio.sample(5)
# Out:
# (2700, 43)
#                 ID  epoch diagnosis  ratio_l_frontal_delta_skew  \
# 1037  sub-87974617      6   HEALTHY                    1.233971
# 5844  sub-88058633      1   HEALTHY                    0.783002
# 356   sub-87967729      9       SMC                   -0.436790
# 483   sub-87968229      4       SMC                    1.429541
# 2533  sub-88023529      2       MDD                    2.995655
#
#       ratio_r_central_delta_std  ratio_r_central_theta_std  \
# 1037                   1.118929                   1.053579
# 5844                   0.907015                   1.084074
# 356                    1.255392                   1.526506
# 483                    1.320043                   1.236285
# 2533                   1.018076                   1.264047
#
#       ratio_r_central_theta_mean  ratio_r_central_theta_median  \
# 1037                    1.168728                      1.108943
# 5844                    1.100861                      1.027637
# 356                     2.469541                      2.362854
# 483                     1.415253                      1.309029
# 2533                    1.548660                      1.605007
#
#       ratio_m_posterior_theta_std  ratio_m_posterior_theta_skew  ...  \
# 1037                     1.120620                      0.578223  ...
# 5844                     0.882629                      1.478581  ...
# 356                      1.336713                     -0.036846  ...
# 483                      0.992015                      1.435820  ...
# 2533                     1.225934                      5.235474  ...
#
#       ratio_l_posterior_gamma_skew  ratio_m_posterior_gamma_std  \
# 1037                      2.121189                     0.996538
# 5844                      1.231936                     1.139191
# 356                       0.794741                     0.962432
# 483                       0.575416                     0.927624
# 2533                      1.002283                     1.131391
#
#       ratio_m_posterior_gamma_mean  ratio_m_posterior_gamma_median  \
# 1037                      0.986533                        0.987680
# 5844                      1.244482                        1.299983
# 356                       0.901836                        0.888977
# 483                       0.823107                        1.003550
# 2533                      1.238534                        1.149607
#
#       ratio_m_posterior_gamma_skew  ratio_m_posterior_gamma_kurt  \
# 1037                      1.130715                      2.352754
# 5844                      1.066445                      0.811547
# 356                       1.206662                      0.848008
# 483                       1.399364                      3.316476
# 2533                      1.320463                      8.917814
#
#       ratio_r_posterior_gamma_std  ratio_r_posterior_gamma_mean  \
# 1037                     1.004930                      0.980060
# 5844                     0.997713                      0.984748
# 356                      0.993297                      0.939794
# 483                      0.977974                      0.905741
# 2533                     1.020217                      1.085734
#
#       ratio_r_posterior_gamma_median  ratio_r_posterior_gamma_skew
# 1037                        1.000940                      1.438444
# 5844                        0.804553                      1.413358
# 356                         0.909836                      1.464227
# 483                         0.905537                      1.856935
# 2533                        1.102653                      0.719726
#
# [5 rows x 43 columns]

# %% [markdown]
# ### EC features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_features_ec.columns if 'EC' in num_col]
 
X = df_features_ec[numeric_cols]
Y = df_features_ec['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_estimators=170, n_jobs=-1, max_depth=10)
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=1)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 1 / 100
# Iteration: 2 / 100
# Iteration: 3 / 100
# Iteration: 4 / 100
# Iteration: 5 / 100
# Iteration: 6 / 100
# Iteration: 7 / 100
# Iteration: 8 / 100
# Iteration: 9 / 100
# Iteration: 10 / 100
# Iteration: 11 / 100
# Iteration: 12 / 100
# Iteration: 13 / 100
# Iteration: 14 / 100
# Iteration: 15 / 100
# Iteration: 16 / 100
# Iteration: 17 / 100
# Iteration: 18 / 100
# Iteration: 19 / 100
# Iteration: 20 / 100
# Iteration: 21 / 100
# Iteration: 22 / 100
# Iteration: 23 / 100
# Iteration: 24 / 100
# Iteration: 25 / 100
# Iteration: 26 / 100
# Iteration: 27 / 100
# Iteration: 28 / 100
# Iteration: 29 / 100
# Iteration: 30 / 100
# Iteration: 31 / 100
# Iteration: 32 / 100
# Iteration: 33 / 100
# Iteration: 34 / 100
# Iteration: 35 / 100
# Iteration: 36 / 100
# Iteration: 37 / 100
# Iteration: 38 / 100
# Iteration: 39 / 100
# Iteration: 40 / 100
# Iteration: 41 / 100
# Iteration: 42 / 100
# Iteration: 43 / 100
# Iteration: 44 / 100
# Iteration: 45 / 100
# Iteration: 46 / 100
# Iteration: 47 / 100
# Iteration: 48 / 100
# Iteration: 49 / 100
# Iteration: 50 / 100
# Iteration: 51 / 100
# Iteration: 52 / 100
# Iteration: 53 / 100
# Iteration: 54 / 100
# Iteration: 55 / 100
# Iteration: 56 / 100
# Iteration: 57 / 100
# Iteration: 58 / 100
# Iteration: 59 / 100
# Iteration: 60 / 100
# Iteration: 61 / 100
# Iteration: 62 / 100
# Iteration: 63 / 100
# Iteration: 64 / 100
# Iteration: 65 / 100
# Iteration: 66 / 100
# Iteration: 67 / 100
# Iteration: 68 / 100
# Iteration: 69 / 100
# Iteration: 70 / 100
# Iteration: 71 / 100
# Iteration: 72 / 100
# Iteration: 73 / 100
# Iteration: 74 / 100
# Iteration: 75 / 100
# Iteration: 76 / 100
# Iteration: 77 / 100
# Iteration: 78 / 100
# Iteration: 79 / 100
# Iteration: 80 / 100
# Iteration: 81 / 100
# Iteration: 82 / 100
# Iteration: 83 / 100
# Iteration: 84 / 100
# Iteration: 85 / 100
# Iteration: 86 / 100
# Iteration: 87 / 100
# Iteration: 88 / 100
# Iteration: 89 / 100
# Iteration: 90 / 100
# Iteration: 91 / 100
# Iteration: 92 / 100
# Iteration: 93 / 100
# Iteration: 94 / 100
# Iteration: 95 / 100
# Iteration: 96 / 100
# Iteration: 97 / 100
# Iteration: 98 / 100
# Iteration: 99 / 100
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	59
# Tentative: 	5
# Rejected: 	160

# %%
selected_columns = df_features_ec[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_feat_ec = df_features_ec[standard_columns]  # select the columns from the DataFrame
print(df_selected_feat_ec.shape)
df_selected_feat_ec.sample(5)
# Out:
# (2700, 62)
#                 ID  epoch diagnosis  EC_l_posterior_delta_std  \
# 118   sub-87966473     11       SMC                  0.361000
# 3829  sub-88040317      2      ADHD                  0.385990
# 7036  sub-88069649      5       MDD                  0.315802
# 1102  sub-87974973     11   HEALTHY                  0.332874
# 5484  sub-88054225      1       OCD                  0.399757
#
#       EC_l_frontal_theta_std  EC_l_frontal_theta_mean  \
# 118                 0.278725                -0.082400
# 3829                0.315141                -0.114180
# 7036                0.324260                -0.118766
# 1102                0.281144                -0.091666
# 5484                0.318368                -0.099200
#
#       EC_l_frontal_theta_median  EC_m_frontal_theta_std  \
# 118                   -0.082837                0.291125
# 3829                  -0.110867                0.307256
# 7036                  -0.119059                0.338317
# 1102                  -0.084212                0.284847
# 5484                  -0.097610                0.296773
#
#       EC_r_frontal_theta_std  EC_r_frontal_theta_mean  ...  \
# 118                 0.292709                -0.091547  ...
# 3829                0.308327                -0.105264  ...
# 7036                0.326811                -0.120220  ...
# 1102                0.318866                -0.117089  ...
# 5484                0.277723                -0.090811  ...
#
#       EC_l_posterior_gamma_median  EC_l_posterior_gamma_skew  \
# 118                     -0.074426                  -0.434469
# 3829                    -0.076630                  -0.471768
# 7036                    -0.088418                  -0.551703
# 1102                    -0.150527                   0.235380
# 5484                    -0.075922                  -0.437814
#
#       EC_m_posterior_gamma_std  EC_m_posterior_gamma_mean  \
# 118                   0.253251                  -0.070034
# 3829                  0.290603                  -0.083060
# 7036                  0.293113                  -0.089011
# 1102                  0.319715                  -0.125508
# 5484                  0.277985                  -0.077287
#
#       EC_m_posterior_gamma_median  EC_m_posterior_gamma_skew  \
# 118                     -0.063653                  -0.326626
# 3829                    -0.079624                  -0.820789
# 7036                    -0.086774                  -0.589305
# 1102                    -0.102245                  -0.050409
# 5484                    -0.076054                  -0.714949
#
#       EC_r_posterior_gamma_std  EC_r_posterior_gamma_mean  \
# 118                   0.253837                  -0.069206
# 3829                  0.265776                  -0.073279
# 7036                  0.291287                  -0.088403
# 1102                  0.323900                  -0.124802
# 5484                  0.265993                  -0.074690
#
#       EC_r_posterior_gamma_median  EC_r_posterior_gamma_skew
# 118                     -0.069004                  -0.439956
# 3829                    -0.071196                  -0.584701
# 7036                    -0.086351                  -0.555309
# 1102                    -0.104108                  -0.162607
# 5484                    -0.076316                  -0.503855
#
# [5 rows x 62 columns]

# %% [markdown]
# ### EO features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_features_eo.columns if 'EO' in num_col]
 
X = df_features_eo[numeric_cols]
Y = df_features_eo['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_estimators=170, n_jobs=-1, max_depth=5)
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=1)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 1 / 100
# Iteration: 2 / 100
# Iteration: 3 / 100
# Iteration: 4 / 100
# Iteration: 5 / 100
# Iteration: 6 / 100
# Iteration: 7 / 100
# Iteration: 8 / 100
# Iteration: 9 / 100
# Iteration: 10 / 100
# Iteration: 11 / 100
# Iteration: 12 / 100
# Iteration: 13 / 100
# Iteration: 14 / 100
# Iteration: 15 / 100
# Iteration: 16 / 100
# Iteration: 17 / 100
# Iteration: 18 / 100
# Iteration: 19 / 100
# Iteration: 20 / 100
# Iteration: 21 / 100
# Iteration: 22 / 100
# Iteration: 23 / 100
# Iteration: 24 / 100
# Iteration: 25 / 100
# Iteration: 26 / 100
# Iteration: 27 / 100
# Iteration: 28 / 100
# Iteration: 29 / 100
# Iteration: 30 / 100
# Iteration: 31 / 100
# Iteration: 32 / 100
# Iteration: 33 / 100
# Iteration: 34 / 100
# Iteration: 35 / 100
# Iteration: 36 / 100
# Iteration: 37 / 100
# Iteration: 38 / 100
# Iteration: 39 / 100
# Iteration: 40 / 100
# Iteration: 41 / 100
# Iteration: 42 / 100
# Iteration: 43 / 100
# Iteration: 44 / 100
# Iteration: 45 / 100
# Iteration: 46 / 100
# Iteration: 47 / 100
# Iteration: 48 / 100
# Iteration: 49 / 100
# Iteration: 50 / 100
# Iteration: 51 / 100
# Iteration: 52 / 100
# Iteration: 53 / 100
# Iteration: 54 / 100
# Iteration: 55 / 100
# Iteration: 56 / 100
# Iteration: 57 / 100
# Iteration: 58 / 100
# Iteration: 59 / 100
# Iteration: 60 / 100
# Iteration: 61 / 100
# Iteration: 62 / 100
# Iteration: 63 / 100
# Iteration: 64 / 100
# Iteration: 65 / 100
# Iteration: 66 / 100
# Iteration: 67 / 100
# Iteration: 68 / 100
# Iteration: 69 / 100
# Iteration: 70 / 100
# Iteration: 71 / 100
# Iteration: 72 / 100
# Iteration: 73 / 100
# Iteration: 74 / 100
# Iteration: 75 / 100
# Iteration: 76 / 100
# Iteration: 77 / 100
# Iteration: 78 / 100
# Iteration: 79 / 100
# Iteration: 80 / 100
# Iteration: 81 / 100
# Iteration: 82 / 100
# Iteration: 83 / 100
# Iteration: 84 / 100
# Iteration: 85 / 100
# Iteration: 86 / 100
# Iteration: 87 / 100
# Iteration: 88 / 100
# Iteration: 89 / 100
# Iteration: 90 / 100
# Iteration: 91 / 100
# Iteration: 92 / 100
# Iteration: 93 / 100
# Iteration: 94 / 100
# Iteration: 95 / 100
# Iteration: 96 / 100
# Iteration: 97 / 100
# Iteration: 98 / 100
# Iteration: 99 / 100
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	99
# Tentative: 	7
# Rejected: 	105

# %%
selected_columns = df_features_eo[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_feat_eo = df_features_eo[standard_columns]  # select the columns from the DataFrame
print(df_selected_feat_eo.shape)
df_selected_feat_eo.sample(5)
# Out:
# (2700, 102)
#                 ID  epoch diagnosis  EO_l_frontal_delta_skew  \
# 6933  sub-88068841     10   HEALTHY                -0.197953
# 666   sub-87969125      7       SMC                 0.032951
# 857   sub-87970345      6       SMC                -0.342508
# 1199  sub-87976773     12   HEALTHY                -0.687388
# 2977  sub-88028661      2      ADHD                -0.547852
#
#       EO_l_frontal_delta_kurt  EO_r_frontal_delta_mean  \
# 6933                -0.232924                -0.125440
# 666                  0.340450                -0.153825
# 857                  0.367209                -0.128005
# 1199                 1.291325                -0.127022
# 2977                 0.290638                -0.134493
#
#       EO_m_central_delta_mean  EO_r_central_delta_std  \
# 6933                -0.111258                0.390823
# 666                 -0.271177                0.402081
# 857                 -0.139156                0.399094
# 1199                -0.120564                0.375112
# 2977                -0.123947                0.413656
#
#       EO_r_central_delta_mean  EO_r_central_delta_median  ...  \
# 6933                -0.144331                  -0.146203  ...
# 666                 -0.190609                  -0.183459  ...
# 857                 -0.151797                  -0.153386  ...
# 1199                -0.135720                  -0.137548  ...
# 2977                -0.162710                  -0.164255  ...
#
#       EO_m_posterior_gamma_std  EO_m_posterior_gamma_mean  \
# 6933                  0.287532                  -0.086424
# 666                   0.272821                  -0.076283
# 857                   0.265838                  -0.074925
# 1199                  0.302442                  -0.090793
# 2977                  0.309155                  -0.108622
#
#       EO_m_posterior_gamma_median  EO_m_posterior_gamma_skew  \
# 6933                    -0.075811                  -0.539149
# 666                     -0.075875                  -0.603762
# 857                     -0.077636                  -0.448801
# 1199                    -0.092133                  -0.734105
# 2977                    -0.106410                  -0.120743
#
#       EO_m_posterior_gamma_kurt  EO_r_posterior_gamma_std  \
# 6933                   0.352333                  0.289671
# 666                    0.522994                  0.283451
# 857                    0.421761                  0.265867
# 1199                   0.664549                  0.271916
# 2977                   0.043035                  0.336005
#
#       EO_r_posterior_gamma_mean  EO_r_posterior_gamma_median  \
# 6933                  -0.087780                    -0.087915
# 666                   -0.080963                    -0.082509
# 857                   -0.072464                    -0.072326
# 1199                  -0.077775                    -0.075948
# 2977                  -0.131397                    -0.120089
#
#       EO_r_posterior_gamma_skew  EO_r_posterior_gamma_kurt
# 6933                  -0.500158                   0.252589
# 666                   -0.754849                   1.723200
# 857                   -0.618791                   0.566448
# 1199                  -0.501906                   0.473327
# 2977                  -0.149792                   0.313014
#
# [5 rows x 102 columns]

# %% [markdown]
# ### Merge selected ratio, EC, EO features

# %%
# Drop the 'ID', 'epoch', 'diagnosis' columns from the second and third dataframes for concatenation
df_selected_feat_eo = df_selected_feat_eo.drop(['ID', 'epoch', 'diagnosis'], axis=1)
df_selected_feat_ratio = df_selected_feat_ratio.drop(['ID', 'epoch', 'diagnosis'], axis=1)

# Concatenate the dataframes
df_selected_features = pd.concat([df_selected_feat_ec, df_selected_feat_eo, df_selected_feat_ratio], axis=1)
df_selected_features
# Out:
#                 ID  epoch diagnosis  EC_l_posterior_delta_std  \
# 24    sub-87964717      1       SMC                  0.360979
# 25    sub-87964717      2       SMC                  0.396142
# 26    sub-87964717      3       SMC                  0.360976
# 27    sub-87964717      4       SMC                  0.458912
# 28    sub-87964717      5       SMC                  0.336692
# ...            ...    ...       ...                       ...
# 7807  sub-88076717      8       OCD                  0.401744
# 7808  sub-88076717      9       OCD                  0.372481
# 7809  sub-88076717     10       OCD                  0.464772
# 7810  sub-88076717     11       OCD                  0.416722
# 7811  sub-88076717     12       OCD                  0.523907
#
#       EC_l_frontal_theta_std  EC_l_frontal_theta_mean  \
# 24                  0.296711                -0.103983
# 25                  0.320765                -0.101048
# 26                  0.383631                -0.142807
# 27                  0.400738                -0.190151
# 28                  0.344149                -0.130853
# ...                      ...                      ...
# 7807                0.398381                -0.153613
# 7808                0.280391                -0.083200
# 7809                0.394338                -0.156866
# 7810                0.321075                -0.114733
# 7811                0.536480                -0.345792
#
#       EC_l_frontal_theta_median  EC_m_frontal_theta_std  \
# 24                    -0.104952                0.316582
# 25                    -0.091661                0.319229
# 26                    -0.139421                0.369464
# 27                    -0.198076                0.349989
# 28                    -0.132630                0.345981
# ...                         ...                     ...
# 7807                  -0.153747                0.385733
# 7808                  -0.082427                0.269471
# 7809                  -0.157289                0.364809
# 7810                  -0.113885                0.355278
# 7811                  -0.345799                0.510306
#
#       EC_r_frontal_theta_std  EC_r_frontal_theta_mean  ...  \
# 24                  0.314024                -0.109632  ...
# 25                  0.345249                -0.117249  ...
# 26                  0.404183                -0.166141  ...
# 27                  0.383961                -0.168866  ...
# 28                  0.385940                -0.167488  ...
# ...                      ...                      ...  ...
# 7807                0.396440                -0.167367  ...
# 7808                0.308572                -0.107010  ...
# 7809                0.362061                -0.152433  ...
# 7810                0.385819                -0.157592  ...
# 7811                0.510743                -0.338060  ...
#
#       ratio_l_posterior_gamma_skew  ratio_m_posterior_gamma_std  \
# 24                        0.522167                     1.009346
# 25                        0.720480                     0.983948
# 26                        0.956565                     1.130790
# 27                        1.331098                     0.972647
# 28                        0.835716                     1.175073
# ...                            ...                          ...
# 7807                      1.016841                     0.950693
# 7808                      1.180789                     1.045766
# 7809                      0.856885                     0.983628
# 7810                      2.178256                     1.018119
# 7811                      4.375478                     0.978409
#
#       ratio_m_posterior_gamma_mean  ratio_m_posterior_gamma_median  \
# 24                        1.078347                        1.028052
# 25                        1.022707                        1.084144
# 26                        1.256831                        1.235856
# 27                        0.916448                        1.059041
# 28                        1.492219                        1.438212
# ...                            ...                             ...
# 7807                      0.876182                        0.853135
# 7808                      1.099941                        1.193314
# 7809                      0.994318                        1.048994
# 7810                      1.014035                        1.015445
# 7811                      0.934243                        1.070239
#
#       ratio_m_posterior_gamma_skew  ratio_m_posterior_gamma_kurt  \
# 24                        0.603866                      0.159593
# 25                        0.575195                      0.079641
# 26                        0.971040                      0.630136
# 27                        1.158384                      0.639208
# 28                        0.648777                      1.667125
# ...                            ...                           ...
# 7807                      1.312748                      2.115164
# 7808                      0.852539                      0.680275
# 7809                      0.816864                      0.843761
# 7810                      1.066978                      0.687766
# 7811                      1.172039                      0.299776
#
#       ratio_r_posterior_gamma_std  ratio_r_posterior_gamma_mean  \
# 24                       1.020543                      1.089969
# 25                       1.032616                      1.096335
# 26                       1.125305                      1.261261
# 27                       1.000264                      0.949167
# 28                       1.144547                      1.378300
# ...                           ...                           ...
# 7807                     0.976949                      0.895213
# 7808                     1.058189                      1.086473
# 7809                     0.975462                      0.960748
# 7810                     1.006964                      1.011169
# 7811                     1.026548                      0.983014
#
#       ratio_r_posterior_gamma_median  ratio_r_posterior_gamma_skew
# 24                          1.206395                      0.741274
# 25                          1.123558                      0.756438
# 26                          1.274927                      0.898000
# 27                          0.989528                      1.394617
# 28                          1.134033                      0.823934
# ...                              ...                           ...
# 7807                        1.004927                      1.681671
# 7808                        1.128326                      1.366124
# 7809                        0.960796                      1.100767
# 7810                        0.984383                      1.155833
# 7811                        0.933590                      1.495373
#
# [2700 rows x 201 columns]

# %%
df_selected_features.to_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_selected_stat_features.pkl')

# %% [markdown]
# # 2. statistical TFR + connectivity features

# %%
df_conn_features = pd.read_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_connectivity_features.pkl')
df_features = df_features.dropna(subset=['diagnosis'])

# %%
# subsample dataset to rebalance dataset
df_conn_subsample = df_conn_features[(df_conn_features['ID'].isin(df_ids_subsample_index))] # use same sampled IDs from earlier for the stat features
df_conn_subsample['diagnosis'].value_counts()
# Out:
# diagnosis
# SMC        540
# HEALTHY    540
# MDD        540
# ADHD       540
# OCD        540
# Name: count, dtype: int64

# %%
# merge stat and conn features and store for later training of GCNs
df_stat_conn_features = pd.merge(df_stat_subsample, df_conn_subsample.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
# drop age and gender columns
df_stat_conn_features = df_stat_conn_features.drop(columns=['age', 'gender'])
df_stat_conn_features.to_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_stat_conn_features.pkl')
print(df_stat_conn_features.shape)
df_stat_conn_features.sample(3)
# Out:
# (2700, 1218)
#                 ID diagnosis  epoch  EO_l_frontal_delta_std  \
# 85    sub-87967061       SMC      2                0.526946
# 569   sub-87974665   HEALTHY      6                0.337011
# 1434  sub-88042661      ADHD      7                0.384420
#
#       EO_l_frontal_delta_mean  EO_l_frontal_delta_median  \
# 85                  -0.321490                  -0.329293
# 569                 -0.108363                  -0.111538
# 1434                -0.153788                  -0.142895
#
#       EO_l_frontal_delta_skew  EO_l_frontal_delta_kurt  \
# 85                   0.138598                -0.040187
# 569                 -0.824303                 0.685945
# 1434                -0.302585                -0.351258
#
#       EO_m_frontal_delta_std  EO_m_frontal_delta_mean  ...  \
# 85                  0.616136                -0.543819  ...
# 569                 0.333057                -0.108726  ...
# 1434                0.382060                -0.149558  ...
#
#       ratio_gamma_m_central-r_central  ratio_gamma_m_central-l_posterior  \
# 85                           1.051912                           1.021816
# 569                          0.991200                           1.007697
# 1434                         1.022694                           1.095642
#
#       ratio_gamma_m_central-m_posterior  ratio_gamma_m_central-r_posterior  \
# 85                             1.007011                           1.000890
# 569                            0.985133                           0.979130
# 1434                           1.085537                           1.088894
#
#       ratio_gamma_r_central-l_posterior  ratio_gamma_r_central-m_posterior  \
# 85                             1.077221                           1.056034
# 569                            1.050544                           1.046434
# 1434                           1.040364                           1.024484
#
#       ratio_gamma_r_central-r_posterior  ratio_gamma_l_posterior-m_posterior  \
# 85                             1.042243                             1.034750
# 569                            1.034819                             1.031872
# 1434                           1.028787                             1.060162
#
#       ratio_gamma_l_posterior-r_posterior  ratio_gamma_m_posterior-r_posterior
# 85                               1.038238                             1.013438
# 569                              1.076038                             1.059462
# 1434                             1.074329                             1.057202
#
# [3 rows x 1218 columns]

# %%
# create 3 feature sets [EC, EO, ratio] with column ['ID', 'age', 'gender', 'diagnosis', 'epoch']
df_conn_features_ec = df_conn_subsample[df_conn_features.columns[~(df_conn_subsample.columns.str.startswith('EO') | df_conn_subsample.columns.str.startswith('ratio'))]]
df_conn_features_eo = df_conn_subsample[df_conn_features.columns[~(df_conn_subsample.columns.str.startswith('EC') | df_conn_subsample.columns.str.startswith('ratio'))]]
df_conn_features_ratio = df_conn_subsample[df_conn_features.columns[~(df_conn_subsample.columns.str.startswith('EC') | df_conn_subsample.columns.str.startswith('EO'))]]

# %%
# concat connectivity features with stat features
df_stat_conn_features_ec = pd.merge(df_features_ec, df_conn_features_ec.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
df_stat_conn_features_eo = pd.merge(df_features_eo, df_conn_features_eo.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
df_stat_conn_features_ratio = pd.merge(df_features_ratio, df_conn_features_ratio.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
print(df_stat_conn_features_ec.shape)
# Out:
# (2700, 410)

# %% [markdown]
# ### Ratio features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_stat_conn_features_ratio.columns if 'ratio' in num_col]
 
X = df_stat_conn_features_ratio[numeric_cols]
Y = df_stat_conn_features_ratio['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_estimators=200, n_jobs=-1, max_depth=15)
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=1)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 1 / 100
# Iteration: 2 / 100
# Iteration: 3 / 100
# Iteration: 4 / 100
# Iteration: 5 / 100
# Iteration: 6 / 100
# Iteration: 7 / 100
# Iteration: 8 / 100
# Iteration: 9 / 100
# Iteration: 10 / 100
# Iteration: 11 / 100
# Iteration: 12 / 100
# Iteration: 13 / 100
# Iteration: 14 / 100
# Iteration: 15 / 100
# Iteration: 16 / 100
# Iteration: 17 / 100
# Iteration: 18 / 100
# Iteration: 19 / 100
# Iteration: 20 / 100
# Iteration: 21 / 100
# Iteration: 22 / 100
# Iteration: 23 / 100
# Iteration: 24 / 100
# Iteration: 25 / 100
# Iteration: 26 / 100
# Iteration: 27 / 100
# Iteration: 28 / 100
# Iteration: 29 / 100
# Iteration: 30 / 100
# Iteration: 31 / 100
# Iteration: 32 / 100
# Iteration: 33 / 100
# Iteration: 34 / 100
# Iteration: 35 / 100
# Iteration: 36 / 100
# Iteration: 37 / 100
# Iteration: 38 / 100
# Iteration: 39 / 100
# Iteration: 40 / 100
# Iteration: 41 / 100
# Iteration: 42 / 100
# Iteration: 43 / 100
# Iteration: 44 / 100
# Iteration: 45 / 100
# Iteration: 46 / 100
# Iteration: 47 / 100
# Iteration: 48 / 100
# Iteration: 49 / 100
# Iteration: 50 / 100
# Iteration: 51 / 100
# Iteration: 52 / 100
# Iteration: 53 / 100
# Iteration: 54 / 100
# Iteration: 55 / 100
# Iteration: 56 / 100
# Iteration: 57 / 100
# Iteration: 58 / 100
# Iteration: 59 / 100
# Iteration: 60 / 100
# Iteration: 61 / 100
# Iteration: 62 / 100
# Iteration: 63 / 100
# Iteration: 64 / 100
# Iteration: 65 / 100
# Iteration: 66 / 100
# Iteration: 67 / 100
# Iteration: 68 / 100
# Iteration: 69 / 100
# Iteration: 70 / 100
# Iteration: 71 / 100
# Iteration: 72 / 100
# Iteration: 73 / 100
# Iteration: 74 / 100
# Iteration: 75 / 100
# Iteration: 76 / 100
# Iteration: 77 / 100
# Iteration: 78 / 100
# Iteration: 79 / 100
# Iteration: 80 / 100
# Iteration: 81 / 100
# Iteration: 82 / 100
# Iteration: 83 / 100
# Iteration: 84 / 100
# Iteration: 85 / 100
# Iteration: 86 / 100
# Iteration: 87 / 100
# Iteration: 88 / 100
# Iteration: 89 / 100
# Iteration: 90 / 100
# Iteration: 91 / 100
# Iteration: 92 / 100
# Iteration: 93 / 100
# Iteration: 94 / 100
# Iteration: 95 / 100
# Iteration: 96 / 100
# Iteration: 97 / 100
# Iteration: 98 / 100
# Iteration: 99 / 100
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	185
# Tentative: 	14
# Rejected: 	202

# %%
selected_columns = df_stat_conn_features_ratio[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_stat_conn_feat_ratio = df_stat_conn_features_ratio[standard_columns]  # select the columns from the DataFrame
print(df_selected_stat_conn_feat_ratio.shape)
df_selected_stat_conn_feat_ratio.sample(5)
# Out:
# (2700, 188)
#                 ID  epoch diagnosis  ratio_l_frontal_delta_skew  \
# 2584  sub-88073797      5       MDD                    1.734636
# 1618  sub-88048413     11       OCD                    1.764382
# 1697  sub-88051073      6   HEALTHY                   -0.923252
# 2433  sub-88068797     10      ADHD                    2.051265
# 470   sub-87970969      3       SMC                   -0.216021
#
#       ratio_r_central_theta_std  ratio_r_central_theta_median  \
# 2584                   0.845964                      0.701163
# 1618                   1.141451                      1.505451
# 1697                   0.800433                      0.684456
# 2433                   0.874699                      0.836828
# 470                    0.929585                      0.672073
#
#       ratio_m_posterior_theta_std  ratio_m_posterior_theta_skew  \
# 2584                     0.926052                      1.407399
# 1618                     1.146409                      0.680985
# 1697                     0.817995                     -3.058665
# 2433                     0.998416                      0.352311
# 470                      0.755853                    -15.893336
#
#       ratio_r_posterior_theta_std  ratio_r_posterior_theta_median  ...  \
# 2584                     0.958076                        0.881047  ...
# 1618                     1.174552                        1.433504  ...
# 1697                     0.787956                        0.692607  ...
# 2433                     1.060356                        1.101439  ...
# 470                      0.824979                        0.576558  ...
#
#       ratio_gamma_m_central-r_central  ratio_gamma_m_central-l_posterior  \
# 2584                         1.068738                           1.005128
# 1618                         1.101121                           1.089355
# 1697                         1.112452                           1.014360
# 2433                         1.039875                           1.094727
# 470                          0.997913                           0.990705
#
#       ratio_gamma_m_central-m_posterior  ratio_gamma_m_central-r_posterior  \
# 2584                           1.048565                           1.049145
# 1618                           1.066655                           1.089460
# 1697                           1.030111                           1.022473
# 2433                           1.090382                           1.096736
# 470                            1.003559                           1.008891
#
#       ratio_gamma_r_central-l_posterior  ratio_gamma_r_central-m_posterior  \
# 2584                           1.032499                           1.061583
# 1618                           1.178309                           1.147828
# 1697                           1.057986                           1.079725
# 2433                           1.083691                           1.053736
# 470                            0.945486                           0.988112
#
#       ratio_gamma_r_central-r_posterior  ratio_gamma_l_posterior-m_posterior  \
# 2584                           1.043382                             1.001597
# 1618                           1.117850                             1.040817
# 1697                           1.030821                             1.056365
# 2433                           1.053583                             1.060015
# 470                            0.996087                             0.996193
#
#       ratio_gamma_l_posterior-r_posterior  ratio_gamma_m_posterior-r_posterior
# 2584                             0.992954                             1.014573
# 1618                             1.090683                             1.072821
# 1697                             1.019626                             1.049995
# 2433                             1.069017                             1.061576
# 470                              0.969387                             0.996419
#
# [5 rows x 188 columns]

# %% [markdown]
# ### EC features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_stat_conn_features_ec.columns if 'EC' in num_col]
 
X = df_stat_conn_features_ec[numeric_cols]
Y = df_stat_conn_features_ec['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_estimators=185, n_jobs=-1, max_depth=20)
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=1)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 1 / 100
# Iteration: 2 / 100
# Iteration: 3 / 100
# Iteration: 4 / 100
# Iteration: 5 / 100
# Iteration: 6 / 100
# Iteration: 7 / 100
# Iteration: 8 / 100
# Iteration: 9 / 100
# Iteration: 10 / 100
# Iteration: 11 / 100
# Iteration: 12 / 100
# Iteration: 13 / 100
# Iteration: 14 / 100
# Iteration: 15 / 100
# Iteration: 16 / 100
# Iteration: 17 / 100
# Iteration: 18 / 100
# Iteration: 19 / 100
# Iteration: 20 / 100
# Iteration: 21 / 100
# Iteration: 22 / 100
# Iteration: 23 / 100
# Iteration: 24 / 100
# Iteration: 25 / 100
# Iteration: 26 / 100
# Iteration: 27 / 100
# Iteration: 28 / 100
# Iteration: 29 / 100
# Iteration: 30 / 100
# Iteration: 31 / 100
# Iteration: 32 / 100
# Iteration: 33 / 100
# Iteration: 34 / 100
# Iteration: 35 / 100
# Iteration: 36 / 100
# Iteration: 37 / 100
# Iteration: 38 / 100
# Iteration: 39 / 100
# Iteration: 40 / 100
# Iteration: 41 / 100
# Iteration: 42 / 100
# Iteration: 43 / 100
# Iteration: 44 / 100
# Iteration: 45 / 100
# Iteration: 46 / 100
# Iteration: 47 / 100
# Iteration: 48 / 100
# Iteration: 49 / 100
# Iteration: 50 / 100
# Iteration: 51 / 100
# Iteration: 52 / 100
# Iteration: 53 / 100
# Iteration: 54 / 100
# Iteration: 55 / 100
# Iteration: 56 / 100
# Iteration: 57 / 100
# Iteration: 58 / 100
# Iteration: 59 / 100
# Iteration: 60 / 100
# Iteration: 61 / 100
# Iteration: 62 / 100
# Iteration: 63 / 100
# Iteration: 64 / 100
# Iteration: 65 / 100
# Iteration: 66 / 100
# Iteration: 67 / 100
# Iteration: 68 / 100
# Iteration: 69 / 100
# Iteration: 70 / 100
# Iteration: 71 / 100
# Iteration: 72 / 100
# Iteration: 73 / 100
# Iteration: 74 / 100
# Iteration: 75 / 100
# Iteration: 76 / 100
# Iteration: 77 / 100
# Iteration: 78 / 100
# Iteration: 79 / 100
# Iteration: 80 / 100
# Iteration: 81 / 100
# Iteration: 82 / 100
# Iteration: 83 / 100
# Iteration: 84 / 100
# Iteration: 85 / 100
# Iteration: 86 / 100
# Iteration: 87 / 100
# Iteration: 88 / 100
# Iteration: 89 / 100
# Iteration: 90 / 100
# Iteration: 91 / 100
# Iteration: 92 / 100
# Iteration: 93 / 100
# Iteration: 94 / 100
# Iteration: 95 / 100
# Iteration: 96 / 100
# Iteration: 97 / 100
# Iteration: 98 / 100
# Iteration: 99 / 100
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	272
# Tentative: 	10
# Rejected: 	114

# %%
selected_columns = df_stat_conn_features_ec[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_stat_conn_feat_ec = df_stat_conn_features_ec[standard_columns]  # select the columns from the DataFrame
print(df_selected_stat_conn_feat_ec.shape)
df_selected_stat_conn_feat_ec.sample(5)
# Out:
# (2700, 275)
#                 ID  epoch diagnosis  EC_r_central_delta_std  \
# 1899  sub-88054937      4       OCD                0.332098
# 793   sub-87980417      2   HEALTHY                0.355726
# 512   sub-87971197      9       SMC                0.414198
# 2093  sub-88059397      6   HEALTHY                0.346646
# 590   sub-87974841      3   HEALTHY                0.399027
#
#       EC_r_central_delta_mean  EC_r_central_delta_median  \
# 1899                -0.122867                  -0.113763
# 793                 -0.131721                  -0.128410
# 512                 -0.167084                  -0.160148
# 2093                -0.127832                  -0.125848
# 590                 -0.156863                  -0.144610
#
#       EC_l_frontal_theta_std  EC_l_frontal_theta_mean  \
# 1899                0.328039                -0.111721
# 793                 0.367791                -0.157296
# 512                 0.387119                -0.194502
# 2093                0.358515                -0.131966
# 590                 0.301474                -0.094987
#
#       EC_l_frontal_theta_median  EC_m_frontal_theta_std  ...  \
# 1899                  -0.108884                0.322662  ...
# 793                   -0.160873                0.381967  ...
# 512                   -0.183695                0.395064  ...
# 2093                  -0.130152                0.336782  ...
# 590                   -0.096058                0.251270  ...
#
#       EC_gamma_m_central-r_central  EC_gamma_m_central-l_posterior  \
# 1899                      0.729098                        0.719448
# 793                       0.796595                        0.761514
# 512                       0.728360                        0.675939
# 2093                      0.784685                        0.697352
# 590                       0.775076                        0.764817
#
#       EC_gamma_m_central-m_posterior  EC_gamma_m_central-r_posterior  \
# 1899                        0.734877                        0.709100
# 793                         0.750052                        0.743671
# 512                         0.703368                        0.681176
# 2093                        0.745172                        0.707320
# 590                         0.751841                        0.756274
#
#       EC_gamma_r_central-l_posterior  EC_gamma_r_central-m_posterior  \
# 1899                        0.672243                        0.699778
# 793                         0.719313                        0.736035
# 512                         0.581422                        0.633229
# 2093                        0.668015                        0.728186
# 590                         0.716758                        0.741123
#
#       EC_gamma_r_central-r_posterior  EC_gamma_l_posterior-m_posterior  \
# 1899                        0.726153                          0.778882
# 793                         0.772624                          0.783369
# 512                         0.716224                          0.758735
# 2093                        0.752003                          0.772532
# 590                         0.811943                          0.777369
#
#       EC_gamma_l_posterior-r_posterior  EC_gamma_m_posterior-r_posterior
# 1899                          0.725873                          0.771979
# 793                           0.749037                          0.765651
# 512                           0.663426                          0.728528
# 2093                          0.708964                          0.771122
# 590                           0.768977                          0.776461
#
# [5 rows x 275 columns]

# %% [markdown]
# ### EO features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_stat_conn_features_eo.columns if 'EO' in num_col]
 
X = df_stat_conn_features_eo[numeric_cols]
Y = df_stat_conn_features_eo['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_estimators=200, n_jobs=-1, max_depth=20)
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=1)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 1 / 100
# Iteration: 2 / 100
# Iteration: 3 / 100
# Iteration: 4 / 100
# Iteration: 5 / 100
# Iteration: 6 / 100
# Iteration: 7 / 100
# Iteration: 8 / 100
# Iteration: 9 / 100
# Iteration: 10 / 100
# Iteration: 11 / 100
# Iteration: 12 / 100
# Iteration: 13 / 100
# Iteration: 14 / 100
# Iteration: 15 / 100
# Iteration: 16 / 100
# Iteration: 17 / 100
# Iteration: 18 / 100
# Iteration: 19 / 100
# Iteration: 20 / 100
# Iteration: 21 / 100
# Iteration: 22 / 100
# Iteration: 23 / 100
# Iteration: 24 / 100
# Iteration: 25 / 100
# Iteration: 26 / 100
# Iteration: 27 / 100
# Iteration: 28 / 100
# Iteration: 29 / 100
# Iteration: 30 / 100
# Iteration: 31 / 100
# Iteration: 32 / 100
# Iteration: 33 / 100
# Iteration: 34 / 100
# Iteration: 35 / 100
# Iteration: 36 / 100
# Iteration: 37 / 100
# Iteration: 38 / 100
# Iteration: 39 / 100
# Iteration: 40 / 100
# Iteration: 41 / 100
# Iteration: 42 / 100
# Iteration: 43 / 100
# Iteration: 44 / 100
# Iteration: 45 / 100
# Iteration: 46 / 100
# Iteration: 47 / 100
# Iteration: 48 / 100
# Iteration: 49 / 100
# Iteration: 50 / 100
# Iteration: 51 / 100
# Iteration: 52 / 100
# Iteration: 53 / 100
# Iteration: 54 / 100
# Iteration: 55 / 100
# Iteration: 56 / 100
# Iteration: 57 / 100
# Iteration: 58 / 100
# Iteration: 59 / 100
# Iteration: 60 / 100
# Iteration: 61 / 100
# Iteration: 62 / 100
# Iteration: 63 / 100
# Iteration: 64 / 100
# Iteration: 65 / 100
# Iteration: 66 / 100
# Iteration: 67 / 100
# Iteration: 68 / 100
# Iteration: 69 / 100
# Iteration: 70 / 100
# Iteration: 71 / 100
# Iteration: 72 / 100
# Iteration: 73 / 100
# Iteration: 74 / 100
# Iteration: 75 / 100
# Iteration: 76 / 100
# Iteration: 77 / 100
# Iteration: 78 / 100
# Iteration: 79 / 100
# Iteration: 80 / 100
# Iteration: 81 / 100
# Iteration: 82 / 100
# Iteration: 83 / 100
# Iteration: 84 / 100
# Iteration: 85 / 100
# Iteration: 86 / 100
# Iteration: 87 / 100
# Iteration: 88 / 100
# Iteration: 89 / 100
# Iteration: 90 / 100
# Iteration: 91 / 100
# Iteration: 92 / 100
# Iteration: 93 / 100
# Iteration: 94 / 100
# Iteration: 95 / 100
# Iteration: 96 / 100
# Iteration: 97 / 100
# Iteration: 98 / 100
# Iteration: 99 / 100
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	273
# Tentative: 	10
# Rejected: 	116

# %%
selected_columns = df_stat_conn_features_eo[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_stat_conn_feat_eo = df_stat_conn_features_eo[standard_columns]  # select the columns from the DataFrame
print(df_selected_stat_conn_feat_eo.shape)
df_selected_stat_conn_feat_eo.sample(5)
# Out:
# (2700, 276)
#                 ID  epoch diagnosis  EO_l_frontal_theta_std  \
# 2564  sub-88073521      9      ADHD                0.369040
# 44    sub-87966473      9       SMC                0.330724
# 97    sub-87967325      2       SMC                0.290488
# 302   sub-87969125      3       SMC                0.361798
# 1352  sub-88039057      9       MDD                0.287262
#
#       EO_l_frontal_theta_mean  EO_r_frontal_theta_std  \
# 2564                -0.130609                0.333611
# 44                  -0.100442                0.298581
# 97                  -0.088545                0.324689
# 302                 -0.127621                0.361973
# 1352                -0.090314                0.280382
#
#       EO_r_frontal_theta_mean  EO_r_frontal_theta_median  \
# 2564                -0.103903                  -0.108409
# 44                  -0.095506                  -0.097355
# 97                  -0.110936                  -0.106055
# 302                 -0.130708                  -0.133362
# 1352                -0.083377                  -0.081038
#
#       EO_l_central_theta_std  EO_l_central_theta_mean  ...  \
# 2564                0.300973                -0.089251  ...
# 44                  0.345872                -0.130806  ...
# 97                  0.295522                -0.090128  ...
# 302                 0.334124                -0.130810  ...
# 1352                0.288889                -0.096891  ...
#
#       EO_gamma_m_central-r_central  EO_gamma_m_central-l_posterior  \
# 2564                      0.926426                        0.893795
# 44                        0.776750                        0.728496
# 97                        0.857844                        0.830164
# 302                       0.757515                        0.729445
# 1352                      0.811852                        0.788490
#
#       EO_gamma_m_central-m_posterior  EO_gamma_m_central-r_posterior  \
# 2564                        0.904600                        0.896193
# 44                          0.754226                        0.719271
# 97                          0.842875                        0.838960
# 302                         0.759878                        0.723909
# 1352                        0.810385                        0.761601
#
#       EO_gamma_r_central-l_posterior  EO_gamma_r_central-m_posterior  \
# 2564                        0.882448                        0.898397
# 44                          0.702038                        0.747659
# 97                          0.792319                        0.824158
# 302                         0.668298                        0.710833
# 1352                        0.775973                        0.805451
#
#       EO_gamma_r_central-r_posterior  EO_gamma_l_posterior-m_posterior  \
# 2564                        0.906914                          0.918846
# 44                          0.781849                          0.805680
# 97                          0.865513                          0.867315
# 302                         0.752270                          0.816734
# 1352                        0.821950                          0.821838
#
#       EO_gamma_l_posterior-r_posterior  EO_gamma_m_posterior-r_posterior
# 2564                          0.907781                          0.919347
# 44                            0.743799                          0.807446
# 97                            0.842301                          0.871122
# 302                           0.733191                          0.789267
# 1352                          0.779955                          0.811165
#
# [5 rows x 276 columns]

# %% [markdown]
# ### Merge selected ratio, EC, EO features

# %%
# Drop the 'ID', 'epoch', 'diagnosis' columns from the second and third dataframes for concatenation
df_selected_stat_conn_feat_eo = df_selected_stat_conn_feat_eo.drop(['ID', 'epoch', 'diagnosis'], axis=1)
df_selected_stat_conn_feat_ratio = df_selected_stat_conn_feat_ratio.drop(['ID', 'epoch', 'diagnosis'], axis=1)

# Concatenate the dataframes
df_selected_stat_conn_features = pd.concat([df_selected_stat_conn_feat_ec, df_selected_stat_conn_feat_eo, df_selected_stat_conn_feat_ratio], axis=1)
df_selected_stat_conn_features
# Out:
#                 ID  epoch diagnosis  EC_r_central_delta_std  \
# 0     sub-87964717      1       SMC                0.396625
# 1     sub-87964717      2       SMC                0.394062
# 2     sub-87964717      3       SMC                0.410010
# 3     sub-87964717      4       SMC                0.469550
# 4     sub-87964717      5       SMC                0.355055
# ...            ...    ...       ...                     ...
# 2695  sub-88076717      8       OCD                0.474489
# 2696  sub-88076717      9       OCD                0.351207
# 2697  sub-88076717     10       OCD                0.367805
# 2698  sub-88076717     11       OCD                0.420107
# 2699  sub-88076717     12       OCD                0.490927
#
#       EC_r_central_delta_mean  EC_r_central_delta_median  \
# 0                   -0.174628                  -0.177734
# 1                   -0.158610                  -0.156196
# 2                   -0.196367                  -0.187606
# 3                   -0.230582                  -0.225645
# 4                   -0.131668                  -0.134253
# ...                       ...                        ...
# 2695                -0.223597                  -0.222273
# 2696                -0.151888                  -0.148171
# 2697                -0.150474                  -0.144268
# 2698                -0.182264                  -0.170567
# 2699                -0.299498                  -0.297503
#
#       EC_l_frontal_theta_std  EC_l_frontal_theta_mean  \
# 0                   0.296711                -0.103983
# 1                   0.320765                -0.101048
# 2                   0.383631                -0.142807
# 3                   0.400738                -0.190151
# 4                   0.344149                -0.130853
# ...                      ...                      ...
# 2695                0.398381                -0.153613
# 2696                0.280391                -0.083200
# 2697                0.394338                -0.156866
# 2698                0.321075                -0.114733
# 2699                0.536480                -0.345792
#
#       EC_l_frontal_theta_median  EC_m_frontal_theta_std  ...  \
# 0                     -0.104952                0.316582  ...
# 1                     -0.091661                0.319229  ...
# 2                     -0.139421                0.369464  ...
# 3                     -0.198076                0.349989  ...
# 4                     -0.132630                0.345981  ...
# ...                         ...                     ...  ...
# 2695                  -0.153747                0.385733  ...
# 2696                  -0.082427                0.269471  ...
# 2697                  -0.157289                0.364809  ...
# 2698                  -0.113885                0.355278  ...
# 2699                  -0.345799                0.510306  ...
#
#       ratio_gamma_m_central-r_central  ratio_gamma_m_central-l_posterior  \
# 0                            0.983375                           0.982205
# 1                            0.951962                           0.999252
# 2                            1.007210                           1.003786
# 3                            0.987823                           1.029448
# 4                            1.042865                           1.021432
# ...                               ...                                ...
# 2695                         1.050150                           1.093657
# 2696                         1.095957                           1.144254
# 2697                         1.059378                           1.114762
# 2698                         1.048840                           1.054833
# 2699                         1.069163                           1.087860
#
#       ratio_gamma_m_central-m_posterior  ratio_gamma_m_central-r_posterior  \
# 0                              0.973501                           0.957588
# 1                              0.989583                           0.969516
# 2                              0.997969                           0.981911
# 3                              1.023404                           1.011507
# 4                              1.011774                           1.023296
# ...                                 ...                                ...
# 2695                           1.076960                           1.060231
# 2696                           1.111357                           1.115784
# 2697                           1.086334                           1.146659
# 2698                           1.083075                           1.104262
# 2699                           1.099526                           1.116985
#
#       ratio_gamma_r_central-l_posterior  ratio_gamma_r_central-m_posterior  \
# 0                              0.965101                           0.975819
# 1                              0.930350                           0.938956
# 2                              1.021233                           1.027465
# 3                              0.995531                           1.025771
# 4                              1.010551                           1.047893
# ...                                 ...                                ...
# 2695                           1.153361                           1.122004
# 2696                           1.178204                           1.139658
# 2697                           1.183257                           1.136850
# 2698                           1.037404                           1.049401
# 2699                           1.091360                           1.102320
#
#       ratio_gamma_r_central-r_posterior  ratio_gamma_l_posterior-m_posterior  \
# 0                              0.977929                             0.973242
# 1                              0.968311                             0.982378
# 2                              1.020506                             0.977939
# 3                              1.032580                             0.990293
# 4                              1.041591                             1.019603
# ...                                 ...                                  ...
# 2695                           1.055451                             1.082843
# 2696                           1.100500                             1.109036
# 2697                           1.136010                             1.085056
# 2698                           1.063298                             1.047424
# 2699                           1.098257                             1.062940
#
#       ratio_gamma_l_posterior-r_posterior  ratio_gamma_m_posterior-r_posterior
# 0                                0.955600                             0.985688
# 1                                0.955147                             0.965178
# 2                                0.966586                             0.985563
# 3                                0.982638                             1.006213
# 4                                1.005809                             1.024247
# ...                                   ...                                  ...
# 2695                             1.109466                             1.075791
# 2696                             1.142876                             1.095822
# 2697                             1.136426                             1.107047
# 2698                             1.064664                             1.070277
# 2699                             1.066860                             1.070410
#
# [2700 rows x 733 columns]

# %%
df_selected_stat_conn_features.to_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_selected_stat_conn_features.pkl')
