# %% [markdown]
# ## AIM: reduce dimensionality by feature selection with BORUTA

# %% [markdown]
# A seperate BORUTA will be performed for each feature set (6 total):
# 1. statistical TFR features (for ratio, EC, and EO)
# 2. stat TFR features + connectivity features (for ratio, EC, and EO)
#
# n_estimates & max_depth for RFs in BORUTA were determined for each feature set in 'boruta_hyperparameter_tuning.ipynb' located in the 'background_notebooks' subdir

# %%
from boruta import BorutaPy
import pandas as pd
import numpy as np
import mne
import pickle
import os

from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # 1. statistical TFR features

# %%
df_features = pd.read_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_stat_features.pkl')
df_features['age'] = df_features['age'].round().astype('Int32') # round age to nearest year and convert to int
df_features = df_features.dropna(subset=['diagnosis'])
df_features.sample(7)
# Out:
#                 ID  age  gender diagnosis  epoch  EO_l_frontal_delta_std  \
# 7273  sub-88071949   60     1.0       MDD      2                0.168680
# 3752  sub-88039325   48     1.0       MDD      9                0.186247
# 5765  sub-88057869   28     0.0   HEALTHY      6                0.121956
# 3099  sub-88029833   46     1.0       MDD      4                0.182030
# 2871  sub-88027129   63     0.0       MDD      4                0.127204
# 7143  sub-88070285   61     0.0       MDD      4                0.163312
# 3240  sub-88032753   13     1.0      ADHD      1                0.131222
#
#       EO_l_frontal_delta_mean  EO_l_frontal_delta_median  \
# 7273                      0.2                        0.2
# 3752                      0.2                        0.2
# 5765                      0.2                        0.2
# 3099                      0.2                        0.2
# 2871                      0.2                        0.2
# 7143                      0.2                        0.2
# 3240                      0.2                        0.2
#
#       EO_l_frontal_delta_skew  EO_l_frontal_delta_kurt  ...  \
# 7273                 3.116735                11.511835  ...
# 3752                 2.052963                 4.232184  ...
# 5765                 1.208803                 1.986963  ...
# 3099                 2.785748                10.101949  ...
# 2871                 0.701024                -0.313077  ...
# 7143                 1.471972                 1.770233  ...
# 3240                 1.093803                 1.323133  ...
#
#       ratio_m_posterior_gamma_std  ratio_m_posterior_gamma_mean  \
# 7273                     0.311999                      1.047310
# 3752                     0.425491                      1.081598
# 5765                     0.302155                      1.040452
# 3099                     0.457252                      1.064678
# 2871                     0.307858                      1.050595
# 7143                     0.653432                      1.160359
# 3240                     0.490617                      1.118036
#
#       ratio_m_posterior_gamma_median  ratio_m_posterior_gamma_skew  \
# 7273                        1.000477                      1.088472
# 3752                        1.007331                      1.667232
# 5765                        1.013240                      0.385636
# 3099                        0.960730                      1.127410
# 2871                        0.990633                      1.001896
# 7143                        1.057652                      1.637996
# 3240                        0.985654                      1.292537
#
#       ratio_m_posterior_gamma_kurt  ratio_r_posterior_gamma_std  \
# 7273                      1.791012                     0.414166
# 3752                      4.069520                     0.317394
# 5765                     -0.392551                     0.311762
# 3099                      1.623219                     0.411469
# 2871                      1.480925                     0.335147
# 7143                      3.830987                     0.567746
# 3240                      1.350926                     0.496779
#
#       ratio_r_posterior_gamma_mean  ratio_r_posterior_gamma_median  \
# 7273                      1.068323                        0.953492
# 3752                      1.055687                        1.035326
# 5765                      1.043178                        1.035781
# 3099                      1.059645                        1.007971
# 2871                      1.056289                        1.006957
# 7143                      1.128301                        1.050633
# 3240                      1.117683                        1.004234
#
#       ratio_r_posterior_gamma_skew  ratio_r_posterior_gamma_kurt
# 7273                      1.582792                      2.383129
# 3752                      1.099747                      2.318430
# 5765                      0.498187                     -0.031483
# 3099                      0.769105                      0.212510
# 2871                      0.924052                      1.017339
# 7143                      1.348286                      2.713012
# 3240                      1.280876                      2.074884
#
# [7 rows x 680 columns]

# %% [markdown]
# Subsampling dataset here to rebalance dataset. Possibly would have been more efficient to perform before feature extraction, however I already extracted features of the full sample, which allows me to not have to recompute features if we ever change this subsampling step. Additionally, for a still unknown reason, during feature extraction some participants data seem to be lossed, possibly due to the marked 'BAD' files from preprocessing.

# %%
# subsample dataset to rebalance dataset
df_ids = df_features[(df_features['epoch'] == 1)] # select only first epoch to make sure we subsample from participants, and not from epochs
df_ids_subsample = df_ids.groupby('diagnosis').sample(45, random_state=42) # sample 45 participants per diagnosis (which is the max for OCD)
df_ids_subsample_index = df_ids_subsample['ID'].tolist()
df_stat_subsample = df_features[(df_features['ID'].isin(df_ids_subsample_index))]
df_stat_subsample['diagnosis'].value_counts()
# Out:
# diagnosis
# SMC        540
# HEALTHY    540
# MDD        540
# ADHD       540
# OCD        540
# Name: count, dtype: int64

# %%
# create 3 feature sets [EC, EO, ratio] with column ['ID', 'age', 'gender', 'diagnosis', 'epoch']
df_features_ec = df_stat_subsample[df_features.columns[~(df_stat_subsample.columns.str.startswith('EO') | df_stat_subsample.columns.str.startswith('ratio'))]]
df_features_eo = df_stat_subsample[df_features.columns[~(df_stat_subsample.columns.str.startswith('EC') | df_stat_subsample.columns.str.startswith('ratio'))]]
df_features_ratio = df_stat_subsample[df_features.columns[~(df_stat_subsample.columns.str.startswith('EC') | df_stat_subsample.columns.str.startswith('EO'))]]

# %% [markdown]
# ### Ratio features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_features_ratio.columns if 'ratio' in num_col]
 
X = df_features_ratio[numeric_cols]
Y = df_features_ratio['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=5, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=3, n_estimators=135)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	44
# Tentative: 	75
# Rejected: 	106
# Iteration: 	9 / 100
# Confirmed: 	44
# Tentative: 	75
# Rejected: 	106
# Iteration: 	10 / 100
# Confirmed: 	44
# Tentative: 	75
# Rejected: 	106
# Iteration: 	11 / 100
# Confirmed: 	44
# Tentative: 	75
# Rejected: 	106
# Iteration: 	12 / 100
# Confirmed: 	50
# Tentative: 	56
# Rejected: 	119
# Iteration: 	13 / 100
# Confirmed: 	50
# Tentative: 	56
# Rejected: 	119
# Iteration: 	14 / 100
# Confirmed: 	50
# Tentative: 	56
# Rejected: 	119
# Iteration: 	15 / 100
# Confirmed: 	50
# Tentative: 	56
# Rejected: 	119
# Iteration: 	16 / 100
# Confirmed: 	50
# Tentative: 	56
# Rejected: 	119
# Iteration: 	17 / 100
# Confirmed: 	50
# Tentative: 	56
# Rejected: 	119
# Iteration: 	18 / 100
# Confirmed: 	50
# Tentative: 	56
# Rejected: 	119
# Iteration: 	19 / 100
# Confirmed: 	50
# Tentative: 	49
# Rejected: 	126
# Iteration: 	20 / 100
# Confirmed: 	50
# Tentative: 	49
# Rejected: 	126
# Iteration: 	21 / 100
# Confirmed: 	50
# Tentative: 	49
# Rejected: 	126
# Iteration: 	22 / 100
# Confirmed: 	51
# Tentative: 	48
# Rejected: 	126
# Iteration: 	23 / 100
# Confirmed: 	51
# Tentative: 	48
# Rejected: 	126
# Iteration: 	24 / 100
# Confirmed: 	51
# Tentative: 	48
# Rejected: 	126
# Iteration: 	25 / 100
# Confirmed: 	51
# Tentative: 	47
# Rejected: 	127
# Iteration: 	26 / 100
# Confirmed: 	55
# Tentative: 	43
# Rejected: 	127
# Iteration: 	27 / 100
# Confirmed: 	55
# Tentative: 	43
# Rejected: 	127
# Iteration: 	28 / 100
# Confirmed: 	55
# Tentative: 	42
# Rejected: 	128
# Iteration: 	29 / 100
# Confirmed: 	55
# Tentative: 	42
# Rejected: 	128
# Iteration: 	30 / 100
# Confirmed: 	55
# Tentative: 	42
# Rejected: 	128
# Iteration: 	31 / 100
# Confirmed: 	55
# Tentative: 	42
# Rejected: 	128
# Iteration: 	32 / 100
# Confirmed: 	55
# Tentative: 	42
# Rejected: 	128
# Iteration: 	33 / 100
# Confirmed: 	55
# Tentative: 	42
# Rejected: 	128
# Iteration: 	34 / 100
# Confirmed: 	56
# Tentative: 	41
# Rejected: 	128
# Iteration: 	35 / 100
# Confirmed: 	56
# Tentative: 	39
# Rejected: 	130
# Iteration: 	36 / 100
# Confirmed: 	56
# Tentative: 	39
# Rejected: 	130
# Iteration: 	37 / 100
# Confirmed: 	57
# Tentative: 	35
# Rejected: 	133
# Iteration: 	38 / 100
# Confirmed: 	57
# Tentative: 	35
# Rejected: 	133
# Iteration: 	39 / 100
# Confirmed: 	57
# Tentative: 	35
# Rejected: 	133
# Iteration: 	40 / 100
# Confirmed: 	57
# Tentative: 	35
# Rejected: 	133
# Iteration: 	41 / 100
# Confirmed: 	57
# Tentative: 	33
# Rejected: 	135
# Iteration: 	42 / 100
# Confirmed: 	57
# Tentative: 	33
# Rejected: 	135
# Iteration: 	43 / 100
# Confirmed: 	59
# Tentative: 	31
# Rejected: 	135
# Iteration: 	44 / 100
# Confirmed: 	59
# Tentative: 	31
# Rejected: 	135
# Iteration: 	45 / 100
# Confirmed: 	59
# Tentative: 	31
# Rejected: 	135
# Iteration: 	46 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	47 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	48 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	49 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	50 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	51 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	52 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	53 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	54 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	55 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	56 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	57 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	58 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	59 / 100
# Confirmed: 	62
# Tentative: 	28
# Rejected: 	135
# Iteration: 	60 / 100
# Confirmed: 	62
# Tentative: 	27
# Rejected: 	136
# Iteration: 	61 / 100
# Confirmed: 	62
# Tentative: 	27
# Rejected: 	136
# Iteration: 	62 / 100
# Confirmed: 	63
# Tentative: 	26
# Rejected: 	136
# Iteration: 	63 / 100
# Confirmed: 	63
# Tentative: 	26
# Rejected: 	136
# Iteration: 	64 / 100
# Confirmed: 	63
# Tentative: 	26
# Rejected: 	136
# Iteration: 	65 / 100
# Confirmed: 	63
# Tentative: 	24
# Rejected: 	138
# Iteration: 	66 / 100
# Confirmed: 	63
# Tentative: 	24
# Rejected: 	138
# Iteration: 	67 / 100
# Confirmed: 	63
# Tentative: 	24
# Rejected: 	138
# Iteration: 	68 / 100
# Confirmed: 	63
# Tentative: 	24
# Rejected: 	138
# Iteration: 	69 / 100
# Confirmed: 	63
# Tentative: 	24
# Rejected: 	138
# Iteration: 	70 / 100
# Confirmed: 	63
# Tentative: 	24
# Rejected: 	138
# Iteration: 	71 / 100
# Confirmed: 	63
# Tentative: 	24
# Rejected: 	138
# Iteration: 	72 / 100
# Confirmed: 	63
# Tentative: 	24
# Rejected: 	138
# Iteration: 	73 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	74 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	75 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	76 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	77 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	78 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	79 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	80 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	81 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	82 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	83 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	84 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	85 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	86 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	87 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	88 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	89 / 100
# Confirmed: 	63
# Tentative: 	23
# Rejected: 	139
# Iteration: 	90 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	91 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	92 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	93 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	94 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	95 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	96 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	97 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	98 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
# Iteration: 	99 / 100
# Confirmed: 	63
# Tentative: 	22
# Rejected: 	140
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	63
# Tentative: 	11
# Rejected: 	140

# %%
selected_columns = df_features_ratio[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_feat_ratio = df_features_ratio[standard_columns]  # select the columns from the DataFrame
print(df_selected_feat_ratio.shape)
df_selected_feat_ratio.sample(5)
# Out:
# (2700, 66)
#                 ID  epoch diagnosis  ratio_r_frontal_delta_mean  \
# 3903  sub-88041261      4       MDD                    2.003224
# 1324  sub-87980913      5   HEALTHY                    1.450606
# 61    sub-87966337      2       SMC                    1.786957
# 997   sub-87971241      2       SMC                    1.954192
# 5563  sub-88054937      8       OCD                    1.718662
#
#       ratio_m_central_delta_mean  ratio_r_posterior_delta_mean  \
# 3903                    2.119469                      1.532933
# 1324                    1.312201                      1.455224
# 61                      1.560750                      1.426331
# 997                     2.360694                      1.455691
# 5563                    1.578264                      1.729553
#
#       ratio_r_frontal_theta_median  ratio_r_central_theta_mean  \
# 3903                      0.880780                    1.386825
# 1324                      1.075115                    1.265228
# 61                        0.990533                    1.210854
# 997                       1.013099                    1.672661
# 5563                      1.454259                    1.839202
#
#       ratio_r_posterior_theta_mean  ratio_l_frontal_alpha_std  ...  \
# 3903                      1.271055                   1.981035  ...
# 1324                      1.199601                   1.302651  ...
# 61                        1.251926                   0.899747  ...
# 997                       1.247597                   0.685097  ...
# 5563                      1.211841                   1.440488  ...
#
#       ratio_r_central_gamma_mean  ratio_l_posterior_gamma_std  \
# 3903                    1.079731                     0.313765
# 1324                    1.106500                     0.363248
# 61                      2.227920                     0.384504
# 997                     1.081375                     0.616229
# 5563                    1.088304                     0.309989
#
#       ratio_l_posterior_gamma_mean  ratio_l_posterior_gamma_median  \
# 3903                      1.047906                        0.970155
# 1324                      1.062128                        0.967569
# 61                        1.095770                        1.075511
# 997                       1.138961                        0.974003
# 5563                      1.054799                        1.061732
#
#       ratio_m_posterior_gamma_std  ratio_m_posterior_gamma_mean  \
# 3903                     0.348967                      1.055056
# 1324                     0.469983                      1.074639
# 61                       0.411858                      1.120291
# 997                      0.511144                      1.069508
# 5563                     0.326782                      1.058263
#
#       ratio_m_posterior_gamma_median  ratio_r_posterior_gamma_std  \
# 3903                        0.958547                     0.465183
# 1324                        0.977212                     0.465240
# 61                          1.096891                     0.713548
# 997                         0.933093                     0.441337
# 5563                        1.005193                     0.323157
#
#       ratio_r_posterior_gamma_mean  ratio_r_posterior_gamma_median
# 3903                      1.085805                        0.953161
# 1324                      1.054431                        0.924736
# 61                        1.288760                        1.132063
# 997                       1.053814                        0.977888
# 5563                      1.070157                        1.007133
#
# [5 rows x 66 columns]

# %% [markdown]
# ### EC features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_features_ec.columns if 'EC' in num_col]
 
X = df_features_ec[numeric_cols]
Y = df_features_ec['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=10, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=10, n_estimators=195)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	23
# Tentative: 	35
# Rejected: 	167
# Iteration: 	9 / 100
# Confirmed: 	23
# Tentative: 	35
# Rejected: 	167
# Iteration: 	10 / 100
# Confirmed: 	23
# Tentative: 	35
# Rejected: 	167
# Iteration: 	11 / 100
# Confirmed: 	23
# Tentative: 	35
# Rejected: 	167
# Iteration: 	12 / 100
# Confirmed: 	25
# Tentative: 	27
# Rejected: 	173
# Iteration: 	13 / 100
# Confirmed: 	25
# Tentative: 	27
# Rejected: 	173
# Iteration: 	14 / 100
# Confirmed: 	25
# Tentative: 	27
# Rejected: 	173
# Iteration: 	15 / 100
# Confirmed: 	25
# Tentative: 	27
# Rejected: 	173
# Iteration: 	16 / 100
# Confirmed: 	25
# Tentative: 	27
# Rejected: 	173
# Iteration: 	17 / 100
# Confirmed: 	25
# Tentative: 	25
# Rejected: 	175
# Iteration: 	18 / 100
# Confirmed: 	25
# Tentative: 	25
# Rejected: 	175
# Iteration: 	19 / 100
# Confirmed: 	26
# Tentative: 	24
# Rejected: 	175
# Iteration: 	20 / 100
# Confirmed: 	26
# Tentative: 	24
# Rejected: 	175
# Iteration: 	21 / 100
# Confirmed: 	26
# Tentative: 	24
# Rejected: 	175
# Iteration: 	22 / 100
# Confirmed: 	26
# Tentative: 	20
# Rejected: 	179
# Iteration: 	23 / 100
# Confirmed: 	26
# Tentative: 	20
# Rejected: 	179
# Iteration: 	24 / 100
# Confirmed: 	26
# Tentative: 	20
# Rejected: 	179
# Iteration: 	25 / 100
# Confirmed: 	26
# Tentative: 	20
# Rejected: 	179
# Iteration: 	26 / 100
# Confirmed: 	26
# Tentative: 	18
# Rejected: 	181
# Iteration: 	27 / 100
# Confirmed: 	26
# Tentative: 	18
# Rejected: 	181
# Iteration: 	28 / 100
# Confirmed: 	26
# Tentative: 	18
# Rejected: 	181
# Iteration: 	29 / 100
# Confirmed: 	26
# Tentative: 	18
# Rejected: 	181
# Iteration: 	30 / 100
# Confirmed: 	26
# Tentative: 	17
# Rejected: 	182
# Iteration: 	31 / 100
# Confirmed: 	26
# Tentative: 	17
# Rejected: 	182
# Iteration: 	32 / 100
# Confirmed: 	26
# Tentative: 	16
# Rejected: 	183
# Iteration: 	33 / 100
# Confirmed: 	26
# Tentative: 	16
# Rejected: 	183
# Iteration: 	34 / 100
# Confirmed: 	26
# Tentative: 	14
# Rejected: 	185
# Iteration: 	35 / 100
# Confirmed: 	26
# Tentative: 	14
# Rejected: 	185
# Iteration: 	36 / 100
# Confirmed: 	26
# Tentative: 	14
# Rejected: 	185
# Iteration: 	37 / 100
# Confirmed: 	27
# Tentative: 	13
# Rejected: 	185
# Iteration: 	38 / 100
# Confirmed: 	27
# Tentative: 	13
# Rejected: 	185
# Iteration: 	39 / 100
# Confirmed: 	27
# Tentative: 	13
# Rejected: 	185
# Iteration: 	40 / 100
# Confirmed: 	28
# Tentative: 	12
# Rejected: 	185
# Iteration: 	41 / 100
# Confirmed: 	28
# Tentative: 	12
# Rejected: 	185
# Iteration: 	42 / 100
# Confirmed: 	28
# Tentative: 	12
# Rejected: 	185
# Iteration: 	43 / 100
# Confirmed: 	28
# Tentative: 	12
# Rejected: 	185
# Iteration: 	44 / 100
# Confirmed: 	28
# Tentative: 	12
# Rejected: 	185
# Iteration: 	45 / 100
# Confirmed: 	28
# Tentative: 	12
# Rejected: 	185
# Iteration: 	46 / 100
# Confirmed: 	28
# Tentative: 	12
# Rejected: 	185
# Iteration: 	47 / 100
# Confirmed: 	28
# Tentative: 	12
# Rejected: 	185
# Iteration: 	48 / 100
# Confirmed: 	28
# Tentative: 	12
# Rejected: 	185
# Iteration: 	49 / 100
# Confirmed: 	28
# Tentative: 	12
# Rejected: 	185
# Iteration: 	50 / 100
# Confirmed: 	28
# Tentative: 	12
# Rejected: 	185
# Iteration: 	51 / 100
# Confirmed: 	28
# Tentative: 	11
# Rejected: 	186
# Iteration: 	52 / 100
# Confirmed: 	28
# Tentative: 	11
# Rejected: 	186
# Iteration: 	53 / 100
# Confirmed: 	28
# Tentative: 	11
# Rejected: 	186
# Iteration: 	54 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	55 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	56 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	57 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	58 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	59 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	60 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	61 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	62 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	63 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	64 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	65 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	66 / 100
# Confirmed: 	29
# Tentative: 	10
# Rejected: 	186
# Iteration: 	67 / 100
# Confirmed: 	30
# Tentative: 	9
# Rejected: 	186
# Iteration: 	68 / 100
# Confirmed: 	30
# Tentative: 	9
# Rejected: 	186
# Iteration: 	69 / 100
# Confirmed: 	30
# Tentative: 	9
# Rejected: 	186
# Iteration: 	70 / 100
# Confirmed: 	30
# Tentative: 	9
# Rejected: 	186
# Iteration: 	71 / 100
# Confirmed: 	30
# Tentative: 	9
# Rejected: 	186
# Iteration: 	72 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	73 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	74 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	75 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	76 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	77 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	78 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	79 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	80 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	81 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	82 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	83 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	84 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	85 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	86 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	87 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	186
# Iteration: 	88 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
# Iteration: 	89 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
# Iteration: 	90 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
# Iteration: 	91 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
# Iteration: 	92 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
# Iteration: 	93 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
# Iteration: 	94 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
# Iteration: 	95 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
# Iteration: 	96 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
# Iteration: 	97 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
# Iteration: 	98 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
# Iteration: 	99 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	186
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	32
# Tentative: 	5
# Rejected: 	186

# %%
selected_columns = df_features_ec[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_feat_ec = df_features_ec[standard_columns]  # select the columns from the DataFrame
print(df_selected_feat_ec.shape)
df_selected_feat_ec.sample(5)
# Out:
# (2700, 35)
#                 ID  epoch diagnosis  EC_l_frontal_theta_std  \
# 6948  sub-88068981      1       OCD                0.108951
# 2566  sub-88024697     11       MDD                0.123111
# 7042  sub-88069649     11       MDD                0.139336
# 1872  sub-88013761      1       OCD                0.091943
# 388   sub-87967869      5       SMC                0.127497
#
#       EC_r_frontal_theta_std  EC_r_central_theta_std  \
# 6948                0.089886                0.095733
# 2566                0.159501                0.104905
# 7042                0.154673                0.187674
# 1872                0.108748                0.110516
# 388                 0.137819                0.149251
#
#       EC_m_posterior_theta_std  EC_l_frontal_alpha_std  \
# 6948                  0.124795                0.137705
# 2566                  0.101477                0.111448
# 7042                  0.127402                0.175334
# 1872                  0.091062                0.107061
# 388                   0.144283                0.125154
#
#       EC_m_frontal_alpha_std  EC_r_frontal_alpha_std  ...  \
# 6948                0.132616                0.131015  ...
# 2566                0.126182                0.118773  ...
# 7042                0.154354                0.154633  ...
# 1872                0.121067                0.121116  ...
# 388                 0.127311                0.135406  ...
#
#       EC_l_central_gamma_skew  EC_m_central_gamma_std  \
# 6948                 0.655195                0.052877
# 2566                -0.044150                0.051325
# 7042                 0.756983                0.076070
# 1872                 0.619862                0.061948
# 388                  0.329537                0.049787
#
#       EC_m_central_gamma_skew  EC_r_central_gamma_std  \
# 6948                 0.427583                0.055133
# 2566                -0.022581                0.048027
# 7042                 0.733246                0.081648
# 1872                 0.390598                0.062493
# 388                  0.500112                0.049580
#
#       EC_r_central_gamma_skew  EC_l_posterior_gamma_std  \
# 6948                 0.156472                  0.063522
# 2566                -0.033781                  0.057240
# 7042                 0.805561                  0.077420
# 1872                 0.383662                  0.062980
# 388                  0.408481                  0.049941
#
#       EC_l_posterior_gamma_skew  EC_m_posterior_gamma_std  \
# 6948                   0.753148                  0.157907
# 2566                   0.019620                  0.054745
# 7042                   0.810562                  0.076596
# 1872                   0.274757                  0.064289
# 388                    0.323892                  0.051879
#
#       EC_r_posterior_gamma_std  EC_r_posterior_gamma_skew
# 6948                  0.060459                   0.209123
# 2566                  0.052163                  -0.065585
# 7042                  0.079092                   0.846677
# 1872                  0.066039                   0.331973
# 388                   0.055741                   0.012808
#
# [5 rows x 35 columns]

# %% [markdown]
# ### EO features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_features_eo.columns if 'EO' in num_col]
 
X = df_features_eo[numeric_cols]
Y = df_features_eo['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=10, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=10, n_estimators=195)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	225
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	23
# Tentative: 	35
# Rejected: 	167
# Iteration: 	9 / 100
# Confirmed: 	23
# Tentative: 	35
# Rejected: 	167
# Iteration: 	10 / 100
# Confirmed: 	23
# Tentative: 	35
# Rejected: 	167
# Iteration: 	11 / 100
# Confirmed: 	23
# Tentative: 	35
# Rejected: 	167
# Iteration: 	12 / 100
# Confirmed: 	23
# Tentative: 	22
# Rejected: 	180
# Iteration: 	13 / 100
# Confirmed: 	23
# Tentative: 	22
# Rejected: 	180
# Iteration: 	14 / 100
# Confirmed: 	23
# Tentative: 	22
# Rejected: 	180
# Iteration: 	15 / 100
# Confirmed: 	23
# Tentative: 	22
# Rejected: 	180
# Iteration: 	16 / 100
# Confirmed: 	23
# Tentative: 	18
# Rejected: 	184
# Iteration: 	17 / 100
# Confirmed: 	23
# Tentative: 	18
# Rejected: 	184
# Iteration: 	18 / 100
# Confirmed: 	23
# Tentative: 	18
# Rejected: 	184
# Iteration: 	19 / 100
# Confirmed: 	24
# Tentative: 	17
# Rejected: 	184
# Iteration: 	20 / 100
# Confirmed: 	24
# Tentative: 	17
# Rejected: 	184
# Iteration: 	21 / 100
# Confirmed: 	24
# Tentative: 	16
# Rejected: 	185
# Iteration: 	22 / 100
# Confirmed: 	24
# Tentative: 	14
# Rejected: 	187
# Iteration: 	23 / 100
# Confirmed: 	24
# Tentative: 	14
# Rejected: 	187
# Iteration: 	24 / 100
# Confirmed: 	24
# Tentative: 	14
# Rejected: 	187
# Iteration: 	25 / 100
# Confirmed: 	24
# Tentative: 	14
# Rejected: 	187
# Iteration: 	26 / 100
# Confirmed: 	24
# Tentative: 	14
# Rejected: 	187
# Iteration: 	27 / 100
# Confirmed: 	24
# Tentative: 	14
# Rejected: 	187
# Iteration: 	28 / 100
# Confirmed: 	24
# Tentative: 	14
# Rejected: 	187
# Iteration: 	29 / 100
# Confirmed: 	24
# Tentative: 	14
# Rejected: 	187
# Iteration: 	30 / 100
# Confirmed: 	24
# Tentative: 	14
# Rejected: 	187
# Iteration: 	31 / 100
# Confirmed: 	24
# Tentative: 	14
# Rejected: 	187
# Iteration: 	32 / 100
# Confirmed: 	24
# Tentative: 	13
# Rejected: 	188
# Iteration: 	33 / 100
# Confirmed: 	24
# Tentative: 	13
# Rejected: 	188
# Iteration: 	34 / 100
# Confirmed: 	24
# Tentative: 	13
# Rejected: 	188
# Iteration: 	35 / 100
# Confirmed: 	24
# Tentative: 	13
# Rejected: 	188
# Iteration: 	36 / 100
# Confirmed: 	24
# Tentative: 	13
# Rejected: 	188
# Iteration: 	37 / 100
# Confirmed: 	24
# Tentative: 	13
# Rejected: 	188
# Iteration: 	38 / 100
# Confirmed: 	24
# Tentative: 	13
# Rejected: 	188
# Iteration: 	39 / 100
# Confirmed: 	24
# Tentative: 	13
# Rejected: 	188
# Iteration: 	40 / 100
# Confirmed: 	24
# Tentative: 	13
# Rejected: 	188
# Iteration: 	41 / 100
# Confirmed: 	24
# Tentative: 	13
# Rejected: 	188
# Iteration: 	42 / 100
# Confirmed: 	24
# Tentative: 	13
# Rejected: 	188
# Iteration: 	43 / 100
# Confirmed: 	24
# Tentative: 	11
# Rejected: 	190
# Iteration: 	44 / 100
# Confirmed: 	24
# Tentative: 	11
# Rejected: 	190
# Iteration: 	45 / 100
# Confirmed: 	24
# Tentative: 	11
# Rejected: 	190
# Iteration: 	46 / 100
# Confirmed: 	24
# Tentative: 	11
# Rejected: 	190
# Iteration: 	47 / 100
# Confirmed: 	24
# Tentative: 	11
# Rejected: 	190
# Iteration: 	48 / 100
# Confirmed: 	24
# Tentative: 	11
# Rejected: 	190
# Iteration: 	49 / 100
# Confirmed: 	24
# Tentative: 	11
# Rejected: 	190
# Iteration: 	50 / 100
# Confirmed: 	24
# Tentative: 	11
# Rejected: 	190
# Iteration: 	51 / 100
# Confirmed: 	24
# Tentative: 	10
# Rejected: 	191
# Iteration: 	52 / 100
# Confirmed: 	24
# Tentative: 	10
# Rejected: 	191
# Iteration: 	53 / 100
# Confirmed: 	24
# Tentative: 	10
# Rejected: 	191
# Iteration: 	54 / 100
# Confirmed: 	24
# Tentative: 	10
# Rejected: 	191
# Iteration: 	55 / 100
# Confirmed: 	24
# Tentative: 	10
# Rejected: 	191
# Iteration: 	56 / 100
# Confirmed: 	24
# Tentative: 	10
# Rejected: 	191
# Iteration: 	57 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	58 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	59 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	60 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	61 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	62 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	63 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	64 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	65 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	66 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	67 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	68 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	69 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	70 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	71 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	72 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	73 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	74 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	75 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	76 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	77 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	78 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	79 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	80 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	81 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	82 / 100
# Confirmed: 	24
# Tentative: 	9
# Rejected: 	192
# Iteration: 	83 / 100
# Confirmed: 	25
# Tentative: 	8
# Rejected: 	192
# Iteration: 	84 / 100
# Confirmed: 	25
# Tentative: 	8
# Rejected: 	192
# Iteration: 	85 / 100
# Confirmed: 	25
# Tentative: 	8
# Rejected: 	192
# Iteration: 	86 / 100
# Confirmed: 	25
# Tentative: 	8
# Rejected: 	192
# Iteration: 	87 / 100
# Confirmed: 	25
# Tentative: 	8
# Rejected: 	192
# Iteration: 	88 / 100
# Confirmed: 	25
# Tentative: 	8
# Rejected: 	192
# Iteration: 	89 / 100
# Confirmed: 	25
# Tentative: 	8
# Rejected: 	192
# Iteration: 	90 / 100
# Confirmed: 	25
# Tentative: 	8
# Rejected: 	192
# Iteration: 	91 / 100
# Confirmed: 	25
# Tentative: 	8
# Rejected: 	192
# Iteration: 	92 / 100
# Confirmed: 	25
# Tentative: 	8
# Rejected: 	192
# Iteration: 	93 / 100
# Confirmed: 	26
# Tentative: 	7
# Rejected: 	192
# Iteration: 	94 / 100
# Confirmed: 	26
# Tentative: 	7
# Rejected: 	192
# Iteration: 	95 / 100
# Confirmed: 	26
# Tentative: 	7
# Rejected: 	192
# Iteration: 	96 / 100
# Confirmed: 	26
# Tentative: 	7
# Rejected: 	192
# Iteration: 	97 / 100
# Confirmed: 	26
# Tentative: 	7
# Rejected: 	192
# Iteration: 	98 / 100
# Confirmed: 	26
# Tentative: 	7
# Rejected: 	192
# Iteration: 	99 / 100
# Confirmed: 	26
# Tentative: 	7
# Rejected: 	192
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	192

# %%
selected_columns = df_features_eo[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_feat_eo = df_features_eo[standard_columns]  # select the columns from the DataFrame
print(df_selected_feat_eo.shape)
df_selected_feat_eo.sample(5)
# Out:
# (2700, 29)
#                 ID  epoch diagnosis  EO_l_central_theta_std  \
# 952   sub-87971021      5       SMC                0.145748
# 178   sub-87966789     11       SMC                0.105888
# 4855  sub-88048729      8   HEALTHY                0.085390
# 5416  sub-88053677      5       OCD                0.143328
# 6464  sub-88064837      9       MDD                0.129625
#
#       EO_r_central_theta_std  EO_l_frontal_alpha_std  EO_m_frontal_alpha_std  \
# 952                 0.137303                0.190433                0.225691
# 178                 0.123861                0.117108                0.119604
# 4855                0.088237                0.156010                0.137830
# 5416                0.154357                0.285872                0.259050
# 6464                0.093266                0.256212                0.230666
#
#       EO_r_frontal_alpha_std  EO_l_central_alpha_std  EO_m_central_alpha_std  \
# 952                 0.204266                0.132179                0.152887
# 178                 0.122632                0.111361                0.127422
# 4855                0.110616                0.139208                0.152762
# 5416                0.248440                0.254546                0.268179
# 6464                0.206458                0.255360                0.223412
#
#       ...  EO_m_frontal_gamma_std  EO_r_frontal_gamma_std  \
# 952   ...                0.123443                0.088551
# 178   ...                0.051472                0.065147
# 4855  ...                0.060073                0.054395
# 5416  ...                0.347029                0.518007
# 6464  ...                0.071372                0.083213
#
#       EO_l_central_gamma_std  EO_m_central_gamma_std  EO_r_central_gamma_std  \
# 952                 0.098761                0.101528                0.077844
# 178                 0.044687                0.044296                0.051516
# 4855                0.070285                0.065490                0.060263
# 5416                0.257568                0.344079                0.480013
# 6464                0.069349                0.064185                0.068807
#
#       EO_l_posterior_gamma_std  EO_m_posterior_gamma_std  \
# 952                   0.057044                  0.053514
# 178                   0.098009                  0.071494
# 4855                  0.059224                  0.057233
# 5416                  0.367662                  0.358712
# 6464                  0.072058                  0.070959
#
#       EO_m_posterior_gamma_skew  EO_r_posterior_gamma_std  \
# 952                    0.397197                  0.051488
# 178                    1.589827                  0.054754
# 4855                   0.607032                  0.056980
# 5416                   3.145637                  0.375996
# 6464                   1.463925                  0.081098
#
#       EO_r_posterior_gamma_skew
# 952                    0.167537
# 178                    0.620328
# 4855                   0.383700
# 5416                   3.171278
# 6464                   1.761482
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Merge selected ratio, EC, EO features

# %%
# Drop the 'ID', 'epoch', 'diagnosis' columns from the second and third dataframes for concatenation
df_selected_feat_eo = df_selected_feat_eo.drop(['ID', 'epoch', 'diagnosis'], axis=1)
df_selected_feat_ratio = df_selected_feat_ratio.drop(['ID', 'epoch', 'diagnosis'], axis=1)

# Concatenate the dataframes
df_selected_features = pd.concat([df_selected_feat_ec, df_selected_feat_eo, df_selected_feat_ratio], axis=1)
df_selected_features
# Out:
#                 ID  epoch diagnosis  EC_l_frontal_theta_std  \
# 24    sub-87964717      1       SMC                0.146601
# 25    sub-87964717      2       SMC                0.103510
# 26    sub-87964717      3       SMC                0.126494
# 27    sub-87964717      4       SMC                0.199366
# 28    sub-87964717      5       SMC                0.145020
# ...            ...    ...       ...                     ...
# 7807  sub-88076717      8       OCD                0.148191
# 7808  sub-88076717      9       OCD                0.111555
# 7809  sub-88076717     10       OCD                0.159637
# 7810  sub-88076717     11       OCD                0.139784
# 7811  sub-88076717     12       OCD                0.267289
#
#       EC_r_frontal_theta_std  EC_r_central_theta_std  \
# 24                  0.134083                0.126677
# 25                  0.113882                0.113146
# 26                  0.153072                0.176219
# 27                  0.190631                0.161905
# 28                  0.181982                0.153659
# ...                      ...                     ...
# 7807                0.173885                0.203578
# 7808                0.139117                0.116225
# 7809                0.184458                0.188101
# 7810                0.164089                0.166881
# 7811                0.286961                0.246421
#
#       EC_m_posterior_theta_std  EC_l_frontal_alpha_std  \
# 24                    0.088821                0.133251
# 25                    0.093144                0.120214
# 26                    0.122526                0.105422
# 27                    0.155581                0.128919
# 28                    0.130231                0.142192
# ...                        ...                     ...
# 7807                  0.131782                0.124016
# 7808                  0.116095                0.104099
# 7809                  0.169570                0.107770
# 7810                  0.150072                0.125906
# 7811                  0.217819                0.256446
#
#       EC_m_frontal_alpha_std  EC_r_frontal_alpha_std  ...  \
# 24                  0.136564                0.126442  ...
# 25                  0.108708                0.122549  ...
# 26                  0.108432                0.145150  ...
# 27                  0.106647                0.107669  ...
# 28                  0.167562                0.161236  ...
# ...                      ...                     ...  ...
# 7807                0.134765                0.140447  ...
# 7808                0.111799                0.118723  ...
# 7809                0.121271                0.135420  ...
# 7810                0.128966                0.142744  ...
# 7811                0.230326                0.241873  ...
#
#       ratio_r_central_gamma_mean  ratio_l_posterior_gamma_std  \
# 24                      1.087600                     0.483367
# 25                      1.057341                     0.496462
# 26                      1.118931                     0.422118
# 27                      1.240129                     0.609446
# 28                      1.125797                     0.702789
# ...                          ...                          ...
# 7807                    1.106774                     0.430855
# 7808                    1.054210                     0.320705
# 7809                    1.086880                     0.394367
# 7810                    1.123323                     0.667891
# 7811                    1.192061                     0.461534
#
#       ratio_l_posterior_gamma_mean  ratio_l_posterior_gamma_median  \
# 24                        1.070833                        0.945090
# 25                        1.094712                        1.012856
# 26                        1.080215                        1.006534
# 27                        1.253339                        1.197622
# 28                        1.121589                        0.921769
# ...                            ...                             ...
# 7807                      1.075240                        0.965426
# 7808                      1.039691                        0.993901
# 7809                      1.069753                        1.013555
# 7810                      1.143056                        1.000576
# 7811                      1.118180                        1.042685
#
#       ratio_m_posterior_gamma_std  ratio_m_posterior_gamma_mean  \
# 24                       0.404591                      1.052324
# 25                       0.549874                      1.108695
# 26                       0.504356                      1.089061
# 27                       0.475679                      1.146048
# 28                       0.640190                      1.100259
# ...                           ...                           ...
# 7807                     0.440777                      1.082105
# 7808                     0.292085                      1.034767
# 7809                     0.430236                      1.088069
# 7810                     0.419430                      1.076165
# 7811                     0.395366                      1.083653
#
#       ratio_m_posterior_gamma_median  ratio_r_posterior_gamma_std  \
# 24                          0.958792                     0.493553
# 25                          0.950054                     0.581599
# 26                          1.006077                     0.541452
# 27                          1.109712                     0.460338
# 28                          0.930693                     0.628968
# ...                              ...                          ...
# 7807                        0.990665                     0.407258
# 7808                        1.005944                     0.313329
# 7809                        1.028141                     0.421369
# 7810                        1.001551                     0.448825
# 7811                        1.035568                     0.482152
#
#       ratio_r_posterior_gamma_mean  ratio_r_posterior_gamma_median
# 24                        1.086141                        0.973209
# 25                        1.117381                        0.948814
# 26                        1.098838                        0.973932
# 27                        1.128810                        1.110328
# 28                        1.105704                        0.952507
# ...                            ...                             ...
# 7807                      1.083663                        0.996010
# 7808                      1.050033                        1.023995
# 7809                      1.095421                        1.021315
# 7810                      1.085113                        1.031082
# 7811                      1.121904                        1.086677
#
# [2700 rows x 124 columns]

# %%
df_selected_features.to_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_selected_stat_features.pkl')

# %% [markdown]
# # 2. statistical TFR + connectivity features

# %%
df_conn_features = pd.read_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_connectivity_features.pkl')
df_features = df_features.dropna(subset=['diagnosis'])

# %%
# subsample dataset to rebalance dataset
df_conn_subsample = df_conn_features[(df_conn_features['ID'].isin(df_ids_subsample_index))] # use same sampled IDs from earlier for the stat features
df_conn_subsample['diagnosis'].value_counts()
# Out:
# diagnosis
# SMC        540
# HEALTHY    540
# MDD        540
# ADHD       540
# OCD        540
# Name: count, dtype: int64

# %%
# merge stat and conn features and store for later training of GCNs
df_stat_conn_features = pd.merge(df_stat_subsample, df_conn_subsample.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
# drop age and gender columns
df_stat_conn_features = df_stat_conn_features.drop(columns=['age', 'gender'])
df_stat_conn_features.to_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_stat_conn_features.pkl')
print(df_stat_conn_features.shape)
df_stat_conn_features.sample(3)
# Out:
# (2700, 1218)
#                 ID diagnosis  epoch  EO_l_frontal_delta_std  \
# 158   sub-87967781       SMC      3                0.184909
# 1590  sub-88047789       MDD      7                0.150474
# 1525  sub-88045809       MDD      2                0.116537
#
#       EO_l_frontal_delta_mean  EO_l_frontal_delta_median  \
# 158                       0.2                        0.2
# 1590                      0.2                        0.2
# 1525                      0.2                        0.2
#
#       EO_l_frontal_delta_skew  EO_l_frontal_delta_kurt  \
# 158                  2.171460                 5.753834
# 1590                 1.226924                 2.115696
# 1525                 0.784385                 0.223850
#
#       EO_m_frontal_delta_std  EO_m_frontal_delta_mean  ...  \
# 158                 0.136602                      0.2  ...
# 1590                0.126341                      0.2  ...
# 1525                0.115017                      0.2  ...
#
#       ratio_gamma_m_central-r_central  ratio_gamma_m_central-l_posterior  \
# 158                          0.978163                           1.049595
# 1590                         1.031051                           1.052111
# 1525                         1.046713                           1.060350
#
#       ratio_gamma_m_central-m_posterior  ratio_gamma_m_central-r_posterior  \
# 158                            1.044583                           0.995937
# 1590                           1.043470                           1.070464
# 1525                           1.061318                           1.064623
#
#       ratio_gamma_r_central-l_posterior  ratio_gamma_r_central-m_posterior  \
# 158                            1.050426                           1.047645
# 1590                           1.057530                           1.046055
# 1525                           1.066857                           1.041233
#
#       ratio_gamma_r_central-r_posterior  ratio_gamma_l_posterior-m_posterior  \
# 158                            1.015708                             1.007729
# 1590                           1.066234                             1.048837
# 1525                           0.999901                             1.069585
#
#       ratio_gamma_l_posterior-r_posterior  ratio_gamma_m_posterior-r_posterior
# 158                              1.011348                             1.029767
# 1590                             1.082087                             1.069819
# 1525                             1.100770                             1.076392
#
# [3 rows x 1218 columns]

# %%
# create 3 feature sets [EC, EO, ratio] with column ['ID', 'age', 'gender', 'diagnosis', 'epoch']
df_conn_features_ec = df_conn_subsample[df_conn_features.columns[~(df_conn_subsample.columns.str.startswith('EO') | df_conn_subsample.columns.str.startswith('ratio'))]]
df_conn_features_eo = df_conn_subsample[df_conn_features.columns[~(df_conn_subsample.columns.str.startswith('EC') | df_conn_subsample.columns.str.startswith('ratio'))]]
df_conn_features_ratio = df_conn_subsample[df_conn_features.columns[~(df_conn_subsample.columns.str.startswith('EC') | df_conn_subsample.columns.str.startswith('EO'))]]

# %%
# concat connectivity features with stat features
df_stat_conn_features_ec = pd.merge(df_features_ec, df_conn_features_ec.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
df_stat_conn_features_eo = pd.merge(df_features_eo, df_conn_features_eo.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
df_stat_conn_features_ratio = pd.merge(df_features_ratio, df_conn_features_ratio.drop(columns=['diagnosis']),  how='outer', on=['ID', 'epoch'])
print(df_stat_conn_features_ec.shape)
# Out:
# (2700, 410)

# %% [markdown]
# ### Ratio features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_stat_conn_features_ratio.columns if 'ratio' in num_col]
 
X = df_stat_conn_features_ratio[numeric_cols]
Y = df_stat_conn_features_ratio['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=10, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=10, n_estimators=195)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	127
# Tentative: 	138
# Rejected: 	140
# Iteration: 	9 / 100
# Confirmed: 	127
# Tentative: 	138
# Rejected: 	140
# Iteration: 	10 / 100
# Confirmed: 	127
# Tentative: 	138
# Rejected: 	140
# Iteration: 	11 / 100
# Confirmed: 	127
# Tentative: 	138
# Rejected: 	140
# Iteration: 	12 / 100
# Confirmed: 	141
# Tentative: 	99
# Rejected: 	165
# Iteration: 	13 / 100
# Confirmed: 	141
# Tentative: 	99
# Rejected: 	165
# Iteration: 	14 / 100
# Confirmed: 	141
# Tentative: 	99
# Rejected: 	165
# Iteration: 	15 / 100
# Confirmed: 	141
# Tentative: 	99
# Rejected: 	165
# Iteration: 	16 / 100
# Confirmed: 	143
# Tentative: 	85
# Rejected: 	177
# Iteration: 	17 / 100
# Confirmed: 	143
# Tentative: 	85
# Rejected: 	177
# Iteration: 	18 / 100
# Confirmed: 	143
# Tentative: 	85
# Rejected: 	177
# Iteration: 	19 / 100
# Confirmed: 	144
# Tentative: 	84
# Rejected: 	177
# Iteration: 	20 / 100
# Confirmed: 	144
# Tentative: 	84
# Rejected: 	177
# Iteration: 	21 / 100
# Confirmed: 	144
# Tentative: 	84
# Rejected: 	177
# Iteration: 	22 / 100
# Confirmed: 	146
# Tentative: 	82
# Rejected: 	177
# Iteration: 	23 / 100
# Confirmed: 	146
# Tentative: 	82
# Rejected: 	177
# Iteration: 	24 / 100
# Confirmed: 	146
# Tentative: 	77
# Rejected: 	182
# Iteration: 	25 / 100
# Confirmed: 	146
# Tentative: 	77
# Rejected: 	182
# Iteration: 	26 / 100
# Confirmed: 	147
# Tentative: 	76
# Rejected: 	182
# Iteration: 	27 / 100
# Confirmed: 	147
# Tentative: 	76
# Rejected: 	182
# Iteration: 	28 / 100
# Confirmed: 	147
# Tentative: 	76
# Rejected: 	182
# Iteration: 	29 / 100
# Confirmed: 	147
# Tentative: 	69
# Rejected: 	189
# Iteration: 	30 / 100
# Confirmed: 	147
# Tentative: 	69
# Rejected: 	189
# Iteration: 	31 / 100
# Confirmed: 	147
# Tentative: 	69
# Rejected: 	189
# Iteration: 	32 / 100
# Confirmed: 	149
# Tentative: 	67
# Rejected: 	189
# Iteration: 	33 / 100
# Confirmed: 	149
# Tentative: 	67
# Rejected: 	189
# Iteration: 	34 / 100
# Confirmed: 	151
# Tentative: 	63
# Rejected: 	191
# Iteration: 	35 / 100
# Confirmed: 	151
# Tentative: 	63
# Rejected: 	191
# Iteration: 	36 / 100
# Confirmed: 	151
# Tentative: 	63
# Rejected: 	191
# Iteration: 	37 / 100
# Confirmed: 	154
# Tentative: 	60
# Rejected: 	191
# Iteration: 	38 / 100
# Confirmed: 	154
# Tentative: 	56
# Rejected: 	195
# Iteration: 	39 / 100
# Confirmed: 	154
# Tentative: 	56
# Rejected: 	195
# Iteration: 	40 / 100
# Confirmed: 	156
# Tentative: 	54
# Rejected: 	195
# Iteration: 	41 / 100
# Confirmed: 	156
# Tentative: 	54
# Rejected: 	195
# Iteration: 	42 / 100
# Confirmed: 	156
# Tentative: 	54
# Rejected: 	195
# Iteration: 	43 / 100
# Confirmed: 	156
# Tentative: 	54
# Rejected: 	195
# Iteration: 	44 / 100
# Confirmed: 	156
# Tentative: 	54
# Rejected: 	195
# Iteration: 	45 / 100
# Confirmed: 	156
# Tentative: 	54
# Rejected: 	195
# Iteration: 	46 / 100
# Confirmed: 	156
# Tentative: 	54
# Rejected: 	195
# Iteration: 	47 / 100
# Confirmed: 	156
# Tentative: 	51
# Rejected: 	198
# Iteration: 	48 / 100
# Confirmed: 	156
# Tentative: 	51
# Rejected: 	198
# Iteration: 	49 / 100
# Confirmed: 	156
# Tentative: 	51
# Rejected: 	198
# Iteration: 	50 / 100
# Confirmed: 	156
# Tentative: 	51
# Rejected: 	198
# Iteration: 	51 / 100
# Confirmed: 	156
# Tentative: 	51
# Rejected: 	198
# Iteration: 	52 / 100
# Confirmed: 	156
# Tentative: 	51
# Rejected: 	198
# Iteration: 	53 / 100
# Confirmed: 	156
# Tentative: 	49
# Rejected: 	200
# Iteration: 	54 / 100
# Confirmed: 	157
# Tentative: 	48
# Rejected: 	200
# Iteration: 	55 / 100
# Confirmed: 	157
# Tentative: 	48
# Rejected: 	200
# Iteration: 	56 / 100
# Confirmed: 	157
# Tentative: 	48
# Rejected: 	200
# Iteration: 	57 / 100
# Confirmed: 	157
# Tentative: 	48
# Rejected: 	200
# Iteration: 	58 / 100
# Confirmed: 	157
# Tentative: 	48
# Rejected: 	200
# Iteration: 	59 / 100
# Confirmed: 	157
# Tentative: 	48
# Rejected: 	200
# Iteration: 	60 / 100
# Confirmed: 	157
# Tentative: 	48
# Rejected: 	200
# Iteration: 	61 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	62 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	63 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	64 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	65 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	66 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	67 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	68 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	69 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	70 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	71 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	72 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	202
# Iteration: 	73 / 100
# Confirmed: 	157
# Tentative: 	44
# Rejected: 	204
# Iteration: 	74 / 100
# Confirmed: 	157
# Tentative: 	44
# Rejected: 	204
# Iteration: 	75 / 100
# Confirmed: 	159
# Tentative: 	42
# Rejected: 	204
# Iteration: 	76 / 100
# Confirmed: 	159
# Tentative: 	42
# Rejected: 	204
# Iteration: 	77 / 100
# Confirmed: 	159
# Tentative: 	42
# Rejected: 	204
# Iteration: 	78 / 100
# Confirmed: 	159
# Tentative: 	42
# Rejected: 	204
# Iteration: 	79 / 100
# Confirmed: 	159
# Tentative: 	42
# Rejected: 	204
# Iteration: 	80 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	81 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	82 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	83 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	84 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	85 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	86 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	87 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	88 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	89 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	90 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	91 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	92 / 100
# Confirmed: 	159
# Tentative: 	41
# Rejected: 	205
# Iteration: 	93 / 100
# Confirmed: 	160
# Tentative: 	40
# Rejected: 	205
# Iteration: 	94 / 100
# Confirmed: 	160
# Tentative: 	40
# Rejected: 	205
# Iteration: 	95 / 100
# Confirmed: 	160
# Tentative: 	40
# Rejected: 	205
# Iteration: 	96 / 100
# Confirmed: 	160
# Tentative: 	40
# Rejected: 	205
# Iteration: 	97 / 100
# Confirmed: 	160
# Tentative: 	40
# Rejected: 	205
# Iteration: 	98 / 100
# Confirmed: 	160
# Tentative: 	40
# Rejected: 	205
# Iteration: 	99 / 100
# Confirmed: 	160
# Tentative: 	40
# Rejected: 	205
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	160
# Tentative: 	11
# Rejected: 	205

# %%
selected_columns = df_stat_conn_features_ratio[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_stat_conn_feat_ratio = df_stat_conn_features_ratio[standard_columns]  # select the columns from the DataFrame
print(df_selected_stat_conn_feat_ratio.shape)
df_selected_stat_conn_feat_ratio.sample(5)
# Out:
# (2700, 163)
#                 ID  epoch diagnosis  ratio_l_frontal_alpha_mean  \
# 1352  sub-88039057      9       MDD                    1.213141
# 653   sub-87976457      6   HEALTHY                    1.312502
# 2420  sub-88068305      9       OCD                    1.735111
# 462   sub-87970881      7       SMC                    1.681079
# 566   sub-87974665      3   HEALTHY                    1.263135
#
#       ratio_m_frontal_alpha_std  ratio_m_frontal_alpha_mean  \
# 1352                   1.327848                    1.256289
# 653                    0.832912                    1.101114
# 2420                   2.191840                    1.823405
# 462                    3.013073                    1.783206
# 566                    1.265745                    1.300396
#
#       ratio_r_frontal_alpha_std  ratio_r_frontal_alpha_mean  \
# 1352                   1.193689                    1.273507
# 653                    1.020761                    1.230748
# 2420                   1.621107                    1.564413
# 462                    2.367164                    1.519516
# 566                    1.027637                    1.298083
#
#       ratio_l_central_alpha_std  ratio_l_central_alpha_mean  ...  \
# 1352                   0.888743                    1.195313  ...
# 653                    1.546617                    1.489874  ...
# 2420                   2.967017                    1.762768  ...
# 462                    2.335599                    1.632410  ...
# 566                    1.672523                    1.451080  ...
#
#       ratio_gamma_m_central-r_central  ratio_gamma_m_central-l_posterior  \
# 1352                         0.991579                           0.916280
# 653                          1.076991                           1.119261
# 2420                         1.060700                           1.016922
# 462                          1.029815                           0.969744
# 566                          0.991367                           0.987678
#
#       ratio_gamma_m_central-m_posterior  ratio_gamma_m_central-r_posterior  \
# 1352                           0.942460                           0.969335
# 653                            1.113363                           1.134421
# 2420                           1.017605                           1.031636
# 462                            0.953663                           0.940683
# 566                            0.973874                           0.971294
#
#       ratio_gamma_r_central-l_posterior  ratio_gamma_r_central-m_posterior  \
# 1352                           0.893161                           0.933583
# 653                            1.161495                           1.134454
# 2420                           1.055644                           1.052823
# 462                            1.013320                           1.018825
# 566                            1.057333                           1.049983
#
#       ratio_gamma_r_central-r_posterior  ratio_gamma_l_posterior-m_posterior  \
# 1352                           0.933522                             0.942397
# 653                            1.128749                             1.045884
# 2420                           1.024429                             1.003283
# 462                            1.012468                             0.977051
# 566                            1.043067                             0.999315
#
#       ratio_gamma_l_posterior-r_posterior  ratio_gamma_m_posterior-r_posterior
# 1352                             0.920569                             0.944964
# 653                              1.116939                             1.087178
# 2420                             1.013044                             1.014297
# 462                              0.958037                             0.964870
# 566                              1.031435                             1.061390
#
# [5 rows x 163 columns]

# %%
# count the number of selected statistical features (columns containing ['std', 'mean', 'median', 'skew', 'kurt'])
stat_selected = [col for col in df_selected_stat_conn_feat_ratio.columns if any(x in col for x in ['std', 'mean', 'median', 'skew', 'kurt'])]
print(len(stat_selected))
# Out:
# 53

# %% [markdown]
# ### EC features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_stat_conn_features_ec.columns if 'EC' in num_col]
 
X = df_stat_conn_features_ec[numeric_cols]
Y = df_stat_conn_features_ec['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=15, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=10, n_estimators=175)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	194
# Tentative: 	53
# Rejected: 	158
# Iteration: 	9 / 100
# Confirmed: 	194
# Tentative: 	53
# Rejected: 	158
# Iteration: 	10 / 100
# Confirmed: 	194
# Tentative: 	53
# Rejected: 	158
# Iteration: 	11 / 100
# Confirmed: 	194
# Tentative: 	53
# Rejected: 	158
# Iteration: 	12 / 100
# Confirmed: 	196
# Tentative: 	51
# Rejected: 	158
# Iteration: 	13 / 100
# Confirmed: 	196
# Tentative: 	51
# Rejected: 	158
# Iteration: 	14 / 100
# Confirmed: 	196
# Tentative: 	43
# Rejected: 	166
# Iteration: 	15 / 100
# Confirmed: 	196
# Tentative: 	43
# Rejected: 	166
# Iteration: 	16 / 100
# Confirmed: 	199
# Tentative: 	40
# Rejected: 	166
# Iteration: 	17 / 100
# Confirmed: 	199
# Tentative: 	40
# Rejected: 	166
# Iteration: 	18 / 100
# Confirmed: 	199
# Tentative: 	40
# Rejected: 	166
# Iteration: 	19 / 100
# Confirmed: 	199
# Tentative: 	40
# Rejected: 	166
# Iteration: 	20 / 100
# Confirmed: 	199
# Tentative: 	40
# Rejected: 	166
# Iteration: 	21 / 100
# Confirmed: 	199
# Tentative: 	40
# Rejected: 	166
# Iteration: 	22 / 100
# Confirmed: 	202
# Tentative: 	37
# Rejected: 	166
# Iteration: 	23 / 100
# Confirmed: 	202
# Tentative: 	30
# Rejected: 	173
# Iteration: 	24 / 100
# Confirmed: 	202
# Tentative: 	30
# Rejected: 	173
# Iteration: 	25 / 100
# Confirmed: 	202
# Tentative: 	30
# Rejected: 	173
# Iteration: 	26 / 100
# Confirmed: 	202
# Tentative: 	30
# Rejected: 	173
# Iteration: 	27 / 100
# Confirmed: 	202
# Tentative: 	30
# Rejected: 	173
# Iteration: 	28 / 100
# Confirmed: 	202
# Tentative: 	30
# Rejected: 	173
# Iteration: 	29 / 100
# Confirmed: 	202
# Tentative: 	30
# Rejected: 	173
# Iteration: 	30 / 100
# Confirmed: 	202
# Tentative: 	29
# Rejected: 	174
# Iteration: 	31 / 100
# Confirmed: 	202
# Tentative: 	29
# Rejected: 	174
# Iteration: 	32 / 100
# Confirmed: 	204
# Tentative: 	27
# Rejected: 	174
# Iteration: 	33 / 100
# Confirmed: 	204
# Tentative: 	26
# Rejected: 	175
# Iteration: 	34 / 100
# Confirmed: 	208
# Tentative: 	22
# Rejected: 	175
# Iteration: 	35 / 100
# Confirmed: 	208
# Tentative: 	22
# Rejected: 	175
# Iteration: 	36 / 100
# Confirmed: 	208
# Tentative: 	22
# Rejected: 	175
# Iteration: 	37 / 100
# Confirmed: 	209
# Tentative: 	19
# Rejected: 	177
# Iteration: 	38 / 100
# Confirmed: 	209
# Tentative: 	19
# Rejected: 	177
# Iteration: 	39 / 100
# Confirmed: 	209
# Tentative: 	19
# Rejected: 	177
# Iteration: 	40 / 100
# Confirmed: 	209
# Tentative: 	19
# Rejected: 	177
# Iteration: 	41 / 100
# Confirmed: 	209
# Tentative: 	19
# Rejected: 	177
# Iteration: 	42 / 100
# Confirmed: 	209
# Tentative: 	19
# Rejected: 	177
# Iteration: 	43 / 100
# Confirmed: 	209
# Tentative: 	19
# Rejected: 	177
# Iteration: 	44 / 100
# Confirmed: 	209
# Tentative: 	19
# Rejected: 	177
# Iteration: 	45 / 100
# Confirmed: 	209
# Tentative: 	19
# Rejected: 	177
# Iteration: 	46 / 100
# Confirmed: 	210
# Tentative: 	18
# Rejected: 	177
# Iteration: 	47 / 100
# Confirmed: 	210
# Tentative: 	18
# Rejected: 	177
# Iteration: 	48 / 100
# Confirmed: 	210
# Tentative: 	18
# Rejected: 	177
# Iteration: 	49 / 100
# Confirmed: 	210
# Tentative: 	18
# Rejected: 	177
# Iteration: 	50 / 100
# Confirmed: 	210
# Tentative: 	18
# Rejected: 	177
# Iteration: 	51 / 100
# Confirmed: 	210
# Tentative: 	18
# Rejected: 	177
# Iteration: 	52 / 100
# Confirmed: 	210
# Tentative: 	17
# Rejected: 	178
# Iteration: 	53 / 100
# Confirmed: 	210
# Tentative: 	17
# Rejected: 	178
# Iteration: 	54 / 100
# Confirmed: 	211
# Tentative: 	16
# Rejected: 	178
# Iteration: 	55 / 100
# Confirmed: 	211
# Tentative: 	16
# Rejected: 	178
# Iteration: 	56 / 100
# Confirmed: 	211
# Tentative: 	16
# Rejected: 	178
# Iteration: 	57 / 100
# Confirmed: 	212
# Tentative: 	15
# Rejected: 	178
# Iteration: 	58 / 100
# Confirmed: 	212
# Tentative: 	15
# Rejected: 	178
# Iteration: 	59 / 100
# Confirmed: 	214
# Tentative: 	13
# Rejected: 	178
# Iteration: 	60 / 100
# Confirmed: 	214
# Tentative: 	13
# Rejected: 	178
# Iteration: 	61 / 100
# Confirmed: 	214
# Tentative: 	13
# Rejected: 	178
# Iteration: 	62 / 100
# Confirmed: 	214
# Tentative: 	13
# Rejected: 	178
# Iteration: 	63 / 100
# Confirmed: 	214
# Tentative: 	13
# Rejected: 	178
# Iteration: 	64 / 100
# Confirmed: 	214
# Tentative: 	13
# Rejected: 	178
# Iteration: 	65 / 100
# Confirmed: 	215
# Tentative: 	12
# Rejected: 	178
# Iteration: 	66 / 100
# Confirmed: 	215
# Tentative: 	12
# Rejected: 	178
# Iteration: 	67 / 100
# Confirmed: 	215
# Tentative: 	12
# Rejected: 	178
# Iteration: 	68 / 100
# Confirmed: 	215
# Tentative: 	12
# Rejected: 	178
# Iteration: 	69 / 100
# Confirmed: 	215
# Tentative: 	12
# Rejected: 	178
# Iteration: 	70 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	71 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	72 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	73 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	74 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	75 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	76 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	77 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	78 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	79 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	80 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	81 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	82 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	83 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	84 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	85 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	86 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	87 / 100
# Confirmed: 	216
# Tentative: 	11
# Rejected: 	178
# Iteration: 	88 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
# Iteration: 	89 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
# Iteration: 	90 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
# Iteration: 	91 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
# Iteration: 	92 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
# Iteration: 	93 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
# Iteration: 	94 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
# Iteration: 	95 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
# Iteration: 	96 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
# Iteration: 	97 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
# Iteration: 	98 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
# Iteration: 	99 / 100
# Confirmed: 	217
# Tentative: 	10
# Rejected: 	178
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	217
# Tentative: 	6
# Rejected: 	178

# %%
selected_columns = df_stat_conn_features_ec[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_stat_conn_feat_ec = df_stat_conn_features_ec[standard_columns]  # select the columns from the DataFrame
print(df_selected_stat_conn_feat_ec.shape)
df_selected_stat_conn_feat_ec.sample(5)
# Out:
# (2700, 220)
#                 ID  epoch diagnosis  EC_l_frontal_theta_std  \
# 536   sub-87971373      9       SMC                0.114785
# 587   sub-87974709     12   HEALTHY                0.108914
# 57    sub-87966517     10       SMC                0.106868
# 1622  sub-88048549      3       OCD                0.094043
# 2593  sub-88073885      2       OCD                0.117982
#
#       EC_m_frontal_theta_std  EC_r_frontal_theta_std  EC_l_central_theta_std  \
# 536                 0.114865                0.103978                0.107140
# 587                 0.133384                0.136674                0.106039
# 57                  0.097470                0.091380                0.098085
# 1622                0.097753                0.098636                0.096663
# 2593                0.107039                0.096011                0.104052
#
#       EC_r_central_theta_std  EC_l_posterior_theta_std  \
# 536                 0.124846                  0.105897
# 587                 0.144736                  0.111079
# 57                  0.085251                  0.119849
# 1622                0.092537                  0.093024
# 2593                0.116916                  0.109236
#
#       EC_m_posterior_theta_std  ...  EC_gamma_m_central-r_central  \
# 536                   0.092273  ...                      0.749505
# 587                   0.119342  ...                      0.895765
# 57                    0.098861  ...                      0.830535
# 1622                  0.093737  ...                      0.775829
# 2593                  0.118895  ...                      0.777775
#
#       EC_gamma_m_central-l_posterior  EC_gamma_m_central-m_posterior  \
# 536                         0.663992                        0.716134
# 587                         0.861933                        0.869849
# 57                          0.781098                        0.799996
# 1622                        0.706324                        0.747617
# 2593                        0.688952                        0.722259
#
#       EC_gamma_m_central-r_posterior  EC_gamma_r_central-l_posterior  \
# 536                         0.674772                        0.580052
# 587                         0.863044                        0.854949
# 57                          0.767622                        0.747995
# 1622                        0.700154                        0.692422
# 2593                        0.694607                        0.664303
#
#       EC_gamma_r_central-m_posterior  EC_gamma_r_central-r_posterior  \
# 536                         0.664514                        0.745458
# 587                         0.867756                        0.879852
# 57                          0.790709                        0.814956
# 1622                        0.757365                        0.786716
# 2593                        0.717218                        0.750099
#
#       EC_gamma_l_posterior-m_posterior  EC_gamma_l_posterior-r_posterior  \
# 536                           0.759964                          0.633281
# 587                           0.900204                          0.874141
# 57                            0.829541                          0.782852
# 1622                          0.811664                          0.732162
# 2593                          0.776573                          0.735147
#
#       EC_gamma_m_posterior-r_posterior
# 536                           0.737054
# 587                           0.896521
# 57                            0.843145
# 1622                          0.799504
# 2593                          0.778172
#
# [5 rows x 220 columns]

# %% [markdown]
# ### EO features

# %%
# define numeric columns
numeric_cols = [num_col for num_col in df_stat_conn_features_eo.columns if 'EO' in num_col]
 
X = df_stat_conn_features_eo[numeric_cols]
Y = df_stat_conn_features_eo['diagnosis']

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X = imp_mean.fit_transform(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y)

np.int = np.int32 # to avoid error message, because installed Boruta package via conda instead of pip
np.float = np.float64
np.bool = np.bool_

clf = RandomForestClassifier(n_jobs=-1, max_depth=20, class_weight='balanced')
trans = BorutaPy(clf, max_iter=100, random_state=42, verbose=10, n_estimators=185)
feature_selection = trans.fit_transform(X, Y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	405
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	186
# Tentative: 	48
# Rejected: 	171
# Iteration: 	9 / 100
# Confirmed: 	186
# Tentative: 	48
# Rejected: 	171
# Iteration: 	10 / 100
# Confirmed: 	186
# Tentative: 	48
# Rejected: 	171
# Iteration: 	11 / 100
# Confirmed: 	186
# Tentative: 	48
# Rejected: 	171
# Iteration: 	12 / 100
# Confirmed: 	191
# Tentative: 	43
# Rejected: 	171
# Iteration: 	13 / 100
# Confirmed: 	191
# Tentative: 	43
# Rejected: 	171
# Iteration: 	14 / 100
# Confirmed: 	191
# Tentative: 	43
# Rejected: 	171
# Iteration: 	15 / 100
# Confirmed: 	191
# Tentative: 	40
# Rejected: 	174
# Iteration: 	16 / 100
# Confirmed: 	193
# Tentative: 	38
# Rejected: 	174
# Iteration: 	17 / 100
# Confirmed: 	193
# Tentative: 	38
# Rejected: 	174
# Iteration: 	18 / 100
# Confirmed: 	193
# Tentative: 	34
# Rejected: 	178
# Iteration: 	19 / 100
# Confirmed: 	195
# Tentative: 	32
# Rejected: 	178
# Iteration: 	20 / 100
# Confirmed: 	195
# Tentative: 	32
# Rejected: 	178
# Iteration: 	21 / 100
# Confirmed: 	195
# Tentative: 	32
# Rejected: 	178
# Iteration: 	22 / 100
# Confirmed: 	197
# Tentative: 	28
# Rejected: 	180
# Iteration: 	23 / 100
# Confirmed: 	197
# Tentative: 	28
# Rejected: 	180
# Iteration: 	24 / 100
# Confirmed: 	197
# Tentative: 	28
# Rejected: 	180
# Iteration: 	25 / 100
# Confirmed: 	197
# Tentative: 	28
# Rejected: 	180
# Iteration: 	26 / 100
# Confirmed: 	197
# Tentative: 	28
# Rejected: 	180
# Iteration: 	27 / 100
# Confirmed: 	197
# Tentative: 	28
# Rejected: 	180
# Iteration: 	28 / 100
# Confirmed: 	197
# Tentative: 	28
# Rejected: 	180
# Iteration: 	29 / 100
# Confirmed: 	199
# Tentative: 	26
# Rejected: 	180
# Iteration: 	30 / 100
# Confirmed: 	199
# Tentative: 	25
# Rejected: 	181
# Iteration: 	31 / 100
# Confirmed: 	199
# Tentative: 	23
# Rejected: 	183
# Iteration: 	32 / 100
# Confirmed: 	199
# Tentative: 	23
# Rejected: 	183
# Iteration: 	33 / 100
# Confirmed: 	199
# Tentative: 	23
# Rejected: 	183
# Iteration: 	34 / 100
# Confirmed: 	199
# Tentative: 	23
# Rejected: 	183
# Iteration: 	35 / 100
# Confirmed: 	199
# Tentative: 	23
# Rejected: 	183
# Iteration: 	36 / 100
# Confirmed: 	199
# Tentative: 	23
# Rejected: 	183
# Iteration: 	37 / 100
# Confirmed: 	200
# Tentative: 	22
# Rejected: 	183
# Iteration: 	38 / 100
# Confirmed: 	200
# Tentative: 	22
# Rejected: 	183
# Iteration: 	39 / 100
# Confirmed: 	200
# Tentative: 	22
# Rejected: 	183
# Iteration: 	40 / 100
# Confirmed: 	201
# Tentative: 	21
# Rejected: 	183
# Iteration: 	41 / 100
# Confirmed: 	201
# Tentative: 	21
# Rejected: 	183
# Iteration: 	42 / 100
# Confirmed: 	201
# Tentative: 	21
# Rejected: 	183
# Iteration: 	43 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	44 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	45 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	46 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	47 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	48 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	49 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	50 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	51 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	52 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	53 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	54 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	55 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	56 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	57 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	58 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	59 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	60 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	61 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	62 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	63 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	64 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	65 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	66 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	67 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	68 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	69 / 100
# Confirmed: 	202
# Tentative: 	20
# Rejected: 	183
# Iteration: 	70 / 100
# Confirmed: 	203
# Tentative: 	19
# Rejected: 	183
# Iteration: 	71 / 100
# Confirmed: 	203
# Tentative: 	19
# Rejected: 	183
# Iteration: 	72 / 100
# Confirmed: 	203
# Tentative: 	19
# Rejected: 	183
# Iteration: 	73 / 100
# Confirmed: 	203
# Tentative: 	19
# Rejected: 	183
# Iteration: 	74 / 100
# Confirmed: 	203
# Tentative: 	19
# Rejected: 	183
# Iteration: 	75 / 100
# Confirmed: 	203
# Tentative: 	19
# Rejected: 	183
# Iteration: 	76 / 100
# Confirmed: 	203
# Tentative: 	19
# Rejected: 	183
# Iteration: 	77 / 100
# Confirmed: 	203
# Tentative: 	19
# Rejected: 	183
# Iteration: 	78 / 100
# Confirmed: 	203
# Tentative: 	19
# Rejected: 	183
# Iteration: 	79 / 100
# Confirmed: 	203
# Tentative: 	19
# Rejected: 	183
# Iteration: 	80 / 100
# Confirmed: 	204
# Tentative: 	18
# Rejected: 	183
# Iteration: 	81 / 100
# Confirmed: 	204
# Tentative: 	18
# Rejected: 	183
# Iteration: 	82 / 100
# Confirmed: 	204
# Tentative: 	18
# Rejected: 	183
# Iteration: 	83 / 100
# Confirmed: 	205
# Tentative: 	17
# Rejected: 	183
# Iteration: 	84 / 100
# Confirmed: 	205
# Tentative: 	17
# Rejected: 	183
# Iteration: 	85 / 100
# Confirmed: 	205
# Tentative: 	17
# Rejected: 	183
# Iteration: 	86 / 100
# Confirmed: 	205
# Tentative: 	17
# Rejected: 	183
# Iteration: 	87 / 100
# Confirmed: 	205
# Tentative: 	17
# Rejected: 	183
# Iteration: 	88 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
# Iteration: 	89 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
# Iteration: 	90 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
# Iteration: 	91 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
# Iteration: 	92 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
# Iteration: 	93 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
# Iteration: 	94 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
# Iteration: 	95 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
# Iteration: 	96 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
# Iteration: 	97 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
# Iteration: 	98 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
# Iteration: 	99 / 100
# Confirmed: 	205
# Tentative: 	15
# Rejected: 	185
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	205
# Tentative: 	7
# Rejected: 	185

# %%
selected_columns = df_stat_conn_features_eo[numeric_cols].columns[trans.support_].tolist()  # get selected features
standard_columns = ['ID', 'epoch', 'diagnosis']  # columns to add
standard_columns.extend(selected_columns)  # add the columns
df_selected_stat_conn_feat_eo = df_stat_conn_features_eo[standard_columns]  # select the columns from the DataFrame
print(df_selected_stat_conn_feat_eo.shape)
df_selected_stat_conn_feat_eo.sample(5)
# Out:
# (2700, 208)
#                 ID  epoch diagnosis  EO_l_frontal_alpha_std  \
# 1062  sub-88022001      7       MDD                0.170621
# 873   sub-88000313     10       MDD                0.152858
# 2031  sub-88058001      4   HEALTHY                0.105697
# 1119  sub-88024697      4       MDD                0.091067
# 965   sub-88016105      6       MDD                0.139119
#
#       EO_m_frontal_alpha_std  EO_r_frontal_alpha_std  EO_l_central_alpha_std  \
# 1062                0.194335                0.164815                0.123891
# 873                 0.141632                0.140625                0.172173
# 2031                0.147422                0.171927                0.114545
# 1119                0.089897                0.085179                0.076782
# 965                 0.137748                0.144738                0.144742
#
#       EO_m_central_alpha_std  EO_r_central_alpha_std  \
# 1062                0.139720                0.150749
# 873                 0.136408                0.155713
# 2031                0.126812                0.136839
# 1119                0.088303                0.099702
# 965                 0.129675                0.128514
#
#       EO_l_posterior_alpha_std  ...  EO_gamma_m_central-r_central  \
# 1062                  0.169280  ...                      0.902350
# 873                   0.207446  ...                      0.755830
# 2031                  0.132618  ...                      0.795670
# 1119                  0.157118  ...                      0.854742
# 965                   0.133519  ...                      0.776565
#
#       EO_gamma_m_central-l_posterior  EO_gamma_m_central-m_posterior  \
# 1062                        0.882493                        0.882733
# 873                         0.685375                        0.716817
# 2031                        0.724958                        0.750816
# 1119                        0.809633                        0.798962
# 965                         0.707950                        0.739443
#
#       EO_gamma_m_central-r_posterior  EO_gamma_r_central-l_posterior  \
# 1062                        0.878334                        0.876694
# 873                         0.685904                        0.650058
# 2031                        0.722474                        0.671388
# 1119                        0.805232                        0.783208
# 965                         0.735176                        0.661362
#
#       EO_gamma_r_central-m_posterior  EO_gamma_r_central-r_posterior  \
# 1062                        0.884839                        0.899373
# 873                         0.704888                        0.732322
# 2031                        0.716272                        0.732355
# 1119                        0.777696                        0.809034
# 965                         0.715445                        0.757211
#
#       EO_gamma_l_posterior-m_posterior  EO_gamma_l_posterior-r_posterior  \
# 1062                          0.900934                          0.887940
# 873                           0.764316                          0.703978
# 2031                          0.809490                          0.752011
# 1119                          0.857499                          0.825579
# 965                           0.787885                          0.740052
#
#       EO_gamma_m_posterior-r_posterior
# 1062                          0.897253
# 873                           0.765960
# 2031                          0.798749
# 1119                          0.837621
# 965                           0.784436
#
# [5 rows x 208 columns]

# %% [markdown]
# ### Merge selected ratio, EC, EO features

# %%
# Drop the 'ID', 'epoch', 'diagnosis' columns from the second and third dataframes for concatenation
df_selected_stat_conn_feat_eo = df_selected_stat_conn_feat_eo.drop(['ID', 'epoch', 'diagnosis'], axis=1)
df_selected_stat_conn_feat_ratio = df_selected_stat_conn_feat_ratio.drop(['ID', 'epoch', 'diagnosis'], axis=1)

# Concatenate the dataframes
df_selected_stat_conn_features = pd.concat([df_selected_stat_conn_feat_ec, df_selected_stat_conn_feat_eo, df_selected_stat_conn_feat_ratio], axis=1)
df_selected_stat_conn_features
# Out:
#                 ID  epoch diagnosis  EC_l_frontal_theta_std  \
# 0     sub-87964717      1       SMC                0.146601
# 1     sub-87964717      2       SMC                0.103510
# 2     sub-87964717      3       SMC                0.126494
# 3     sub-87964717      4       SMC                0.199366
# 4     sub-87964717      5       SMC                0.145020
# ...            ...    ...       ...                     ...
# 2695  sub-88076717      8       OCD                0.148191
# 2696  sub-88076717      9       OCD                0.111555
# 2697  sub-88076717     10       OCD                0.159637
# 2698  sub-88076717     11       OCD                0.139784
# 2699  sub-88076717     12       OCD                0.267289
#
#       EC_m_frontal_theta_std  EC_r_frontal_theta_std  EC_l_central_theta_std  \
# 0                   0.140457                0.134083                0.111772
# 1                   0.106254                0.113882                0.104289
# 2                   0.129298                0.153072                0.116544
# 3                   0.181563                0.190631                0.172736
# 4                   0.183063                0.181982                0.120705
# ...                      ...                     ...                     ...
# 2695                0.145226                0.173885                0.156004
# 2696                0.120504                0.139117                0.126790
# 2697                0.170118                0.184458                0.234596
# 2698                0.157755                0.164089                0.131705
# 2699                0.247254                0.286961                0.285056
#
#       EC_r_central_theta_std  EC_l_posterior_theta_std  \
# 0                   0.126677                  0.097456
# 1                   0.113146                  0.089767
# 2                   0.176219                  0.101275
# 3                   0.161905                  0.160612
# 4                   0.153659                  0.112695
# ...                      ...                       ...
# 2695                0.203578                  0.119112
# 2696                0.116225                  0.123273
# 2697                0.188101                  0.208276
# 2698                0.166881                  0.116801
# 2699                0.246421                  0.233626
#
#       EC_m_posterior_theta_std  ...  ratio_gamma_m_central-r_central  \
# 0                     0.088821  ...                         0.983375
# 1                     0.093144  ...                         0.951962
# 2                     0.122526  ...                         1.007210
# 3                     0.155581  ...                         0.987823
# 4                     0.130231  ...                         1.042865
# ...                        ...  ...                              ...
# 2695                  0.131782  ...                         1.050150
# 2696                  0.116095  ...                         1.095957
# 2697                  0.169570  ...                         1.059378
# 2698                  0.150072  ...                         1.048840
# 2699                  0.217819  ...                         1.069163
#
#       ratio_gamma_m_central-l_posterior  ratio_gamma_m_central-m_posterior  \
# 0                              0.982205                           0.973501
# 1                              0.999252                           0.989583
# 2                              1.003786                           0.997969
# 3                              1.029448                           1.023404
# 4                              1.021432                           1.011774
# ...                                 ...                                ...
# 2695                           1.093657                           1.076960
# 2696                           1.144254                           1.111357
# 2697                           1.114762                           1.086334
# 2698                           1.054833                           1.083075
# 2699                           1.087860                           1.099526
#
#       ratio_gamma_m_central-r_posterior  ratio_gamma_r_central-l_posterior  \
# 0                              0.957588                           0.965101
# 1                              0.969516                           0.930350
# 2                              0.981911                           1.021233
# 3                              1.011507                           0.995531
# 4                              1.023296                           1.010551
# ...                                 ...                                ...
# 2695                           1.060231                           1.153361
# 2696                           1.115784                           1.178204
# 2697                           1.146659                           1.183257
# 2698                           1.104262                           1.037404
# 2699                           1.116985                           1.091360
#
#       ratio_gamma_r_central-m_posterior  ratio_gamma_r_central-r_posterior  \
# 0                              0.975819                           0.977929
# 1                              0.938956                           0.968311
# 2                              1.027465                           1.020506
# 3                              1.025771                           1.032580
# 4                              1.047893                           1.041591
# ...                                 ...                                ...
# 2695                           1.122004                           1.055451
# 2696                           1.139658                           1.100500
# 2697                           1.136850                           1.136010
# 2698                           1.049401                           1.063298
# 2699                           1.102320                           1.098257
#
#       ratio_gamma_l_posterior-m_posterior  \
# 0                                0.973242
# 1                                0.982378
# 2                                0.977939
# 3                                0.990293
# 4                                1.019603
# ...                                   ...
# 2695                             1.082843
# 2696                             1.109036
# 2697                             1.085056
# 2698                             1.047424
# 2699                             1.062940
#
#       ratio_gamma_l_posterior-r_posterior  ratio_gamma_m_posterior-r_posterior
# 0                                0.955600                             0.985688
# 1                                0.955147                             0.965178
# 2                                0.966586                             0.985563
# 3                                0.982638                             1.006213
# 4                                1.005809                             1.024247
# ...                                   ...                                  ...
# 2695                             1.109466                             1.075791
# 2696                             1.142876                             1.095822
# 2697                             1.136426                             1.107047
# 2698                             1.064664                             1.070277
# 2699                             1.066860                             1.070410
#
# [2700 rows x 585 columns]

# %%
df_selected_stat_conn_features.to_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_selected_stat_conn_features.pkl')
