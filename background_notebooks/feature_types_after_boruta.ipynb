# %% [markdown]
# ## AIM: check frequencies of feature types from the statistical features selected by BORUTA

# %%
import pandas as pd
import numpy as np
import pickle

# %%
df_stat_features = pd.read_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_selected_stat_features.pkl')
df_stat_features = df_stat_features.dropna(subset=['diagnosis'])
df_stat_features.sample(7)
# Out:
#                 ID  epoch diagnosis  EC_l_frontal_delta_mean  \
# 1120  sub-87976369      5   HEALTHY                 0.069249
# 6456  sub-88064837      1       MDD                 0.071875
# 1546  sub-88005941     11       MDD                 0.077089
# 758   sub-87969849      3       SMC                 0.067456
# 660   sub-87969125      1       SMC                 0.036956
# 6623  sub-88066413     12       OCD                 0.026782
# 307   sub-87967417      8       SMC                 0.073612
#
#       EC_l_frontal_delta_median  EC_l_frontal_theta_std  \
# 1120                   0.069249                0.041979
# 6456                   0.071875                0.030726
# 1546                   0.077089                0.026883
# 758                    0.067456                0.026031
# 660                    0.036956                0.022504
# 6623                   0.026782                0.045009
# 307                    0.073612                0.032292
#
# ...

# %%
# create 3 feature sets [EC, EO, ratio] with column ['ID', 'age', 'gender', 'diagnosis', 'epoch']
df_stat_features_ec = df_stat_features[df_stat_features.columns[~(df_stat_features.columns.str.startswith('EO') | df_stat_features.columns.str.startswith('ratio'))]]
df_stat_features_eo = df_stat_features[df_stat_features.columns[~(df_stat_features.columns.str.startswith('EC') | df_stat_features.columns.str.startswith('ratio'))]]
df_stat_features_ratio = df_stat_features[df_stat_features.columns[~(df_stat_features.columns.str.startswith('EC') | df_stat_features.columns.str.startswith('EO'))]]

# %%
# count the number of columns names containing stats and bands for each feature set
print('EC:')
print('mean:', df_stat_features_ec.columns.str.contains('mean').sum())
print('std:', df_stat_features_ec.columns.str.contains('std').sum())
print('median:', df_stat_features_ec.columns.str.contains('median').sum())
print('skew:', df_stat_features_ec.columns.str.contains('skew').sum())
print('kurt:', df_stat_features_ec.columns.str.contains('kurt').sum())
print('delta:', df_stat_features_ec.columns.str.contains('delta').sum())
print('theta:', df_stat_features_ec.columns.str.contains('theta').sum())
print('alpha:', df_stat_features_ec.columns.str.contains('alpha').sum())
print('beta:', df_stat_features_ec.columns.str.contains('beta').sum())
print('gamma:', df_stat_features_ec.columns.str.contains('gamma').sum())
print('l_frontal:', df_stat_features_ec.columns.str.contains('l_frontal').sum())
print('m_frontal:', df_stat_features_ec.columns.str.contains('m_frontal').sum())
print('r_frontal:', df_stat_features_ec.columns.str.contains('r_frontal').sum())
print('l_central:', df_stat_features_ec.columns.str.contains('l_central').sum())
print('m_central:', df_stat_features_ec.columns.str.contains('m_central').sum())
print('r_central:', df_stat_features_ec.columns.str.contains('r_central').sum())
print('l_posterior:', df_stat_features_ec.columns.str.contains('l_posterior').sum())
print('m_posterior:', df_stat_features_ec.columns.str.contains('m_posterior').sum())
print('r_posterior:', df_stat_features_ec.columns.str.contains('r_posterior').sum())

print('')
print('EO:')
print('mean:', df_stat_features_eo.columns.str.contains('mean').sum())
print('std:', df_stat_features_eo.columns.str.contains('std').sum())
print('median:', df_stat_features_eo.columns.str.contains('median').sum())
print('skew:', df_stat_features_eo.columns.str.contains('skew').sum())
print('kurt:', df_stat_features_eo.columns.str.contains('kurt').sum())
print('delta:', df_stat_features_eo.columns.str.contains('delta').sum())
print('theta:', df_stat_features_eo.columns.str.contains('theta').sum())
print('alpha:', df_stat_features_eo.columns.str.contains('alpha').sum())
print('beta:', df_stat_features_eo.columns.str.contains('beta').sum())
print('gamma:', df_stat_features_eo.columns.str.contains('gamma').sum())
print('l_frontal:', df_stat_features_eo.columns.str.contains('l_frontal').sum())
print('m_frontal:', df_stat_features_eo.columns.str.contains('m_frontal').sum())
print('r_frontal:', df_stat_features_eo.columns.str.contains('r_frontal').sum())
print('l_central:', df_stat_features_eo.columns.str.contains('l_central').sum())
print('m_central:', df_stat_features_eo.columns.str.contains('m_central').sum())
print('r_central:', df_stat_features_eo.columns.str.contains('r_central').sum())
print('l_posterior:', df_stat_features_eo.columns.str.contains('l_posterior').sum())
print('m_posterior:', df_stat_features_eo.columns.str.contains('m_posterior').sum())
print('r_posterior:', df_stat_features_eo.columns.str.contains('r_posterior').sum())

print('')
print('Ratio:')
print('mean:', df_stat_features_ratio.columns.str.contains('mean').sum())
print('std:', df_stat_features_ratio.columns.str.contains('std').sum())
print('median:', df_stat_features_ratio.columns.str.contains('median').sum())
print('skew:', df_stat_features_ratio.columns.str.contains('skew').sum())
print('kurt:', df_stat_features_ratio.columns.str.contains('kurt').sum())
print('delta:', df_stat_features_ratio.columns.str.contains('delta').sum())
print('theta:', df_stat_features_ratio.columns.str.contains('theta').sum())
print('alpha:', df_stat_features_ratio.columns.str.contains('alpha').sum())
print('beta:', df_stat_features_ratio.columns.str.contains('beta').sum())
print('gamma:', df_stat_features_ratio.columns.str.contains('gamma').sum())
print('l_frontal:', df_stat_features_ratio.columns.str.contains('l_frontal').sum())
print('m_frontal:', df_stat_features_ratio.columns.str.contains('m_frontal').sum())
print('r_frontal:', df_stat_features_ratio.columns.str.contains('r_frontal').sum())
print('l_central:', df_stat_features_ratio.columns.str.contains('l_central').sum())
print('m_central:', df_stat_features_ratio.columns.str.contains('m_central').sum())
print('r_central:', df_stat_features_ratio.columns.str.contains('r_central').sum())
print('l_posterior:', df_stat_features_ratio.columns.str.contains('l_posterior').sum())
print('m_posterior:', df_stat_features_ratio.columns.str.contains('m_posterior').sum())
print('r_posterior:', df_stat_features_ratio.columns.str.contains('r_posterior').sum())
# Out:
# EC:
# mean: 45
# std: 44
# median: 45
# skew: 10
# kurt: 3
# delta: 26
# theta: 27
# alpha: 28
# beta: 27
# gamma: 39
# l_frontal: 15
# m_frontal: 16
# r_frontal: 17
# l_central: 16
# m_central: 16
# r_central: 16
# l_posterior: 17
# m_posterior: 16
# r_posterior: 18
#
# EO:
# mean: 45
# std: 38
# median: 45
# skew: 7
# kurt: 0
# delta: 25
# theta: 25
# alpha: 24
# beta: 27
# gamma: 34
# l_frontal: 16
# m_frontal: 15
# r_frontal: 16
# l_central: 16
# m_central: 12
# r_central: 15
# l_posterior: 14
# m_posterior: 15
# r_posterior: 16
#
# Ratio:
# mean: 23
# std: 12
# median: 31
# skew: 0
# kurt: 0
# delta: 7
# theta: 16
# alpha: 6
# beta: 12
# gamma: 25
# l_frontal: 5
# m_frontal: 4
# r_frontal: 6
# l_central: 7
# m_central: 4
# r_central: 7
# l_posterior: 12
# m_posterior: 11
# r_posterior: 10

# %% [markdown]
# ### selected stat + conn features

# %%
df_stat_conn_features = pd.read_pickle(r'D:\Documents\RU\Master_Neurobiology\Internship_jaar_2\Project\TD-BRAIN\TD-BRAIN_extracted_features\df_selected_stat_conn_features.pkl')
df_stat_conn_features = df_stat_conn_features.dropna(subset=['diagnosis'])
df_stat_conn_features.sample(7)
# Out:
#                 ID  epoch diagnosis  EC_l_frontal_delta_std  \
# 938   sub-88013761      3       OCD                0.078819
# 1025  sub-88019165      6      ADHD                0.054296
# 272   sub-87968765      9       SMC                0.068936
# 367   sub-87969805      8       SMC                0.222957
# 1915  sub-88055121      8   HEALTHY                0.078157
# 2004  sub-88057781      1      ADHD                0.064329
# 1916  sub-88055121      9   HEALTHY                0.033392
#
#       EC_l_frontal_delta_mean  EC_l_frontal_delta_median  \
# 938                  0.089856                   0.089856
# 1025                 0.084108                   0.084108
# 272                  0.063821                   0.063821
# 367                  0.076194                   0.076194
# 1915                 0.091308                   0.091308
# 2004                 0.072954                   0.072954
# 1916                 0.055913                   0.055913
#
# ...

# %%
df_stat_conn_features_ec = df_stat_conn_features[df_stat_conn_features.columns[~(df_stat_conn_features.columns.str.startswith('EO') | df_stat_conn_features.columns.str.startswith('ratio'))]]
df_stat_conn_features_eo = df_stat_conn_features[df_stat_conn_features.columns[~(df_stat_conn_features.columns.str.startswith('EC') | df_stat_conn_features.columns.str.startswith('ratio'))]]
df_stat_conn_features_ratio = df_stat_conn_features[df_stat_conn_features.columns[~(df_stat_conn_features.columns.str.startswith('EC') | df_stat_conn_features.columns.str.startswith('EO'))]]

# %%
# count the number of columns names containing stats and bands for each feature set
print('EC:')
print('mean:', df_stat_conn_features_ec.columns.str.contains('mean').sum())
print('std:', df_stat_conn_features_ec.columns.str.contains('std').sum())
print('median:', df_stat_conn_features_ec.columns.str.contains('median').sum())
print('skew:', df_stat_conn_features_ec.columns.str.contains('skew').sum())
print('kurt:', df_stat_conn_features_ec.columns.str.contains('kurt').sum())
print('delta:', df_stat_conn_features_ec.columns.str.contains('delta').sum())
print('theta:', df_stat_conn_features_ec.columns.str.contains('theta').sum())
print('alpha:', df_stat_conn_features_ec.columns.str.contains('alpha').sum())
print('beta:', df_stat_conn_features_ec.columns.str.contains('beta').sum())
print('gamma:', df_stat_conn_features_ec.columns.str.contains('gamma').sum())
print('connectivity:', df_stat_conn_features_ec.columns.str.contains('-').sum())
print('l_frontal:', df_stat_conn_features_ec.columns.str.contains('l_frontal').sum())
print('m_frontal:', df_stat_conn_features_ec.columns.str.contains('m_frontal').sum())
print('r_frontal:', df_stat_conn_features_ec.columns.str.contains('r_frontal').sum())
print('l_central:', df_stat_conn_features_ec.columns.str.contains('l_central').sum())
print('m_central:', df_stat_conn_features_ec.columns.str.contains('m_central').sum())
print('r_central:', df_stat_conn_features_ec.columns.str.contains('r_central').sum())
print('l_posterior:', df_stat_conn_features_ec.columns.str.contains('l_posterior').sum())
print('m_posterior:', df_stat_conn_features_ec.columns.str.contains('m_posterior').sum())
print('r_posterior:', df_stat_conn_features_ec.columns.str.contains('r_posterior').sum())

print('')
print('EO:')
print('mean:', df_stat_conn_features_eo.columns.str.contains('mean').sum())
print('std:', df_stat_conn_features_eo.columns.str.contains('std').sum())
print('median:', df_stat_conn_features_eo.columns.str.contains('median').sum())
print('skew:', df_stat_conn_features_eo.columns.str.contains('skew').sum())
print('kurt:', df_stat_conn_features_eo.columns.str.contains('kurt').sum())
print('delta:', df_stat_conn_features_eo.columns.str.contains('delta').sum())
print('theta:', df_stat_conn_features_eo.columns.str.contains('theta').sum())
print('alpha:', df_stat_conn_features_eo.columns.str.contains('alpha').sum())
print('beta:', df_stat_conn_features_eo.columns.str.contains('beta').sum())
print('gamma:', df_stat_conn_features_eo.columns.str.contains('gamma').sum())
print('connectivity:', df_stat_conn_features_eo.columns.str.contains('-').sum())
print('l_frontal:', df_stat_conn_features_eo.columns.str.contains('l_frontal').sum())
print('m_frontal:', df_stat_conn_features_eo.columns.str.contains('m_frontal').sum())
print('r_frontal:', df_stat_conn_features_eo.columns.str.contains('r_frontal').sum())
print('l_central:', df_stat_conn_features_eo.columns.str.contains('l_central').sum())
print('m_central:', df_stat_conn_features_eo.columns.str.contains('m_central').sum())
print('r_central:', df_stat_conn_features_eo.columns.str.contains('r_central').sum())
print('l_posterior:', df_stat_conn_features_eo.columns.str.contains('l_posterior').sum())
print('m_posterior:', df_stat_conn_features_eo.columns.str.contains('m_posterior').sum())
print('r_posterior:', df_stat_conn_features_eo.columns.str.contains('r_posterior').sum())

print('')
print('Ratio:')
print('mean:', df_stat_conn_features_ratio.columns.str.contains('mean').sum())
print('std:', df_stat_conn_features_ratio.columns.str.contains('std').sum())
print('median:', df_stat_conn_features_ratio.columns.str.contains('median').sum())
print('skew:', df_stat_conn_features_ratio.columns.str.contains('skew').sum())
print('kurt:', df_stat_conn_features_ratio.columns.str.contains('kurt').sum())
print('delta:', df_stat_conn_features_ratio.columns.str.contains('delta').sum())
print('theta:', df_stat_conn_features_ratio.columns.str.contains('theta').sum())
print('alpha:', df_stat_conn_features_ratio.columns.str.contains('alpha').sum())
print('beta:', df_stat_conn_features_ratio.columns.str.contains('beta').sum())
print('gamma:', df_stat_conn_features_ratio.columns.str.contains('gamma').sum())
print('connectivity:', df_stat_conn_features_ratio.columns.str.contains('-').sum())
print('l_frontal:', df_stat_conn_features_ratio.columns.str.contains('l_frontal').sum())
print('m_frontal:', df_stat_conn_features_ratio.columns.str.contains('m_frontal').sum())
print('r_frontal:', df_stat_conn_features_ratio.columns.str.contains('r_frontal').sum())
print('l_central:', df_stat_conn_features_ratio.columns.str.contains('l_central').sum())
print('m_central:', df_stat_conn_features_ratio.columns.str.contains('m_central').sum())
print('r_central:', df_stat_conn_features_ratio.columns.str.contains('r_central').sum())
print('l_posterior:', df_stat_conn_features_ratio.columns.str.contains('l_posterior').sum())
print('m_posterior:', df_stat_conn_features_ratio.columns.str.contains('m_posterior').sum())
print('r_posterior:', df_stat_conn_features_ratio.columns.str.contains('r_posterior').sum())
# Out:
# EC:
# mean: 45
# std: 45
# median: 45
# skew: 3
# kurt: 1
# delta: 63
# theta: 63
# alpha: 63
# beta: 63
# gamma: 67
# connectivity: 180
# l_frontal: 55
# m_frontal: 55
# r_frontal: 55
# l_central: 55
# m_central: 55
# r_central: 55
# l_posterior: 57
# m_posterior: 56
# r_posterior: 56
#
# EO:
# mean: 45
# std: 36
# median: 45
# skew: 0
# kurt: 0
# delta: 54
# theta: 58
# alpha: 63
# beta: 63
# gamma: 63
# connectivity: 175
# l_frontal: 52
# m_frontal: 54
# r_frontal: 50
# l_central: 53
# m_central: 53
# r_central: 54
# l_posterior: 55
# m_posterior: 53
# r_posterior: 52
#
# Ratio:
# mean: 28
# std: 12
# median: 39
# skew: 0
# kurt: 0
# delta: 10
# theta: 35
# alpha: 40
# beta: 34
# gamma: 63
# connectivity: 103
# l_frontal: 30
# m_frontal: 30
# r_frontal: 32
# l_central: 31
# m_central: 29
# r_central: 32
# l_posterior: 33
# m_posterior: 34
# r_posterior: 34
